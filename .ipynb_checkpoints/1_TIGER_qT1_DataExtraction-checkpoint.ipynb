# %%
from nipype.interfaces.io import DataSink, SelectFiles, DataGrabber 
from nipype.interfaces.utility import IdentityInterface, Function    
from nipype.pipeline.engine import Node, Workflow, JoinNode, MapNode
from nipype.interfaces import fsl
from nipype.interfaces import freesurfer as fsr
from nipype.interfaces import brainsuite
from nipype.interfaces.io import SelectFiles, DataSink, DataGrabber
from shutil import copyfile
import pandas as pd
from glob import glob
from os.path import abspath, expanduser, join
from os import chdir, remove, getcwd
from nipype import config, logging
from datetime import date
today = str(date.today())
config.enable_debug_mode()

# %%
#Set variables
# subject_list = ['02-T2', '06-T1', '07-T2','08-T1', '09-T2', '10-T1', '11-T1', '12-T1', '13-T1', '15-T1', '16-T1', '17-T1',
#                 '18-T1', '19-T1', '20-T1', '21-T1', '22-T1', '23-T1', '24-T1', '29-T1', '30-T1', '31-T1', '32-T1',
#                 '35-T1', '36-T1', '37-T1', '38-T1', '40-T1', '102-T1', '103-T1', '104-T1', '105-T1', '106-T1', '107-T1', '108-T1', '109-T1',
#                 '110-T1', '111-T1']

#subject_list = ['072-T4', '112-T4'] #'164-T3','072-T3', 

home = '/Volumes/group/proc/TIGERanalysis/qT1'
fpath = home + '/subjDir'
userhome = '/Users/lucindasisk/Documents/qT1_10.2020Analysis'
data_dir = userhome + '/data'
workflow_dir = userhome + '/workflow_1.27.21'
data = userhome + '/flywheel_subjDir'

# subs = glob(data + '/*-*')
# subject_list = pd.Series(subs).str.replace(data + '/', '')
# subject_list

subs = pd.read_csv('/Users/lucindasisk/Dropbox/TIGER CURATED/qT1/LucindaAnalysis_12.2020/Tiger_qT1_MasterFile_2021-02-19.csv', header=0)
sub_noctl = subs[subs['Group'] != 'notCTL']
subject_list = sub_noctl['ID'].tolist() ## [0:18]
print(len(subject_list))
# Out:
# 83

# %%
#Setup Datasink, Infosource, Selectfiles

datasink = Node(DataSink(base_directory = data_dir,
                        substitutions=[('_subject_id_', '')]),
                   name='datasink')

#Set infosource iterables
infosource = Node(IdentityInterface(fields=['subject_id']),
                  name="infosource")
infosource.iterables = [('subject_id', subject_list)]

#SelectFiles
template = dict(t1 = fpath + '/{subject_id}/raw/T1_acpc.nii.gz',
               qt1 = data + '/{subject_id}/fw_qT1_t1fit_final.nii.gz')

sf = Node(SelectFiles(template, 
                      base_directory = fpath),
          name = 'sf')

# %%
#Skullstrip T1w image
stripT1 = Node(fsl.BET(out_file = 'T1_acpc_bet.nii.gz'),
             name = 'stripT1')

#Reorient qT1 to standard orientation
reorient = Node(fsl.Reorient2Std(out_file = 'reoriented_qT1.nii.gz',
                              output_type = 'NIFTI_GZ'),
                    name = 'reorient')

#Register qT1 to T1w
register_qt1 = Node(fsl.FLIRT(out_file = 'registered_qT1_T1acpc.nii.gz',
                              output_type = 'NIFTI_GZ',
                              out_matrix_file = 'flirt_transform_qt1.mat'),
                    name = 'register_qt1')

#Extract voxel values from qT1 beneath overlaid mask - Left Uncinate
get_voxLUF = Node(fsl.ImageMeants(show_all = True,
                               out_file = 'ROI_voxel-contrasts_LeftUF.txt'),
               name = 'get_voxLUF')

#Extract voxel values from qT1 beneath overlaid mask - Right Uncinate
get_voxRUF = Node(fsl.ImageMeants(show_all = True,
                               out_file = 'ROI_voxel-contrasts_RightUF.txt'),
               name = 'get_voxRUF')

#Extract voxel values from qT1 beneath overlaid mask - Left Cingulum Cingulate
get_voxLCC = Node(fsl.ImageMeants(show_all = True,
                               out_file = 'ROI_voxel-contrasts_LeftCC.txt'),
               name = 'get_voxLCC')

#Extract voxel values from qT1 beneath overlaid mask - Right Cingulum Cingulate
get_voxRCC = Node(fsl.ImageMeants(show_all = True,
                               out_file = 'ROI_voxel-contrasts_RightCC.txt'),
               name = 'get_voxRCC')

#Extract voxel values from qT1 beneath overlaid mask - Left Corticosponal
get_voxLCST = Node(fsl.ImageMeants(show_all = True,
                               out_file = 'ROI_voxel-contrasts_LeftCST.txt'),
               name = 'get_voxLCST')

#Extract voxel values from qT1 beneath overlaid mask - Right Corticospinal
get_voxRCST = Node(fsl.ImageMeants(show_all = True,
                               out_file = 'ROI_voxel-contrasts_RightCST.txt'),
               name = 'get_voxRCST')

#Extract voxel values from qT1 beneath overlaid mask - Callosum Major
get_voxCCMaj = Node(fsl.ImageMeants(show_all = True,
                               out_file = 'ROI_voxel-contrasts_CCMaj.txt'),
               name = 'get_voxCCMaj')

#Extract voxel values from qT1 beneath overlaid mask - Callosum Minor
get_voxCCMin = Node(fsl.ImageMeants(show_all = True,
                               out_file = 'ROI_voxel-contrasts_CCMin.txt'),
               name = 'get_voxCCMin')

#Get global R1
get_globalR1 = Node(fsl.ImageMeants(show_all = True,
                               out_file = 'ROI_voxel-contrasts_GlobalR1.txt'),
               name = 'get_globalR1')

# %%
qt1proc_flow = Workflow(name='qt1proc_flow')
qt1proc_flow.connect([(infosource, sf, [('subject_id', 'subject_id')]),
                      (sf, stripT1, [('t1', 'in_file')]),
                      (stripT1, datasink, [('out_file', '1_check_alignment')]),
                      (sf, reorient, [('qt1', 'in_file')]),
                      (reorient, datasink, [
                       ('out_file', '1_check_alignment.@par')]),
                      (reorient, register_qt1, [('out_file', 'in_file')]),
                      (stripT1, register_qt1, [('out_file', 'reference')]),
                      (register_qt1, datasink, [
                       ('out_file', '1_check_alignment.@par.@par')])
                      ])

qt1proc_flow.base_dir = workflow_dir
qt1proc_flow.write_graph(graph2use='flat')
preproc = qt1proc_flow.run('MultiProc', plugin_args={'n_procs': 4})

# %%
#SelectFiles
template2 = dict(qt1r=data_dir+'/1_check_alignment/{subject_id}/registered_qT1_T1acpc.nii.gz',
                unc_maskL = fpath+'/{subject_id}/Left_Uncinate.nii.gz',
                unc_maskR = fpath+'/{subject_id}/Right_Uncinate.nii.gz',
                cc_maskL = fpath+'/{subject_id}/Left_Cingulum_Cingulate.nii.gz',
                cc_maskR = fpath+'/{subject_id}/Right_Cingulum_Cingulate.nii.gz',
#                 cst_maskL = fpath+'/{subject_id}/Left_Corticospinal.nii.gz',
#                 cst_maskR = fpath+'/{subject_id}/Right_Corticospinal.nii.gz',
                ccmaj_mask = fpath+'/{subject_id}/Callosum_Forceps_Major.nii.gz',
                ccmin_mask = fpath+'/{subject_id}/Callosum_Forceps_Minor.nii.gz')

# 
#             bval=fpath+'/{subject_id}/dti.bval',
#             bvec=fpath+'/{subject_id}/dti.bvec'

sf2 = Node(SelectFiles(template2, 
                      base_directory = fpath),
          name = 'sf2')

# %%
get_stats=Workflow(name='get_stats')
get_stats.connect([(infosource, sf2, [('subject_id','subject_id')]),
                   #Left UF
                   (sf2, get_voxLUF, [('qt1r', 'in_file')]),
                   (sf2, get_voxLUF, [('unc_maskL', 'mask')]),
                   (get_voxLUF, datasink, [('out_file', '2_Extracted_Stats')]),
                   #Left Cingulum
                   (sf2, get_voxLCC, [('qt1r', 'in_file')]),
                   (sf2, get_voxLCC, [('cc_maskL', 'mask')]),
                   (get_voxLCC, datasink, [('out_file', '2_Extracted_Stats.@par')]),
#                    #Left Corticospinal
#                    (sf2, get_voxLCST, [('qt1r', 'in_file')]),
#                    (sf2, get_voxLCST, [('cst_maskL', 'mask')]),
#                    (get_voxLCST, datasink, [('out_file', '2_Extracted_Stats.@par.@par')]),
                   #Right UF
                   (sf2, get_voxRUF, [('qt1r', 'in_file')]),
                   (sf2, get_voxRUF, [('unc_maskR', 'mask')]),
                   (get_voxRUF, datasink, [('out_file', '2_Extracted_Stats.@par.@par.@par')]),
                   #Right Cingulum
                   (sf2, get_voxRCC, [('qt1r', 'in_file')]),
                   (sf2, get_voxRCC, [('cc_maskR', 'mask')]),
                   (get_voxRCC, datasink, [('out_file', '2_Extracted_Stats.@par.@par.@par.@par')]),
#                    #Right Corticospinal
#                    (sf2, get_voxRCST, [('qt1r', 'in_file')]),
#                    (sf2, get_voxRCST, [('cst_maskR', 'mask')]),
#                    (get_voxRCST, datasink, [('out_file', '2_Extracted_Stats.@par.@par.@par.@par.@par')]),
                   #CC Major
                   (sf2, get_voxCCMaj, [('qt1r', 'in_file')]),
                   (sf2, get_voxCCMaj, [('ccmaj_mask', 'mask')]),
                   (get_voxCCMaj, datasink, [('out_file', '2_Extracted_Stats.@par.@par.@par.@par.@par.@par')]),
                   #CC Minor
                   (sf2, get_voxCCMin, [('qt1r', 'in_file')]),
                   (sf2, get_voxCCMin, [('ccmin_mask', 'mask')]),
                   (get_voxCCMin, datasink, [('out_file', '2_Extracted_Stats.@par.@par.@par.@par.@par.@par.@par')]),
                   (sf2, get_globalR1, [('qt1r', 'in_file')]),
                   (get_globalR1, datasink, [('out_file', '2_Extracted_Stats.@par.@par.@par.@par.@par.@par.@par.@par')])
                  ])
get_stats.base_dir = workflow_dir
get_stats.write_graph(graph2use = 'flat')
preproc = get_stats.run('MultiProc', plugin_args={'n_procs': 4})
# Out:
# 210307-22:32:05,779 nipype.workflow DEBUG:
# 	 (get_stats.infosource, get_stats.sf2): No edge data
# 210307-22:32:05,780 nipype.workflow DEBUG:
# 	 (get_stats.infosource, get_stats.sf2): new edge data: {'connect': [('subject_id', 'subject_id')]}
# 210307-22:32:05,781 nipype.workflow DEBUG:
# 	 (get_stats.sf2, get_stats.get_globalR1): No edge data
# 210307-22:32:05,782 nipype.workflow DEBUG:
# 	 (get_stats.sf2, get_stats.get_globalR1): new edge data: {'connect': [('qt1r', 'in_file')]}
# 210307-22:32:05,782 nipype.workflow DEBUG:
# 	 (get_stats.get_globalR1, get_stats.datasink): No edge data
# 210307-22:32:05,783 nipype.workflow DEBUG:
# 	 (get_stats.get_globalR1, get_stats.datasink): new edge data: {'connect': [('out_stat', '2_Extracted_Stats.@par.@par.@par.@par.@par.@par.@par.@par')]}
# 210307-22:32:05,785 nipype.workflow DEBUG:
# 	 Creating flat graph for workflow: get_stats
# 210307-22:32:05,788 nipype.workflow DEBUG:
# 	 expanding workflow: get_stats
# 210307-22:32:05,789 nipype.workflow DEBUG:
# 	 processing node: get_stats.infosource
# 210307-22:32:05,790 nipype.workflow DEBUG:
# 	 processing node: get_stats.sf2
# 210307-22:32:05,791 nipype.workflow DEBUG:
# 	 processing node: get_stats.get_globalR1
# 210307-22:32:05,791 nipype.workflow DEBUG:
# 	 processing node: get_stats.datasink
# 210307-22:32:05,792 nipype.workflow DEBUG:
# 	 finished expanding workflow: get_stats
# 210307-22:32:05,795 nipype.workflow DEBUG:
# 	 using input graph
# 210307-22:32:06,110 nipype.workflow DEBUG:
# 	 creating dot graph
# 210307-22:32:06,394 nipype.workflow INFO:
# 	 Generated workflow graph: /Users/lucindasisk/Documents/qT1_10.2020Analysis/workflow_globalR1/get_stats/graph.png (graph2use=flat, simple_form=True).
# 210307-22:32:06,405 nipype.workflow DEBUG:
# 	 [MultiProc] Starting (n_procs=4, mem_gb=28.80, cwd=/Users/lucindasisk/Dropbox/Github/TIGER_qT1_Tracts)
# 210307-22:32:06,407 nipype.workflow DEBUG:
# 	 Creating flat graph for workflow: get_stats
# 210307-22:32:06,411 nipype.workflow DEBUG:
# 	 expanding workflow: get_stats
# 210307-22:32:06,412 nipype.workflow DEBUG:
# 	 processing node: get_stats.infosource
# 210307-22:32:06,413 nipype.workflow DEBUG:
# 	 processing node: get_stats.sf2
# 210307-22:32:06,414 nipype.workflow DEBUG:
# 	 processing node: get_stats.get_globalR1
# 210307-22:32:06,415 nipype.workflow DEBUG:
# 	 processing node: get_stats.datasink
# 210307-22:32:06,416 nipype.workflow DEBUG:
# 	 finished expanding workflow: get_stats
# 210307-22:32:06,416 nipype.workflow INFO:
# 	 Workflow get_stats settings: ['check', 'execution', 'logging', 'monitoring']
# 210307-22:32:06,419 nipype.workflow DEBUG:
# 	 PE: expanding iterables
# 210307-22:32:06,420 nipype.workflow DEBUG:
# 	 Detected iterable nodes [get_stats.infosource]
# 210307-22:32:06,421 nipype.workflow DEBUG:
# 	 Expanding the iterable node get_stats.infosource...
# 210307-22:32:06,422 nipype.workflow DEBUG:
# 	 node: get_stats.infosource iterables: {'subject_id': <function _standardize_iterables.<locals>.make_field_func.<locals>.<lambda> at 0x7f977893d320>}
# 210307-22:32:06,422 nipype.workflow DEBUG:
# 	 ('subnodes:', [get_stats.infosource, get_stats.sf2, get_stats.get_globalR1, get_stats.datasink])
# 210307-22:32:06,426 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input subject_id = 02-T2
# 210307-22:32:06,427 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_subject_id_02-T2
# 210307-22:32:06,430 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input subject_id = 021-T3
# 210307-22:32:06,431 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_subject_id_021-T3
# 210307-22:32:06,434 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input subject_id = 06-T1
# 210307-22:32:06,435 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_subject_id_06-T1
# 210307-22:32:06,438 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input subject_id = 066-T3
# 210307-22:32:06,439 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_subject_id_066-T3
# 210307-22:32:06,442 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input subject_id = 07-T2
# 210307-22:32:06,442 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_subject_id_07-T2
# 210307-22:32:06,446 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input subject_id = 072-T4
# 210307-22:32:06,447 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_subject_id_072-T4
# 210307-22:32:06,449 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input subject_id = 08-T1
# 210307-22:32:06,450 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_subject_id_08-T1
# 210307-22:32:06,453 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input subject_id = 09-T2
# 210307-22:32:06,454 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_subject_id_09-T2
# 210307-22:32:06,457 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input subject_id = 097-T3
# 210307-22:32:06,457 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_subject_id_097-T3
# 210307-22:32:06,460 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input subject_id = 10-T1
# 210307-22:32:06,461 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_subject_id_10-T1
# 210307-22:32:06,464 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input subject_id = 103-T1
# 210307-22:32:06,464 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_subject_id_103-T1
# 210307-22:32:06,467 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input subject_id = 104-T1
# 210307-22:32:06,467 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_subject_id_104-T1
# 210307-22:32:06,470 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input subject_id = 105-T1
# 210307-22:32:06,471 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_subject_id_105-T1
# 210307-22:32:06,474 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input subject_id = 106-T1
# 210307-22:32:06,475 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_subject_id_106-T1
# 210307-22:32:06,477 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input subject_id = 107-T1
# 210307-22:32:06,478 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_subject_id_107-T1
# 210307-22:32:06,481 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input subject_id = 108-T1
# 210307-22:32:06,482 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_subject_id_108-T1
# 210307-22:32:06,484 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input subject_id = 109-T1
# 210307-22:32:06,485 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_subject_id_109-T1
# 210307-22:32:06,488 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input subject_id = 109-T3
# 210307-22:32:06,488 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_subject_id_109-T3
# 210307-22:32:06,491 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input subject_id = 11-T1
# 210307-22:32:06,492 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_subject_id_11-T1
# 210307-22:32:06,495 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input subject_id = 110-T1
# 210307-22:32:06,496 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_subject_id_110-T1
# 210307-22:32:06,499 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input subject_id = 111-T1
# 210307-22:32:06,500 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_subject_id_111-T1
# 210307-22:32:06,502 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input subject_id = 112-T1
# 210307-22:32:06,503 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_subject_id_112-T1
# 210307-22:32:06,505 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input subject_id = 112-T4
# 210307-22:32:06,506 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_subject_id_112-T4
# 210307-22:32:06,509 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input subject_id = 113-T1
# 210307-22:32:06,509 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_subject_id_113-T1
# 210307-22:32:06,512 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input subject_id = 114-T1
# 210307-22:32:06,513 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_subject_id_114-T1
# 210307-22:32:06,516 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input subject_id = 115-T1
# 210307-22:32:06,517 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_subject_id_115-T1
# 210307-22:32:06,519 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input subject_id = 116-T1
# 210307-22:32:06,520 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_subject_id_116-T1
# 210307-22:32:06,523 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input subject_id = 118-T1
# 210307-22:32:06,523 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_subject_id_118-T1
# 210307-22:32:06,526 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input subject_id = 119-T1
# 210307-22:32:06,527 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_subject_id_119-T1
# 210307-22:32:06,531 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input subject_id = 12-T1
# 210307-22:32:06,532 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_subject_id_12-T1
# 210307-22:32:06,534 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input subject_id = 120-T1
# 210307-22:32:06,535 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_subject_id_120-T1
# 210307-22:32:06,537 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input subject_id = 123-T1
# 210307-22:32:06,538 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_subject_id_123-T1
# 210307-22:32:06,540 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input subject_id = 124-T1
# 210307-22:32:06,541 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_subject_id_124-T1
# 210307-22:32:06,544 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input subject_id = 124-T3
# 210307-22:32:06,545 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_subject_id_124-T3
# 210307-22:32:06,547 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input subject_id = 130-T3
# 210307-22:32:06,548 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_subject_id_130-T3
# 210307-22:32:06,551 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input subject_id = 145-T3
# 210307-22:32:06,551 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_subject_id_145-T3
# 210307-22:32:06,554 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input subject_id = 147-T3
# 210307-22:32:06,555 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_subject_id_147-T3
# 210307-22:32:06,558 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input subject_id = 15-T1
# 210307-22:32:06,558 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_subject_id_15-T1
# 210307-22:32:06,561 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input subject_id = 16-T1
# 210307-22:32:06,562 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_subject_id_16-T1
# 210307-22:32:06,564 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input subject_id = 164-T3
# 210307-22:32:06,565 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_subject_id_164-T3
# 210307-22:32:06,567 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input subject_id = 168-T3
# 210307-22:32:06,568 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_subject_id_168-T3
# 210307-22:32:06,571 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input subject_id = 17-T1
# 210307-22:32:06,571 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_subject_id_17-T1
# 210307-22:32:06,574 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input subject_id = 170-T3
# 210307-22:32:06,575 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_subject_id_170-T3
# 210307-22:32:06,577 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input subject_id = 171-T3
# 210307-22:32:06,578 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_subject_id_171-T3
# 210307-22:32:06,581 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input subject_id = 176-T3
# 210307-22:32:06,581 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_subject_id_176-T3
# 210307-22:32:06,584 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input subject_id = 178-T3
# 210307-22:32:06,584 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_subject_id_178-T3
# 210307-22:32:06,586 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input subject_id = 18-T1
# 210307-22:32:06,587 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_subject_id_18-T1
# 210307-22:32:06,589 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input subject_id = 186-T3
# 210307-22:32:06,590 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_subject_id_186-T3
# 210307-22:32:06,592 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input subject_id = 188-T3
# 210307-22:32:06,593 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_subject_id_188-T3
# 210307-22:32:06,595 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input subject_id = 19-T1
# 210307-22:32:06,596 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_subject_id_19-T1
# 210307-22:32:06,598 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input subject_id = 191-T3
# 210307-22:32:06,599 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_subject_id_191-T3
# 210307-22:32:06,601 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input subject_id = 20-T1
# 210307-22:32:06,602 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_subject_id_20-T1
# 210307-22:32:06,604 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input subject_id = 202-T3
# 210307-22:32:06,605 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_subject_id_202-T3
# 210307-22:32:06,607 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input subject_id = 21-T1
# 210307-22:32:06,607 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_subject_id_21-T1
# 210307-22:32:06,610 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input subject_id = 215-T3
# 210307-22:32:06,610 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_subject_id_215-T3
# 210307-22:32:06,613 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input subject_id = 22-T1
# 210307-22:32:06,613 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_subject_id_22-T1
# 210307-22:32:06,615 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input subject_id = 23-T1
# 210307-22:32:06,616 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_subject_id_23-T1
# 210307-22:32:06,618 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input subject_id = 24-T1
# 210307-22:32:06,619 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_subject_id_24-T1
# 210307-22:32:06,622 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input subject_id = 25-T1
# 210307-22:32:06,623 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_subject_id_25-T1
# 210307-22:32:06,625 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input subject_id = 28-T2
# 210307-22:32:06,625 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_subject_id_28-T2
# 210307-22:32:06,629 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input subject_id = 29-T1
# 210307-22:32:06,629 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_subject_id_29-T1
# 210307-22:32:06,632 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input subject_id = 30-T1
# 210307-22:32:06,632 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_subject_id_30-T1
# 210307-22:32:06,635 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input subject_id = 31-T1
# 210307-22:32:06,635 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_subject_id_31-T1
# 210307-22:32:06,637 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input subject_id = 32-T1
# 210307-22:32:06,638 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_subject_id_32-T1
# 210307-22:32:06,640 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input subject_id = 35-T1
# 210307-22:32:06,641 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_subject_id_35-T1
# 210307-22:32:06,643 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input subject_id = 36-T1
# 210307-22:32:06,644 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_subject_id_36-T1
# 210307-22:32:06,646 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input subject_id = 38-T1
# 210307-22:32:06,647 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_subject_id_38-T1
# 210307-22:32:06,650 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input subject_id = 39-T1
# 210307-22:32:06,650 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_subject_id_39-T1
# 210307-22:32:06,653 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input subject_id = 40-T1
# 210307-22:32:06,653 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_subject_id_40-T1
# 210307-22:32:06,656 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input subject_id = 41-T1
# 210307-22:32:06,656 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_subject_id_41-T1
# 210307-22:32:06,659 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input subject_id = 43-T1
# 210307-22:32:06,660 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_subject_id_43-T1
# 210307-22:32:06,662 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input subject_id = 44-T1
# 210307-22:32:06,663 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_subject_id_44-T1
# 210307-22:32:06,665 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input subject_id = 45-T1
# 210307-22:32:06,666 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_subject_id_45-T1
# 210307-22:32:06,669 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input subject_id = 46-T1
# 210307-22:32:06,669 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_subject_id_46-T1
# 210307-22:32:06,671 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input subject_id = 48-T1
# 210307-22:32:06,672 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_subject_id_48-T1
# 210307-22:32:06,674 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input subject_id = 49-T1
# 210307-22:32:06,675 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_subject_id_49-T1
# 210307-22:32:06,677 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input subject_id = 50-T1
# 210307-22:32:06,678 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_subject_id_50-T1
# 210307-22:32:06,680 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input subject_id = 51-T1
# 210307-22:32:06,681 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_subject_id_51-T1
# 210307-22:32:06,683 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input subject_id = 52-T1
# 210307-22:32:06,684 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_subject_id_52-T1
# 210307-22:32:06,686 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input subject_id = 53-T1
# 210307-22:32:06,687 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_subject_id_53-T1
# 210307-22:32:06,689 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input subject_id = 54-T1
# 210307-22:32:06,690 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_subject_id_54-T1
# 210307-22:32:06,692 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input subject_id = 55-T1
# 210307-22:32:06,693 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_subject_id_55-T1
# 210307-22:32:06,696 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input subject_id = 56-T1
# 210307-22:32:06,696 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_subject_id_56-T1
# 210307-22:32:06,699 nipype.workflow DEBUG:
# 	 PE: expanding iterables ... done
# 210307-22:32:06,702 nipype.workflow DEBUG:
# 	 [Node] sf2 - setting input subject_id = 56-T1
# 210307-22:32:06,702 nipype.workflow DEBUG:
# 	 Removed the identity node get_stats.infosource from the graph.
# 210307-22:32:06,703 nipype.workflow DEBUG:
# 	 [Node] sf2 - setting input subject_id = 55-T1
# 210307-22:32:06,703 nipype.workflow DEBUG:
# 	 Removed the identity node get_stats.infosource from the graph.
# 210307-22:32:06,704 nipype.workflow DEBUG:
# 	 [Node] sf2 - setting input subject_id = 54-T1
# 210307-22:32:06,704 nipype.workflow DEBUG:
# 	 Removed the identity node get_stats.infosource from the graph.
# 210307-22:32:06,705 nipype.workflow DEBUG:
# 	 [Node] sf2 - setting input subject_id = 53-T1
# 210307-22:32:06,705 nipype.workflow DEBUG:
# 	 Removed the identity node get_stats.infosource from the graph.
# 210307-22:32:06,706 nipype.workflow DEBUG:
# 	 [Node] sf2 - setting input subject_id = 52-T1
# 210307-22:32:06,706 nipype.workflow DEBUG:
# 	 Removed the identity node get_stats.infosource from the graph.
# 210307-22:32:06,707 nipype.workflow DEBUG:
# 	 [Node] sf2 - setting input subject_id = 51-T1
# 210307-22:32:06,707 nipype.workflow DEBUG:
# 	 Removed the identity node get_stats.infosource from the graph.
# 210307-22:32:06,707 nipype.workflow DEBUG:
# 	 [Node] sf2 - setting input subject_id = 50-T1
# 210307-22:32:06,708 nipype.workflow DEBUG:
# 	 Removed the identity node get_stats.infosource from the graph.
# 210307-22:32:06,708 nipype.workflow DEBUG:
# 	 [Node] sf2 - setting input subject_id = 49-T1
# 210307-22:32:06,709 nipype.workflow DEBUG:
# 	 Removed the identity node get_stats.infosource from the graph.
# 210307-22:32:06,709 nipype.workflow DEBUG:
# 	 [Node] sf2 - setting input subject_id = 48-T1
# 210307-22:32:06,710 nipype.workflow DEBUG:
# 	 Removed the identity node get_stats.infosource from the graph.
# 210307-22:32:06,710 nipype.workflow DEBUG:
# 	 [Node] sf2 - setting input subject_id = 46-T1
# 210307-22:32:06,711 nipype.workflow DEBUG:
# 	 Removed the identity node get_stats.infosource from the graph.
# 210307-22:32:06,711 nipype.workflow DEBUG:
# 	 [Node] sf2 - setting input subject_id = 45-T1
# 210307-22:32:06,712 nipype.workflow DEBUG:
# 	 Removed the identity node get_stats.infosource from the graph.
# 210307-22:32:06,712 nipype.workflow DEBUG:
# 	 [Node] sf2 - setting input subject_id = 44-T1
# 210307-22:32:06,712 nipype.workflow DEBUG:
# 	 Removed the identity node get_stats.infosource from the graph.
# 210307-22:32:06,713 nipype.workflow DEBUG:
# 	 [Node] sf2 - setting input subject_id = 43-T1
# 210307-22:32:06,713 nipype.workflow DEBUG:
# 	 Removed the identity node get_stats.infosource from the graph.
# 210307-22:32:06,714 nipype.workflow DEBUG:
# 	 [Node] sf2 - setting input subject_id = 41-T1
# 210307-22:32:06,714 nipype.workflow DEBUG:
# 	 Removed the identity node get_stats.infosource from the graph.
# 210307-22:32:06,715 nipype.workflow DEBUG:
# 	 [Node] sf2 - setting input subject_id = 40-T1
# 210307-22:32:06,716 nipype.workflow DEBUG:
# 	 Removed the identity node get_stats.infosource from the graph.
# 210307-22:32:06,716 nipype.workflow DEBUG:
# 	 [Node] sf2 - setting input subject_id = 39-T1
# 210307-22:32:06,717 nipype.workflow DEBUG:
# 	 Removed the identity node get_stats.infosource from the graph.
# 210307-22:32:06,717 nipype.workflow DEBUG:
# 	 [Node] sf2 - setting input subject_id = 38-T1
# 210307-22:32:06,718 nipype.workflow DEBUG:
# 	 Removed the identity node get_stats.infosource from the graph.
# 210307-22:32:06,718 nipype.workflow DEBUG:
# 	 [Node] sf2 - setting input subject_id = 36-T1
# 210307-22:32:06,719 nipype.workflow DEBUG:
# 	 Removed the identity node get_stats.infosource from the graph.
# 210307-22:32:06,719 nipype.workflow DEBUG:
# 	 [Node] sf2 - setting input subject_id = 35-T1
# 210307-22:32:06,720 nipype.workflow DEBUG:
# 	 Removed the identity node get_stats.infosource from the graph.
# 210307-22:32:06,720 nipype.workflow DEBUG:
# 	 [Node] sf2 - setting input subject_id = 32-T1
# 210307-22:32:06,721 nipype.workflow DEBUG:
# 	 Removed the identity node get_stats.infosource from the graph.
# 210307-22:32:06,721 nipype.workflow DEBUG:
# 	 [Node] sf2 - setting input subject_id = 31-T1
# 210307-22:32:06,721 nipype.workflow DEBUG:
# 	 Removed the identity node get_stats.infosource from the graph.
# 210307-22:32:06,722 nipype.workflow DEBUG:
# 	 [Node] sf2 - setting input subject_id = 30-T1
# 210307-22:32:06,722 nipype.workflow DEBUG:
# 	 Removed the identity node get_stats.infosource from the graph.
# 210307-22:32:06,723 nipype.workflow DEBUG:
# 	 [Node] sf2 - setting input subject_id = 29-T1
# 210307-22:32:06,723 nipype.workflow DEBUG:
# 	 Removed the identity node get_stats.infosource from the graph.
# 210307-22:32:06,723 nipype.workflow DEBUG:
# 	 [Node] sf2 - setting input subject_id = 28-T2
# 210307-22:32:06,724 nipype.workflow DEBUG:
# 	 Removed the identity node get_stats.infosource from the graph.
# 210307-22:32:06,724 nipype.workflow DEBUG:
# 	 [Node] sf2 - setting input subject_id = 25-T1
# 210307-22:32:06,725 nipype.workflow DEBUG:
# 	 Removed the identity node get_stats.infosource from the graph.
# 210307-22:32:06,725 nipype.workflow DEBUG:
# 	 [Node] sf2 - setting input subject_id = 24-T1
# 210307-22:32:06,726 nipype.workflow DEBUG:
# 	 Removed the identity node get_stats.infosource from the graph.
# 210307-22:32:06,726 nipype.workflow DEBUG:
# 	 [Node] sf2 - setting input subject_id = 23-T1
# 210307-22:32:06,727 nipype.workflow DEBUG:
# 	 Removed the identity node get_stats.infosource from the graph.
# 210307-22:32:06,727 nipype.workflow DEBUG:
# 	 [Node] sf2 - setting input subject_id = 22-T1
# 210307-22:32:06,728 nipype.workflow DEBUG:
# 	 Removed the identity node get_stats.infosource from the graph.
# 210307-22:32:06,728 nipype.workflow DEBUG:
# 	 [Node] sf2 - setting input subject_id = 215-T3
# 210307-22:32:06,729 nipype.workflow DEBUG:
# 	 Removed the identity node get_stats.infosource from the graph.
# 210307-22:32:06,729 nipype.workflow DEBUG:
# 	 [Node] sf2 - setting input subject_id = 21-T1
# 210307-22:32:06,729 nipype.workflow DEBUG:
# 	 Removed the identity node get_stats.infosource from the graph.
# 210307-22:32:06,730 nipype.workflow DEBUG:
# 	 [Node] sf2 - setting input subject_id = 202-T3
# 210307-22:32:06,730 nipype.workflow DEBUG:
# 	 Removed the identity node get_stats.infosource from the graph.
# 210307-22:32:06,730 nipype.workflow DEBUG:
# 	 [Node] sf2 - setting input subject_id = 20-T1
# 210307-22:32:06,731 nipype.workflow DEBUG:
# 	 Removed the identity node get_stats.infosource from the graph.
# 210307-22:32:06,731 nipype.workflow DEBUG:
# 	 [Node] sf2 - setting input subject_id = 191-T3
# 210307-22:32:06,732 nipype.workflow DEBUG:
# 	 Removed the identity node get_stats.infosource from the graph.
# 210307-22:32:06,732 nipype.workflow DEBUG:
# 	 [Node] sf2 - setting input subject_id = 19-T1
# 210307-22:32:06,732 nipype.workflow DEBUG:
# 	 Removed the identity node get_stats.infosource from the graph.
# 210307-22:32:06,733 nipype.workflow DEBUG:
# 	 [Node] sf2 - setting input subject_id = 188-T3
# 210307-22:32:06,733 nipype.workflow DEBUG:
# 	 Removed the identity node get_stats.infosource from the graph.
# 210307-22:32:06,734 nipype.workflow DEBUG:
# 	 [Node] sf2 - setting input subject_id = 186-T3
# 210307-22:32:06,734 nipype.workflow DEBUG:
# 	 Removed the identity node get_stats.infosource from the graph.
# 210307-22:32:06,734 nipype.workflow DEBUG:
# 	 [Node] sf2 - setting input subject_id = 18-T1
# 210307-22:32:06,735 nipype.workflow DEBUG:
# 	 Removed the identity node get_stats.infosource from the graph.
# 210307-22:32:06,735 nipype.workflow DEBUG:
# 	 [Node] sf2 - setting input subject_id = 178-T3
# 210307-22:32:06,735 nipype.workflow DEBUG:
# 	 Removed the identity node get_stats.infosource from the graph.
# 210307-22:32:06,736 nipype.workflow DEBUG:
# 	 [Node] sf2 - setting input subject_id = 176-T3
# 210307-22:32:06,736 nipype.workflow DEBUG:
# 	 Removed the identity node get_stats.infosource from the graph.
# 210307-22:32:06,737 nipype.workflow DEBUG:
# 	 [Node] sf2 - setting input subject_id = 171-T3
# 210307-22:32:06,737 nipype.workflow DEBUG:
# 	 Removed the identity node get_stats.infosource from the graph.
# 210307-22:32:06,737 nipype.workflow DEBUG:
# 	 [Node] sf2 - setting input subject_id = 170-T3
# 210307-22:32:06,738 nipype.workflow DEBUG:
# 	 Removed the identity node get_stats.infosource from the graph.
# 210307-22:32:06,738 nipype.workflow DEBUG:
# 	 [Node] sf2 - setting input subject_id = 17-T1
# 210307-22:32:06,739 nipype.workflow DEBUG:
# 	 Removed the identity node get_stats.infosource from the graph.
# 210307-22:32:06,739 nipype.workflow DEBUG:
# 	 [Node] sf2 - setting input subject_id = 168-T3
# 210307-22:32:06,739 nipype.workflow DEBUG:
# 	 Removed the identity node get_stats.infosource from the graph.
# 210307-22:32:06,740 nipype.workflow DEBUG:
# 	 [Node] sf2 - setting input subject_id = 164-T3
# 210307-22:32:06,740 nipype.workflow DEBUG:
# 	 Removed the identity node get_stats.infosource from the graph.
# 210307-22:32:06,741 nipype.workflow DEBUG:
# 	 [Node] sf2 - setting input subject_id = 16-T1
# 210307-22:32:06,741 nipype.workflow DEBUG:
# 	 Removed the identity node get_stats.infosource from the graph.
# 210307-22:32:06,741 nipype.workflow DEBUG:
# 	 [Node] sf2 - setting input subject_id = 15-T1
# 210307-22:32:06,742 nipype.workflow DEBUG:
# 	 Removed the identity node get_stats.infosource from the graph.
# 210307-22:32:06,742 nipype.workflow DEBUG:
# 	 [Node] sf2 - setting input subject_id = 147-T3
# 210307-22:32:06,743 nipype.workflow DEBUG:
# 	 Removed the identity node get_stats.infosource from the graph.
# 210307-22:32:06,743 nipype.workflow DEBUG:
# 	 [Node] sf2 - setting input subject_id = 145-T3
# 210307-22:32:06,743 nipype.workflow DEBUG:
# 	 Removed the identity node get_stats.infosource from the graph.
# 210307-22:32:06,744 nipype.workflow DEBUG:
# 	 [Node] sf2 - setting input subject_id = 130-T3
# 210307-22:32:06,744 nipype.workflow DEBUG:
# 	 Removed the identity node get_stats.infosource from the graph.
# 210307-22:32:06,745 nipype.workflow DEBUG:
# 	 [Node] sf2 - setting input subject_id = 124-T3
# 210307-22:32:06,745 nipype.workflow DEBUG:
# 	 Removed the identity node get_stats.infosource from the graph.
# 210307-22:32:06,745 nipype.workflow DEBUG:
# 	 [Node] sf2 - setting input subject_id = 124-T1
# 210307-22:32:06,746 nipype.workflow DEBUG:
# 	 Removed the identity node get_stats.infosource from the graph.
# 210307-22:32:06,746 nipype.workflow DEBUG:
# 	 [Node] sf2 - setting input subject_id = 123-T1
# 210307-22:32:06,746 nipype.workflow DEBUG:
# 	 Removed the identity node get_stats.infosource from the graph.
# 210307-22:32:06,747 nipype.workflow DEBUG:
# 	 [Node] sf2 - setting input subject_id = 120-T1
# 210307-22:32:06,748 nipype.workflow DEBUG:
# 	 Removed the identity node get_stats.infosource from the graph.
# 210307-22:32:06,748 nipype.workflow DEBUG:
# 	 [Node] sf2 - setting input subject_id = 12-T1
# 210307-22:32:06,749 nipype.workflow DEBUG:
# 	 Removed the identity node get_stats.infosource from the graph.
# 210307-22:32:06,749 nipype.workflow DEBUG:
# 	 [Node] sf2 - setting input subject_id = 119-T1
# 210307-22:32:06,749 nipype.workflow DEBUG:
# 	 Removed the identity node get_stats.infosource from the graph.
# 210307-22:32:06,750 nipype.workflow DEBUG:
# 	 [Node] sf2 - setting input subject_id = 118-T1
# 210307-22:32:06,751 nipype.workflow DEBUG:
# 	 Removed the identity node get_stats.infosource from the graph.
# 210307-22:32:06,751 nipype.workflow DEBUG:
# 	 [Node] sf2 - setting input subject_id = 116-T1
# 210307-22:32:06,751 nipype.workflow DEBUG:
# 	 Removed the identity node get_stats.infosource from the graph.
# 210307-22:32:06,752 nipype.workflow DEBUG:
# 	 [Node] sf2 - setting input subject_id = 115-T1
# 210307-22:32:06,752 nipype.workflow DEBUG:
# 	 Removed the identity node get_stats.infosource from the graph.
# 210307-22:32:06,753 nipype.workflow DEBUG:
# 	 [Node] sf2 - setting input subject_id = 114-T1
# 210307-22:32:06,753 nipype.workflow DEBUG:
# 	 Removed the identity node get_stats.infosource from the graph.
# 210307-22:32:06,754 nipype.workflow DEBUG:
# 	 [Node] sf2 - setting input subject_id = 113-T1
# 210307-22:32:06,754 nipype.workflow DEBUG:
# 	 Removed the identity node get_stats.infosource from the graph.
# 210307-22:32:06,755 nipype.workflow DEBUG:
# 	 [Node] sf2 - setting input subject_id = 112-T4
# 210307-22:32:06,755 nipype.workflow DEBUG:
# 	 Removed the identity node get_stats.infosource from the graph.
# 210307-22:32:06,756 nipype.workflow DEBUG:
# 	 [Node] sf2 - setting input subject_id = 112-T1
# 210307-22:32:06,756 nipype.workflow DEBUG:
# 	 Removed the identity node get_stats.infosource from the graph.
# 210307-22:32:06,756 nipype.workflow DEBUG:
# 	 [Node] sf2 - setting input subject_id = 111-T1
# 210307-22:32:06,757 nipype.workflow DEBUG:
# 	 Removed the identity node get_stats.infosource from the graph.
# 210307-22:32:06,757 nipype.workflow DEBUG:
# 	 [Node] sf2 - setting input subject_id = 110-T1
# 210307-22:32:06,758 nipype.workflow DEBUG:
# 	 Removed the identity node get_stats.infosource from the graph.
# 210307-22:32:06,758 nipype.workflow DEBUG:
# 	 [Node] sf2 - setting input subject_id = 11-T1
# 210307-22:32:06,758 nipype.workflow DEBUG:
# 	 Removed the identity node get_stats.infosource from the graph.
# 210307-22:32:06,759 nipype.workflow DEBUG:
# 	 [Node] sf2 - setting input subject_id = 109-T3
# 210307-22:32:06,759 nipype.workflow DEBUG:
# 	 Removed the identity node get_stats.infosource from the graph.
# 210307-22:32:06,759 nipype.workflow DEBUG:
# 	 [Node] sf2 - setting input subject_id = 109-T1
# 210307-22:32:06,760 nipype.workflow DEBUG:
# 	 Removed the identity node get_stats.infosource from the graph.
# 210307-22:32:06,760 nipype.workflow DEBUG:
# 	 [Node] sf2 - setting input subject_id = 108-T1
# 210307-22:32:06,761 nipype.workflow DEBUG:
# 	 Removed the identity node get_stats.infosource from the graph.
# 210307-22:32:06,761 nipype.workflow DEBUG:
# 	 [Node] sf2 - setting input subject_id = 107-T1
# 210307-22:32:06,761 nipype.workflow DEBUG:
# 	 Removed the identity node get_stats.infosource from the graph.
# 210307-22:32:06,762 nipype.workflow DEBUG:
# 	 [Node] sf2 - setting input subject_id = 106-T1
# 210307-22:32:06,762 nipype.workflow DEBUG:
# 	 Removed the identity node get_stats.infosource from the graph.
# 210307-22:32:06,763 nipype.workflow DEBUG:
# 	 [Node] sf2 - setting input subject_id = 105-T1
# 210307-22:32:06,763 nipype.workflow DEBUG:
# 	 Removed the identity node get_stats.infosource from the graph.
# 210307-22:32:06,764 nipype.workflow DEBUG:
# 	 [Node] sf2 - setting input subject_id = 104-T1
# 210307-22:32:06,764 nipype.workflow DEBUG:
# 	 Removed the identity node get_stats.infosource from the graph.
# 210307-22:32:06,764 nipype.workflow DEBUG:
# 	 [Node] sf2 - setting input subject_id = 103-T1
# 210307-22:32:06,765 nipype.workflow DEBUG:
# 	 Removed the identity node get_stats.infosource from the graph.
# 210307-22:32:06,765 nipype.workflow DEBUG:
# 	 [Node] sf2 - setting input subject_id = 10-T1
# 210307-22:32:06,765 nipype.workflow DEBUG:
# 	 Removed the identity node get_stats.infosource from the graph.
# 210307-22:32:06,766 nipype.workflow DEBUG:
# 	 [Node] sf2 - setting input subject_id = 097-T3
# 210307-22:32:06,766 nipype.workflow DEBUG:
# 	 Removed the identity node get_stats.infosource from the graph.
# 210307-22:32:06,766 nipype.workflow DEBUG:
# 	 [Node] sf2 - setting input subject_id = 09-T2
# 210307-22:32:06,767 nipype.workflow DEBUG:
# 	 Removed the identity node get_stats.infosource from the graph.
# 210307-22:32:06,767 nipype.workflow DEBUG:
# 	 [Node] sf2 - setting input subject_id = 08-T1
# 210307-22:32:06,768 nipype.workflow DEBUG:
# 	 Removed the identity node get_stats.infosource from the graph.
# 210307-22:32:06,768 nipype.workflow DEBUG:
# 	 [Node] sf2 - setting input subject_id = 072-T4
# 210307-22:32:06,768 nipype.workflow DEBUG:
# 	 Removed the identity node get_stats.infosource from the graph.
# 210307-22:32:06,769 nipype.workflow DEBUG:
# 	 [Node] sf2 - setting input subject_id = 07-T2
# 210307-22:32:06,769 nipype.workflow DEBUG:
# 	 Removed the identity node get_stats.infosource from the graph.
# 210307-22:32:06,769 nipype.workflow DEBUG:
# 	 [Node] sf2 - setting input subject_id = 066-T3
# 210307-22:32:06,770 nipype.workflow DEBUG:
# 	 Removed the identity node get_stats.infosource from the graph.
# 210307-22:32:06,770 nipype.workflow DEBUG:
# 	 [Node] sf2 - setting input subject_id = 06-T1
# 210307-22:32:06,770 nipype.workflow DEBUG:
# 	 Removed the identity node get_stats.infosource from the graph.
# 210307-22:32:06,771 nipype.workflow DEBUG:
# 	 [Node] sf2 - setting input subject_id = 021-T3
# 210307-22:32:06,771 nipype.workflow DEBUG:
# 	 Removed the identity node get_stats.infosource from the graph.
# 210307-22:32:06,772 nipype.workflow DEBUG:
# 	 [Node] sf2 - setting input subject_id = 02-T2
# 210307-22:32:06,772 nipype.workflow DEBUG:
# 	 Removed the identity node get_stats.infosource from the graph.
# 210307-22:32:06,856 nipype.workflow DEBUG:
# 	 Performing depth first search
# 210307-22:32:06,921 nipype.workflow INFO:
# 	 Running in parallel.
# 210307-22:32:06,927 nipype.workflow DEBUG:
# 	 Progress: 249 jobs, 0/0/83 (done/running/ready), 0/249 (pending_tasks/waiting).
# 210307-22:32:06,928 nipype.workflow DEBUG:
# 	 Tasks currently running: 0. Pending: 0.
# 210307-22:32:06,929 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 83 jobs ready. Free memory (GB): 28.80/28.80, Free processors: 4/4.
# 210307-22:32:06,982 nipype.workflow DEBUG:
# 	 Allocating get_stats.sf2 ID=0 (0.20GB, 1 threads). Free: 28.60GB, 3 threads.
# 210307-22:32:06,983 nipype.workflow DEBUG:
# 	 [Node] Not cached "/Users/lucindasisk/Documents/qT1_10.2020Analysis/workflow_globalR1/get_stats/_subject_id_56-T1/sf2".
# 210307-22:32:06,984 nipype.workflow DEBUG:
# 	 Checking hash "get_stats.sf2" locally: cached=False, updated=False.
# 210307-22:32:07,1 nipype.workflow DEBUG:
# 	 [MultiProc] Submitted task get_stats.sf2 (taskid=1).
# 210307-22:32:07,6 nipype.workflow DEBUG:
# 	 Allocating get_stats.sf2 ID=3 (0.20GB, 1 threads). Free: 28.40GB, 2 threads.
# 210307-22:32:07,7 nipype.workflow DEBUG:
# 	 [Node] Not cached "/Users/lucindasisk/Documents/qT1_10.2020Analysis/workflow_globalR1/get_stats/_subject_id_55-T1/sf2".
# 210307-22:32:07,8 nipype.workflow DEBUG:
# 	 Checking hash "get_stats.sf2" locally: cached=False, updated=False.
# 210307-22:32:07,10 nipype.workflow DEBUG:
# 	 [MultiProc] Submitted task get_stats.sf2 (taskid=2).
# 210307-22:32:07,11 nipype.workflow DEBUG:
# 	 Allocating get_stats.sf2 ID=6 (0.20GB, 1 threads). Free: 28.20GB, 1 threads.
# 210307-22:32:07,7 nipype.workflow INFO:
# 	 [Node] Setting-up "get_stats.sf2" in "/Users/lucindasisk/Documents/qT1_10.2020Analysis/workflow_globalR1/get_stats/_subject_id_56-T1/sf2".
# 210307-22:32:07,12 nipype.workflow DEBUG:
# 	 [Node] Not cached "/Users/lucindasisk/Documents/qT1_10.2020Analysis/workflow_globalR1/get_stats/_subject_id_54-T1/sf2".
# 210307-22:32:07,13 nipype.workflow DEBUG:
# 	 Checking hash "get_stats.sf2" locally: cached=False, updated=False.
# 210307-22:32:07,13 nipype.workflow DEBUG:
# 	 [Node] Not cached "/Users/lucindasisk/Documents/qT1_10.2020Analysis/workflow_globalR1/get_stats/_subject_id_56-T1/sf2".
# 210307-22:32:07,16 nipype.workflow DEBUG:
# 	 [MultiProc] Submitted task get_stats.sf2 (taskid=3).
# 210307-22:32:07,13 nipype.workflow INFO:
# 	 [Node] Setting-up "get_stats.sf2" in "/Users/lucindasisk/Documents/qT1_10.2020Analysis/workflow_globalR1/get_stats/_subject_id_55-T1/sf2".
# 210307-22:32:07,18 nipype.workflow DEBUG:
# 	 Allocating get_stats.sf2 ID=9 (0.20GB, 1 threads). Free: 28.00GB, 0 threads.
# 210307-22:32:07,19 nipype.workflow DEBUG:
# 	 [Node] Not cached "/Users/lucindasisk/Documents/qT1_10.2020Analysis/workflow_globalR1/get_stats/_subject_id_53-T1/sf2".
# 210307-22:32:07,17 nipype.utils DEBUG:
# 	 Removing contents of /Users/lucindasisk/Documents/qT1_10.2020Analysis/workflow_globalR1/get_stats/_subject_id_56-T1/sf2
# 210307-22:32:07,20 nipype.workflow DEBUG:
# 	 Checking hash "get_stats.sf2" locally: cached=False, updated=False.
# 210307-22:32:07,18 nipype.workflow DEBUG:
# 	 [Node] Not cached "/Users/lucindasisk/Documents/qT1_10.2020Analysis/workflow_globalR1/get_stats/_subject_id_55-T1/sf2".
# 210307-22:32:07,22 nipype.workflow DEBUG:
# 	 [Node] Writing pre-exec report to "/Users/lucindasisk/Documents/qT1_10.2020Analysis/workflow_globalR1/get_stats/_subject_id_56-T1/sf2/_report/report.rst"
# 210307-22:32:07,22 nipype.workflow DEBUG:
# 	 [MultiProc] Submitted task get_stats.sf2 (taskid=4).
# 210307-22:32:07,24 nipype.workflow DEBUG:
# 	 Cannot allocate job 12 (0.20GB, 1 threads).
# 210307-22:32:07,22 nipype.utils DEBUG:
# 	 Removing contents of /Users/lucindasisk/Documents/qT1_10.2020Analysis/workflow_globalR1/get_stats/_subject_id_55-T1/sf2
# 210307-22:32:07,25 nipype.workflow DEBUG:
# 	 Cannot allocate job 15 (0.20GB, 1 threads).
# 210307-22:32:07,21 nipype.workflow INFO:
# 	 [Node] Setting-up "get_stats.sf2" in "/Users/lucindasisk/Documents/qT1_10.2020Analysis/workflow_globalR1/get_stats/_subject_id_54-T1/sf2".
# 210307-22:32:07,27 nipype.workflow DEBUG:
# 	 Cannot allocate job 18 (0.20GB, 1 threads).
# 210307-22:32:07,25 nipype.workflow DEBUG:
# 	 [Node] Not cached "/Users/lucindasisk/Documents/qT1_10.2020Analysis/workflow_globalR1/get_stats/_subject_id_54-T1/sf2".
# 210307-22:32:07,28 nipype.workflow DEBUG:
# 	 Cannot allocate job 21 (0.20GB, 1 threads).
# 210307-22:32:07,27 nipype.workflow DEBUG:
# 	 [Node] Writing pre-exec report to "/Users/lucindasisk/Documents/qT1_10.2020Analysis/workflow_globalR1/get_stats/_subject_id_55-T1/sf2/_report/report.rst"
# 210307-22:32:07,29 nipype.workflow DEBUG:
# 	 Cannot allocate job 24 (0.20GB, 1 threads).
# 210307-22:32:07,29 nipype.workflow INFO:
# 	 [Node] Running "sf2" ("nipype.interfaces.io.SelectFiles")
# 210307-22:32:07,31 nipype.workflow DEBUG:
# 	 Cannot allocate job 27 (0.20GB, 1 threads).
# 210307-22:32:07,27 nipype.workflow INFO:
# 	 [Node] Setting-up "get_stats.sf2" in "/Users/lucindasisk/Documents/qT1_10.2020Analysis/workflow_globalR1/get_stats/_subject_id_53-T1/sf2".
# 210307-22:32:07,32 nipype.workflow DEBUG:
# 	 Cannot allocate job 30 (0.20GB, 1 threads).
# 210307-22:32:07,30 nipype.utils DEBUG:
# 	 Removing contents of /Users/lucindasisk/Documents/qT1_10.2020Analysis/workflow_globalR1/get_stats/_subject_id_54-T1/sf2
# 210307-22:32:07,34 nipype.workflow DEBUG:
# 	 Cannot allocate job 33 (0.20GB, 1 threads).
# 210307-22:32:07,32 nipype.workflow DEBUG:
# 	 [Node] Not cached "/Users/lucindasisk/Documents/qT1_10.2020Analysis/workflow_globalR1/get_stats/_subject_id_53-T1/sf2".
# 210307-22:32:07,35 nipype.workflow DEBUG:
# 	 Cannot allocate job 36 (0.20GB, 1 threads).
# 210307-22:32:07,34 nipype.workflow INFO:
# 	 [Node] Running "sf2" ("nipype.interfaces.io.SelectFiles")
# 210307-22:32:07,36 nipype.workflow DEBUG:
# 	 Cannot allocate job 39 (0.20GB, 1 threads).
# 210307-22:32:07,35 nipype.workflow DEBUG:
# 	 [Node] Writing pre-exec report to "/Users/lucindasisk/Documents/qT1_10.2020Analysis/workflow_globalR1/get_stats/_subject_id_54-T1/sf2/_report/report.rst"
# 210307-22:32:07,38 nipype.workflow DEBUG:
# 	 Cannot allocate job 42 (0.20GB, 1 threads).
# 210307-22:32:07,37 nipype.utils DEBUG:
# 	 Removing contents of /Users/lucindasisk/Documents/qT1_10.2020Analysis/workflow_globalR1/get_stats/_subject_id_53-T1/sf2
# 210307-22:32:07,39 nipype.workflow DEBUG:
# 	 Cannot allocate job 45 (0.20GB, 1 threads).
# 210307-22:32:07,40 nipype.workflow DEBUG:
# 	 Cannot allocate job 48 (0.20GB, 1 threads).
# 210307-22:32:07,41 nipype.workflow DEBUG:
# 	 Cannot allocate job 51 (0.20GB, 1 threads).
# 210307-22:32:07,42 nipype.workflow DEBUG:
# 	 Cannot allocate job 54 (0.20GB, 1 threads).
# 210307-22:32:07,46 nipype.workflow DEBUG:
# 	 Cannot allocate job 57 (0.20GB, 1 threads).
# 210307-22:32:07,41 nipype.workflow DEBUG:
# 	 [Node] Writing pre-exec report to "/Users/lucindasisk/Documents/qT1_10.2020Analysis/workflow_globalR1/get_stats/_subject_id_53-T1/sf2/_report/report.rst"
# 210307-22:32:07,43 nipype.workflow INFO:
# 	 [Node] Running "sf2" ("nipype.interfaces.io.SelectFiles")
# 210307-22:32:07,50 nipype.workflow DEBUG:
# 	 Cannot allocate job 60 (0.20GB, 1 threads).
# 210307-22:32:07,51 nipype.workflow DEBUG:
# 	 Cannot allocate job 63 (0.20GB, 1 threads).
# 210307-22:32:07,52 nipype.workflow DEBUG:
# 	 Cannot allocate job 66 (0.20GB, 1 threads).
# 210307-22:32:07,53 nipype.workflow DEBUG:
# 	 Cannot allocate job 69 (0.20GB, 1 threads).
# 210307-22:32:07,54 nipype.workflow DEBUG:
# 	 Cannot allocate job 72 (0.20GB, 1 threads).
# 210307-22:32:07,55 nipype.workflow DEBUG:
# 	 Cannot allocate job 75 (0.20GB, 1 threads).
# 210307-22:32:07,54 nipype.workflow INFO:
# 	 [Node] Running "sf2" ("nipype.interfaces.io.SelectFiles")
# 210307-22:32:07,56 nipype.workflow DEBUG:
# 	 Cannot allocate job 78 (0.20GB, 1 threads).
# 210307-22:32:07,57 nipype.workflow DEBUG:
# 	 Cannot allocate job 81 (0.20GB, 1 threads).
# 210307-22:32:07,59 nipype.workflow DEBUG:
# 	 Cannot allocate job 84 (0.20GB, 1 threads).
# 210307-22:32:07,60 nipype.workflow DEBUG:
# 	 Cannot allocate job 87 (0.20GB, 1 threads).
# 210307-22:32:07,61 nipype.workflow DEBUG:
# 	 Cannot allocate job 90 (0.20GB, 1 threads).
# 210307-22:32:07,62 nipype.workflow DEBUG:
# 	 Cannot allocate job 93 (0.20GB, 1 threads).
# 210307-22:32:07,62 nipype.workflow DEBUG:
# 	 Cannot allocate job 96 (0.20GB, 1 threads).
# 210307-22:32:07,63 nipype.workflow DEBUG:
# 	 Cannot allocate job 99 (0.20GB, 1 threads).
# 210307-22:32:07,64 nipype.workflow DEBUG:
# 	 Cannot allocate job 102 (0.20GB, 1 threads).
# 210307-22:32:07,64 nipype.workflow DEBUG:
# 	 Cannot allocate job 105 (0.20GB, 1 threads).
# 210307-22:32:07,65 nipype.workflow DEBUG:
# 	 Cannot allocate job 108 (0.20GB, 1 threads).
# 210307-22:32:07,66 nipype.workflow DEBUG:
# 	 Cannot allocate job 111 (0.20GB, 1 threads).
# 210307-22:32:07,66 nipype.workflow DEBUG:
# 	 Cannot allocate job 114 (0.20GB, 1 threads).
# 210307-22:32:07,67 nipype.workflow DEBUG:
# 	 Cannot allocate job 117 (0.20GB, 1 threads).
# 210307-22:32:07,68 nipype.workflow DEBUG:
# 	 Cannot allocate job 120 (0.20GB, 1 threads).
# 210307-22:32:07,69 nipype.workflow DEBUG:
# 	 Cannot allocate job 123 (0.20GB, 1 threads).
# 210307-22:32:07,69 nipype.workflow DEBUG:
# 	 Cannot allocate job 126 (0.20GB, 1 threads).
# 210307-22:32:07,70 nipype.workflow DEBUG:
# 	 Cannot allocate job 129 (0.20GB, 1 threads).
# 210307-22:32:07,71 nipype.workflow DEBUG:
# 	 Cannot allocate job 132 (0.20GB, 1 threads).
# 210307-22:32:07,72 nipype.workflow DEBUG:
# 	 Cannot allocate job 135 (0.20GB, 1 threads).
# 210307-22:32:07,72 nipype.workflow DEBUG:
# 	 Cannot allocate job 138 (0.20GB, 1 threads).
# 210307-22:32:07,73 nipype.workflow DEBUG:
# 	 Cannot allocate job 141 (0.20GB, 1 threads).
# 210307-22:32:07,74 nipype.workflow DEBUG:
# 	 Cannot allocate job 144 (0.20GB, 1 threads).
# 210307-22:32:07,75 nipype.workflow DEBUG:
# 	 Cannot allocate job 147 (0.20GB, 1 threads).
# 210307-22:32:07,75 nipype.workflow DEBUG:
# 	 Cannot allocate job 150 (0.20GB, 1 threads).
# 210307-22:32:07,76 nipype.workflow DEBUG:
# 	 Cannot allocate job 153 (0.20GB, 1 threads).
# 210307-22:32:07,77 nipype.workflow DEBUG:
# 	 Cannot allocate job 156 (0.20GB, 1 threads).
# 210307-22:32:07,77 nipype.workflow DEBUG:
# 	 Cannot allocate job 159 (0.20GB, 1 threads).
# 210307-22:32:07,78 nipype.workflow DEBUG:
# 	 Cannot allocate job 162 (0.20GB, 1 threads).
# 210307-22:32:07,79 nipype.workflow DEBUG:
# 	 Cannot allocate job 165 (0.20GB, 1 threads).
# 210307-22:32:07,79 nipype.workflow DEBUG:
# 	 Cannot allocate job 168 (0.20GB, 1 threads).
# 210307-22:32:07,80 nipype.workflow DEBUG:
# 	 Cannot allocate job 171 (0.20GB, 1 threads).
# 210307-22:32:07,81 nipype.workflow DEBUG:
# 	 Cannot allocate job 174 (0.20GB, 1 threads).
# 210307-22:32:07,81 nipype.workflow DEBUG:
# 	 Cannot allocate job 177 (0.20GB, 1 threads).
# 210307-22:32:07,82 nipype.workflow DEBUG:
# 	 Cannot allocate job 180 (0.20GB, 1 threads).
# 210307-22:32:07,83 nipype.workflow DEBUG:
# 	 Cannot allocate job 183 (0.20GB, 1 threads).
# 210307-22:32:07,84 nipype.workflow DEBUG:
# 	 Cannot allocate job 186 (0.20GB, 1 threads).
# 210307-22:32:07,84 nipype.workflow DEBUG:
# 	 Cannot allocate job 189 (0.20GB, 1 threads).
# 210307-22:32:07,85 nipype.workflow DEBUG:
# 	 Cannot allocate job 192 (0.20GB, 1 threads).
# 210307-22:32:07,86 nipype.workflow DEBUG:
# 	 Cannot allocate job 195 (0.20GB, 1 threads).
# 210307-22:32:07,86 nipype.workflow DEBUG:
# 	 Cannot allocate job 198 (0.20GB, 1 threads).
# 210307-22:32:07,87 nipype.workflow DEBUG:
# 	 Cannot allocate job 201 (0.20GB, 1 threads).
# 210307-22:32:07,88 nipype.workflow DEBUG:
# 	 Cannot allocate job 204 (0.20GB, 1 threads).
# 210307-22:32:07,88 nipype.workflow DEBUG:
# 	 Cannot allocate job 207 (0.20GB, 1 threads).
# 210307-22:32:07,89 nipype.workflow DEBUG:
# 	 Cannot allocate job 210 (0.20GB, 1 threads).
# 210307-22:32:07,90 nipype.workflow DEBUG:
# 	 Cannot allocate job 213 (0.20GB, 1 threads).
# 210307-22:32:07,90 nipype.workflow DEBUG:
# 	 Cannot allocate job 216 (0.20GB, 1 threads).
# 210307-22:32:07,91 nipype.workflow DEBUG:
# 	 Cannot allocate job 219 (0.20GB, 1 threads).
# 210307-22:32:07,91 nipype.workflow DEBUG:
# 	 Cannot allocate job 222 (0.20GB, 1 threads).
# 210307-22:32:07,92 nipype.workflow DEBUG:
# 	 Cannot allocate job 225 (0.20GB, 1 threads).
# 210307-22:32:07,93 nipype.workflow DEBUG:
# 	 Cannot allocate job 228 (0.20GB, 1 threads).
# 210307-22:32:07,93 nipype.workflow DEBUG:
# 	 Cannot allocate job 231 (0.20GB, 1 threads).
# 210307-22:32:07,94 nipype.workflow DEBUG:
# 	 Cannot allocate job 234 (0.20GB, 1 threads).
# 210307-22:32:07,95 nipype.workflow DEBUG:
# 	 Cannot allocate job 237 (0.20GB, 1 threads).
# 210307-22:32:07,96 nipype.workflow DEBUG:
# 	 Cannot allocate job 240 (0.20GB, 1 threads).
# 210307-22:32:07,96 nipype.workflow DEBUG:
# ...
# 	 Cannot allocate job 54 (0.20GB, 1 threads).
# 210307-22:32:11,13 nipype.workflow DEBUG:
# 	 [Node] Writing pre-exec report to "/Users/lucindasisk/Documents/qT1_10.2020Analysis/workflow_globalR1/get_stats/_subject_id_56-T1/datasink/_report/report.rst"
# 210307-22:32:11,26 nipype.workflow DEBUG:
# 	 Cannot allocate job 57 (0.20GB, 1 threads).
# 210307-22:32:11,13 nipype.workflow DEBUG:
# 	 [Node] Setting 1 connected inputs of node "datasink" from 1 previous nodes.
# 210307-22:32:11,27 nipype.workflow DEBUG:
# 	 Cannot allocate job 60 (0.20GB, 1 threads).
# 210307-22:32:11,14 nipype.workflow DEBUG:
# 	 output: out_stat
# 210307-22:32:11,28 nipype.workflow DEBUG:
# 	 Cannot allocate job 63 (0.20GB, 1 threads).
# 210307-22:32:11,16 nipype.workflow DEBUG:
# 	 [Node] datasink - setting input 2_Extracted_Stats.@par.@par.@par.@par.@par.@par.@par.@par = []
# 210307-22:32:11,29 nipype.workflow DEBUG:
# 	 Cannot allocate job 66 (0.20GB, 1 threads).
# 210307-22:32:11,16 nipype.utils DEBUG:
# 	 Loading pkl: /Users/lucindasisk/Documents/qT1_10.2020Analysis/workflow_globalR1/get_stats/_subject_id_53-T1/get_globalR1/result_get_globalR1.pklz
# 210307-22:32:11,30 nipype.workflow DEBUG:
# 	 Cannot allocate job 69 (0.20GB, 1 threads).
# 210307-22:32:11,16 nipype.workflow DEBUG:
# 	 [Node] Writing pre-exec report to "/Users/lucindasisk/Documents/qT1_10.2020Analysis/workflow_globalR1/get_stats/_subject_id_55-T1/datasink/_report/report.rst"
# 210307-22:32:11,31 nipype.workflow DEBUG:
# 	 Cannot allocate job 72 (0.20GB, 1 threads).
# 210307-22:32:11,19 nipype.workflow INFO:
# 	 [Node] Running "datasink" ("nipype.interfaces.io.DataSink")
# 210307-22:32:11,32 nipype.workflow DEBUG:
# 	 Cannot allocate job 75 (0.20GB, 1 threads).
# 210307-22:32:11,19 nipype.utils DEBUG:
# 	 Removing contents of /Users/lucindasisk/Documents/qT1_10.2020Analysis/workflow_globalR1/get_stats/_subject_id_54-T1/datasink
# 210307-22:32:11,33 nipype.workflow DEBUG:
# 	 Cannot allocate job 78 (0.20GB, 1 threads).
# 210307-22:32:11,19 nipype.workflow DEBUG:
# 	 Resolving paths in outputs loaded from results file.
# 210307-22:32:11,34 nipype.workflow DEBUG:
# 	 Cannot allocate job 81 (0.20GB, 1 threads).
# 210307-22:32:11,21 nipype.workflow DEBUG:
# 	 output: out_stat
# 210307-22:32:11,22 nipype.workflow DEBUG:
# 	 [Node] Writing pre-exec report to "/Users/lucindasisk/Documents/qT1_10.2020Analysis/workflow_globalR1/get_stats/_subject_id_54-T1/datasink/_report/report.rst"
# 210307-22:32:11,36 nipype.workflow DEBUG:
# 	 Cannot allocate job 84 (0.20GB, 1 threads).
# 210307-22:32:11,22 nipype.workflow INFO:
# 	 [Node] Running "datasink" ("nipype.interfaces.io.DataSink")
# 210307-22:32:11,24 nipype.interface DEBUG:
# 	 key: 2_Extracted_Stats.@par.@par.@par.@par.@par.@par.@par.@par files: []
# 210307-22:32:11,37 nipype.workflow DEBUG:
# 	 Cannot allocate job 87 (0.20GB, 1 threads).
# 210307-22:32:11,24 nipype.workflow DEBUG:
# 	 [Node] datasink - setting input 2_Extracted_Stats.@par.@par.@par.@par.@par.@par.@par.@par = []
# 210307-22:32:11,26 nipype.interface DEBUG:
# 	 key: 2_Extracted_Stats.@par.@par.@par.@par.@par.@par.@par.@par files: []
# 210307-22:32:11,38 nipype.workflow DEBUG:
# 	 Cannot allocate job 90 (0.20GB, 1 threads).
# 210307-22:32:11,26 nipype.utils DEBUG:
# 	 Removing contents of /Users/lucindasisk/Documents/qT1_10.2020Analysis/workflow_globalR1/get_stats/_subject_id_53-T1/datasink
# 210307-22:32:11,27 nipype.workflow INFO:
# 	 [Node] Running "datasink" ("nipype.interfaces.io.DataSink")
# 210307-22:32:11,39 nipype.workflow DEBUG:
# 	 Cannot allocate job 93 (0.20GB, 1 threads).
# 210307-22:32:11,29 nipype.workflow DEBUG:
# 	 [Node] Writing pre-exec report to "/Users/lucindasisk/Documents/qT1_10.2020Analysis/workflow_globalR1/get_stats/_subject_id_53-T1/datasink/_report/report.rst"
# 210307-22:32:11,31 nipype.interface DEBUG:
# 	 key: 2_Extracted_Stats.@par.@par.@par.@par.@par.@par.@par.@par files: []
# 210307-22:32:11,41 nipype.workflow DEBUG:
# 	 Cannot allocate job 96 (0.20GB, 1 threads).
# 210307-22:32:11,31 nipype.workflow DEBUG:
# 	 Saving results file: '/Users/lucindasisk/Documents/qT1_10.2020Analysis/workflow_globalR1/get_stats/_subject_id_56-T1/datasink/result_datasink.pklz'
# 210307-22:32:11,32 nipype.workflow DEBUG:
# 	 Saving results file: '/Users/lucindasisk/Documents/qT1_10.2020Analysis/workflow_globalR1/get_stats/_subject_id_55-T1/datasink/result_datasink.pklz'
# 210307-22:32:11,43 nipype.workflow DEBUG:
# 	 Cannot allocate job 99 (0.20GB, 1 threads).
# 210307-22:32:11,33 nipype.workflow WARNING:
# 	 Storing result file without outputs
# 210307-22:32:11,35 nipype.workflow WARNING:
# 	 Storing result file without outputs
# 210307-22:32:11,44 nipype.workflow DEBUG:
# 	 Cannot allocate job 102 (0.20GB, 1 threads).
# 210307-22:32:11,36 nipype.workflow INFO:
# 	 [Node] Running "datasink" ("nipype.interfaces.io.DataSink")
# 210307-22:32:11,36 nipype.workflow WARNING:
# 	 [Node] Error on "get_stats.datasink" (/Users/lucindasisk/Documents/qT1_10.2020Analysis/workflow_globalR1/get_stats/_subject_id_56-T1/datasink)
# 210307-22:32:11,46 nipype.workflow DEBUG:
# 	 Cannot allocate job 105 (0.20GB, 1 threads).
# 210307-22:32:11,38 nipype.workflow DEBUG:
# 	 Saving results file: '/Users/lucindasisk/Documents/qT1_10.2020Analysis/workflow_globalR1/get_stats/_subject_id_54-T1/datasink/result_datasink.pklz'
# 210307-22:32:11,39 nipype.interface DEBUG:
# 	 key: 2_Extracted_Stats.@par.@par.@par.@par.@par.@par.@par.@par files: []
# 210307-22:32:11,47 nipype.workflow DEBUG:
# 	 Cannot allocate job 108 (0.20GB, 1 threads).
# 210307-22:32:11,40 nipype.workflow WARNING:
# 	 [Node] Error on "get_stats.datasink" (/Users/lucindasisk/Documents/qT1_10.2020Analysis/workflow_globalR1/get_stats/_subject_id_55-T1/datasink)
# 210307-22:32:11,41 nipype.utils DEBUG:
# 	 Loading pkl: /Users/lucindasisk/Documents/qT1_10.2020Analysis/workflow_globalR1/get_stats/_subject_id_56-T1/datasink/result_datasink.pklz
# 210307-22:32:11,49 nipype.workflow DEBUG:
# 	 Cannot allocate job 111 (0.20GB, 1 threads).
# 210307-22:32:11,41 nipype.workflow WARNING:
# 	 Storing result file without outputs
# 210307-22:32:11,44 nipype.utils DEBUG:
# 	 Loading pkl: /Users/lucindasisk/Documents/qT1_10.2020Analysis/workflow_globalR1/get_stats/_subject_id_55-T1/datasink/result_datasink.pklz
# 210307-22:32:11,51 nipype.workflow DEBUG:
# 	 Cannot allocate job 114 (0.20GB, 1 threads).
# 210307-22:32:11,44 nipype.workflow WARNING:
# 	 [Node] Error on "get_stats.datasink" (/Users/lucindasisk/Documents/qT1_10.2020Analysis/workflow_globalR1/get_stats/_subject_id_54-T1/datasink)
# 210307-22:32:11,45 nipype.workflow DEBUG:
# 	 Saving results file: '/Users/lucindasisk/Documents/qT1_10.2020Analysis/workflow_globalR1/get_stats/_subject_id_53-T1/datasink/result_datasink.pklz'
# 210307-22:32:11,53 nipype.workflow DEBUG:
# 	 Cannot allocate job 117 (0.20GB, 1 threads).
# 210307-22:32:11,47 nipype.workflow WARNING:
# 	 Storing result file without outputs
# 210307-22:32:11,48 nipype.utils DEBUG:
# 	 Loading pkl: /Users/lucindasisk/Documents/qT1_10.2020Analysis/workflow_globalR1/get_stats/_subject_id_54-T1/datasink/result_datasink.pklz
# 210307-22:32:11,54 nipype.workflow DEBUG:
# 	 Cannot allocate job 120 (0.20GB, 1 threads).
# 210307-22:32:11,51 nipype.workflow WARNING:
# 	 [Node] Error on "get_stats.datasink" (/Users/lucindasisk/Documents/qT1_10.2020Analysis/workflow_globalR1/get_stats/_subject_id_53-T1/datasink)
# 210307-22:32:11,55 nipype.workflow DEBUG:
# 	 Cannot allocate job 123 (0.20GB, 1 threads).
# 210307-22:32:11,56 nipype.workflow DEBUG:
# 	 Cannot allocate job 126 (0.20GB, 1 threads).
# 210307-22:32:11,55 nipype.utils DEBUG:
# 	 Loading pkl: /Users/lucindasisk/Documents/qT1_10.2020Analysis/workflow_globalR1/get_stats/_subject_id_53-T1/datasink/result_datasink.pklz
# 210307-22:32:11,57 nipype.workflow DEBUG:
# 	 Cannot allocate job 129 (0.20GB, 1 threads).
# 210307-22:32:11,58 nipype.workflow DEBUG:
# 	 Cannot allocate job 132 (0.20GB, 1 threads).
# 210307-22:32:11,59 nipype.workflow DEBUG:
# 	 Cannot allocate job 135 (0.20GB, 1 threads).
# 210307-22:32:11,60 nipype.workflow DEBUG:
# 	 Cannot allocate job 138 (0.20GB, 1 threads).
# 210307-22:32:11,60 nipype.workflow DEBUG:
# 	 Cannot allocate job 141 (0.20GB, 1 threads).
# 210307-22:32:11,61 nipype.workflow DEBUG:
# 	 Cannot allocate job 144 (0.20GB, 1 threads).
# 210307-22:32:11,62 nipype.workflow DEBUG:
# 	 Cannot allocate job 147 (0.20GB, 1 threads).
# 210307-22:32:11,63 nipype.workflow DEBUG:
# 	 Cannot allocate job 150 (0.20GB, 1 threads).
# 210307-22:32:11,64 nipype.workflow DEBUG:
# 	 Cannot allocate job 153 (0.20GB, 1 threads).
# 210307-22:32:11,64 nipype.workflow DEBUG:
# 	 Cannot allocate job 156 (0.20GB, 1 threads).
# 210307-22:32:11,65 nipype.workflow DEBUG:
# 	 Cannot allocate job 159 (0.20GB, 1 threads).
# 210307-22:32:11,65 nipype.workflow DEBUG:
# 	 Cannot allocate job 162 (0.20GB, 1 threads).
# 210307-22:32:11,66 nipype.workflow DEBUG:
# 	 Cannot allocate job 165 (0.20GB, 1 threads).
# 210307-22:32:11,67 nipype.workflow DEBUG:
# 	 Cannot allocate job 168 (0.20GB, 1 threads).
# 210307-22:32:11,67 nipype.workflow DEBUG:
# 	 Cannot allocate job 171 (0.20GB, 1 threads).
# 210307-22:32:11,68 nipype.workflow DEBUG:
# 	 Cannot allocate job 174 (0.20GB, 1 threads).
# 210307-22:32:11,69 nipype.workflow DEBUG:
# 	 Cannot allocate job 177 (0.20GB, 1 threads).
# 210307-22:32:11,69 nipype.workflow DEBUG:
# 	 Cannot allocate job 180 (0.20GB, 1 threads).
# 210307-22:32:11,70 nipype.workflow DEBUG:
# 	 Cannot allocate job 183 (0.20GB, 1 threads).
# 210307-22:32:11,70 nipype.workflow DEBUG:
# 	 Cannot allocate job 186 (0.20GB, 1 threads).
# 210307-22:32:11,71 nipype.workflow DEBUG:
# 	 Cannot allocate job 189 (0.20GB, 1 threads).
# 210307-22:32:11,71 nipype.workflow DEBUG:
# 	 Cannot allocate job 192 (0.20GB, 1 threads).
# 210307-22:32:11,72 nipype.workflow DEBUG:
# 	 Cannot allocate job 195 (0.20GB, 1 threads).
# 210307-22:32:11,72 nipype.workflow DEBUG:
# 	 Cannot allocate job 198 (0.20GB, 1 threads).
# 210307-22:32:11,73 nipype.workflow DEBUG:
# 	 Cannot allocate job 201 (0.20GB, 1 threads).
# 210307-22:32:11,74 nipype.workflow DEBUG:
# 	 Cannot allocate job 204 (0.20GB, 1 threads).
# 210307-22:32:11,74 nipype.workflow DEBUG:
# 	 Cannot allocate job 207 (0.20GB, 1 threads).
# 210307-22:32:11,75 nipype.workflow DEBUG:
# 	 Cannot allocate job 210 (0.20GB, 1 threads).
# 210307-22:32:11,75 nipype.workflow DEBUG:
# 	 Cannot allocate job 213 (0.20GB, 1 threads).
# 210307-22:32:11,76 nipype.workflow DEBUG:
# 	 Cannot allocate job 216 (0.20GB, 1 threads).
# 210307-22:32:11,76 nipype.workflow DEBUG:
# 	 Cannot allocate job 219 (0.20GB, 1 threads).
# 210307-22:32:11,77 nipype.workflow DEBUG:
# 	 Cannot allocate job 222 (0.20GB, 1 threads).
# 210307-22:32:11,78 nipype.workflow DEBUG:
# 	 Cannot allocate job 225 (0.20GB, 1 threads).
# 210307-22:32:11,78 nipype.workflow DEBUG:
# 	 Cannot allocate job 228 (0.20GB, 1 threads).
# 210307-22:32:11,78 nipype.workflow DEBUG:
# 	 Cannot allocate job 231 (0.20GB, 1 threads).
# 210307-22:32:11,79 nipype.workflow DEBUG:
# 	 Cannot allocate job 234 (0.20GB, 1 threads).
# 210307-22:32:11,79 nipype.workflow DEBUG:
# 	 Cannot allocate job 237 (0.20GB, 1 threads).
# 210307-22:32:11,80 nipype.workflow DEBUG:
# 	 Cannot allocate job 240 (0.20GB, 1 threads).
# 210307-22:32:11,80 nipype.workflow DEBUG:
# 	 Cannot allocate job 243 (0.20GB, 1 threads).
# 210307-22:32:11,81 nipype.workflow DEBUG:
# 	 Cannot allocate job 246 (0.20GB, 1 threads).
# 210307-22:32:12,934 nipype.workflow DEBUG:
# 	 Progress: 249 jobs, 8/4/79 (done/running/ready), 4/237 (pending_tasks/waiting).
# 210307-22:32:12,935 nipype.workflow DEBUG:
# 	 Clearing 2 from queue
# 210307-22:32:12,936 nipype.utils DEBUG:
# 	 Loading pkl: /Users/lucindasisk/Documents/qT1_10.2020Analysis/workflow_globalR1/get_stats/_subject_id_56-T1/datasink/result_datasink.pklz
# 210307-22:32:12,938 nipype.workflow ERROR:
# 	 Node datasink.a82 failed to run on host www-skrufi.stanford.edu.
# 210307-22:32:12,939 nipype.workflow ERROR:
# 	 Saving crash info to /Users/lucindasisk/Dropbox/Github/TIGER_qT1_Tracts/crash-20210307-223212-lucindasisk-datasink.a82-810f0af8-a6ac-4279-a71e-12d7d66839e7.pklz
# Traceback (most recent call last):
#   File "/usr/local/anaconda3/lib/python3.7/site-packages/nipype/pipeline/plugins/multiproc.py", line 67, in run_node
#     result["result"] = node.run(updatehash=updatehash)
#   File "/usr/local/anaconda3/lib/python3.7/site-packages/nipype/pipeline/engine/nodes.py", line 516, in run
#     result = self._run_interface(execute=True)
#   File "/usr/local/anaconda3/lib/python3.7/site-packages/nipype/pipeline/engine/nodes.py", line 635, in _run_interface
#     return self._run_command(execute)
#   File "/usr/local/anaconda3/lib/python3.7/site-packages/nipype/pipeline/engine/nodes.py", line 741, in _run_command
#     result = self._interface.run(cwd=outdir)
#   File "/usr/local/anaconda3/lib/python3.7/site-packages/nipype/interfaces/base/core.py", line 421, in run
#     outputs = self.aggregate_outputs(runtime)
#   File "/usr/local/anaconda3/lib/python3.7/site-packages/nipype/interfaces/base/core.py", line 498, in aggregate_outputs
#     predicted_outputs = self._list_outputs()  # Predictions from _list_outputs
#   File "/usr/local/anaconda3/lib/python3.7/site-packages/nipype/interfaces/io.py", line 748, in _list_outputs
#     if isinstance(files[0], list):
# IndexError: list index out of range
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-12-c4112e64c49e> in <module>
#      38 get_stats.base_dir = workflow_dir
#      39 get_stats.write_graph(graph2use = 'flat')
# ---> 40 preproc = get_stats.run('MultiProc', plugin_args={'n_procs': 4})
#
# /usr/local/anaconda3/lib/python3.7/site-packages/nipype/pipeline/engine/workflows.py in run(self, plugin, plugin_args, updatehash)
#     630         if str2bool(self.config["execution"]["create_report"]):
#     631             self._write_report_info(self.base_dir, self.name, execgraph)
# --> 632         runner.run(execgraph, updatehash=updatehash, config=self.config)
#     633         datestr = datetime.utcnow().strftime("%Y%m%dT%H%M%S")
#     634         if str2bool(self.config["execution"]["write_provenance"]):
#
# /usr/local/anaconda3/lib/python3.7/site-packages/nipype/pipeline/plugins/base.py in run(self, graph, config, updatehash)
#     162                         if result["traceback"]:
#     163                             notrun.append(
# --> 164                                 self._clean_queue(jobid, graph, result=result)
#     165                             )
#     166                         else:
#
# /usr/local/anaconda3/lib/python3.7/site-packages/nipype/pipeline/plugins/base.py in _clean_queue(self, jobid, graph, result)
#     225         crashfile = self._report_crash(self.procs[jobid], result=result)
#     226         if str2bool(self._config["execution"]["stop_on_first_crash"]):
# --> 227             raise RuntimeError("".join(result["traceback"]))
#     228         if jobid in self.mapnodesubids:
#     229             # remove current jobid
#
# RuntimeError: Traceback (most recent call last):
#   File "/usr/local/anaconda3/lib/python3.7/site-packages/nipype/pipeline/plugins/multiproc.py", line 67, in run_node
#     result["result"] = node.run(updatehash=updatehash)
#   File "/usr/local/anaconda3/lib/python3.7/site-packages/nipype/pipeline/engine/nodes.py", line 516, in run
#     result = self._run_interface(execute=True)
#   File "/usr/local/anaconda3/lib/python3.7/site-packages/nipype/pipeline/engine/nodes.py", line 635, in _run_interface
#     return self._run_command(execute)
#   File "/usr/local/anaconda3/lib/python3.7/site-packages/nipype/pipeline/engine/nodes.py", line 741, in _run_command
#     result = self._interface.run(cwd=outdir)
#   File "/usr/local/anaconda3/lib/python3.7/site-packages/nipype/interfaces/base/core.py", line 421, in run
#     outputs = self.aggregate_outputs(runtime)
#   File "/usr/local/anaconda3/lib/python3.7/site-packages/nipype/interfaces/base/core.py", line 498, in aggregate_outputs
#     predicted_outputs = self._list_outputs()  # Predictions from _list_outputs
#   File "/usr/local/anaconda3/lib/python3.7/site-packages/nipype/interfaces/io.py", line 748, in _list_outputs
#     if isinstance(files[0], list):
# IndexError: list index out of range

# %% [markdown]
# ### Extract subcortical data

# %%
# #SelectFiles
# template3 = dict(t1w = fpath+'/{subject_id}/freesurfer_brain.nii.gz',
#                 aseg = fpath+'/{subject_id}/aparc.a2009s+aseg.nii.gz',
#                 qt1_reor = data_dir+'/1_check_alignment/_subject_id_{subject_id}/reoriented_qT1.nii.gz')       


# sf3 = Node(SelectFiles(template3, 
#                       base_directory = fpath),
#           name = 'sf3')

# %%
# #MRI Convert Nodes
# convert_wb = Node(fsr.MRIConvert(in_type='mgz',
#                                out_file = 'freesurfer_brain.nii.gz'),
#                name = 'convert_wb')

# convert_aseg = Node(fsr.MRIConvert(in_type='mgz',
#                                out_file = 'aparc.a2009s+aseg.nii.gz'),
#                name = 'convert_aseg')

# %%
# #Extract left hippocampus - seg value 17
# extract_lhipp = Node(fsl.Threshold(thresh = 16.5, 
#                                    direction = 'below', 
#                                    args = '-uthr 17.5',
#                                    output_type = 'NIFTI_GZ',
#                                    out_file = 'left_hippocampus.nii.gz'),
#                         name = 'extract_lhipp')
# #Extract right hippocampus - seg value 53
# extract_rhipp = Node(fsl.Threshold(thresh = 52.5, 
#                                    direction = 'below', 
#                                    args = '-uthr 53.5',
#                                    output_type = 'NIFTI_GZ',
#                                    out_file = 'right_hippocampus.nii.gz'),
#                     name='extract_rhipp')

# %%
# #Extract left amygdala - seg value 18
# extract_lamyg = Node(fsl.Threshold(thresh = 17.5, 
#                                    direction = 'below', 
#                                    args = '-uthr 18.5',
#                                    output_type = 'NIFTI_GZ',
#                                    out_file = 'left_amygdala.nii.gz'),
#                         name = 'extract_lamyg')
# #Extract right amygdala - seg value 54
# extract_ramyg = Node(fsl.Threshold(thresh = 53.5, 
#                                    direction = 'below', 
#                                    args = '-uthr 54.5',
#                                    output_type = 'NIFTI_GZ',
#                                    out_file = 'right_amygdala.nii.gz'),
#                     name='extract_ramyg')

# %%
# #Extract left caudate - seg value 11
# extract_lcaud = Node(fsl.Threshold(thresh = 10.5, 
#                                    direction = 'below', 
#                                    args = '-uthr 11.5',
#                                    output_type = 'NIFTI_GZ',
#                                    out_file = 'left_caudate.nii.gz'),
#                         name = 'extract_lcaud')

# #Extract right caudate - seg value 50
# extract_rcaud = Node(fsl.Threshold(thresh = 49.5, 
#                                    direction = 'below', 
#                                    args = '-uthr 50.5',
#                                    output_type = 'NIFTI_GZ',
#                                    out_file = 'right_caudate.nii.gz'),
#                     name='extract_rcaud')

# %%
# #Extract left nucleus accumbens - seg value 26
# extract_lnacc  = Node(fsl.Threshold(thresh = 25.5, 
#                                    direction = 'below', 
#                                    args = '-uthr 26.5',
#                                    output_type = 'NIFTI_GZ',
#                                    out_file = 'left_nAcc.nii.gz'),
#                         name = 'extract_lnacc')

# #Extract right caudate - seg value 58
# extract_rnacc = Node(fsl.Threshold(thresh = 57.5, 
#                                    direction = 'below', 
#                                    args = '-uthr 58.5',
#                                    output_type = 'NIFTI_GZ',
#                                    out_file = 'right_nAcc.nii.gz'),
#                     name='extract_rnacc')

# %%
# #Extract left putamen - seg value 26
# extract_lput  = Node(fsl.Threshold(thresh = 11.5, 
#                                    direction = 'below', 
#                                    args = '-uthr 12.5',
#                                    output_type = 'NIFTI_GZ',
#                                    out_file = 'left_putamen.nii.gz'),
#                         name = 'extract_lput')

# #Extract right caudate - seg value 51
# extract_rput = Node(fsl.Threshold(thresh = 50.5, 
#                                    direction = 'below', 
#                                    args = '-uthr 51.5',
#                                    output_type = 'NIFTI_GZ',
#                                    out_file = 'right_putamen.nii.gz'),
#                     name='extract_rput')

# %%
# #Extract voxel values from qT1 beneath overlaid mask - Left Hippocampus
# get_voxRhipp = Node(fsl.ImageMeants(show_all = True,
#                                out_file = 'ROI_voxel-contrasts_RightHippocampus.txt'),
#                name = 'get_voxRhipp')

# #Extract voxel values from qT1 beneath overlaid mask - Right Hippocampus
# get_voxLhipp = Node(fsl.ImageMeants(show_all = True,
#                                out_file = 'ROI_voxel-contrasts_LeftHippocampus.txt'),
#                name = 'get_voxLhipp')

# %%
# #Extract voxel values from qT1 beneath overlaid mask - Left Amygdala
# get_voxRamyg = Node(fsl.ImageMeants(show_all = True,
#                                out_file = 'ROI_voxel-contrasts_RightAmygdala.txt'),
#                name = 'get_voxRamyg')

# #Extract voxel values from qT1 beneath overlaid mask - Right Amygdala
# get_voxLamyg = Node(fsl.ImageMeants(show_all = True,
#                                out_file = 'ROI_voxel-contrasts_LeftAmygdala.txt'),
#                name = 'get_voxLamyg')

# %%
# #Extract voxel values from qT1 beneath overlaid mask - Left Putamen
# get_voxRput = Node(fsl.ImageMeants(show_all = True,
#                                out_file = 'ROI_voxel-contrasts_RightPutamen.txt'),
#                name = 'get_voxRput')

# #Extract voxel values from qT1 beneath overlaid mask - Right Putamen
# get_voxLput = Node(fsl.ImageMeants(show_all = True,
#                                out_file = 'ROI_voxel-contrasts_LeftPutamen.txt'),
#                name = 'get_voxLput')

# %%
# #Extract voxel values from qT1 beneath overlaid mask - Left NAcc
# get_voxRnacc = Node(fsl.ImageMeants(show_all = True,
#                                out_file = 'ROI_voxel-contrasts_RightNAcc.txt'),
#                name = 'get_voxRnacc')

# #Extract voxel values from qT1 beneath overlaid mask - Right NAcc
# get_voxLnacc = Node(fsl.ImageMeants(show_all = True,
#                                out_file = 'ROI_voxel-contrasts_LeftNAcc.txt'),
#                name = 'get_voxLnacc')

# %%
# #Extract voxel values from qT1 beneath overlaid mask - Left Caudate
# get_voxRcaud = Node(fsl.ImageMeants(show_all = True,
#                                out_file = 'ROI_voxel-contrasts_RightCaudate.txt'),
#                name = 'get_voxRcaud')

# #Extract voxel values from qT1 beneath overlaid mask - Right Caudate
# get_voxLcaud = Node(fsl.ImageMeants(show_all = True,
#                                out_file = 'ROI_voxel-contrasts_LeftCaudate.txt'),
#                name = 'get_voxLcaud')

# %%
# #Register qT1 to T1w
# register_qt12 = Node(fsl.FLIRT(out_file = 'registered_qT1_toFreesurfer.nii.gz',
#                               output_type = 'NIFTI_GZ',
#                               out_matrix_file = 'flirt_transform_qt1.mat'),
#                     name = 'register_qt12')

# %%
# hippdata_flow = Workflow(name='hippdata_flow')
# hippdata_flow.connect([(infosource, sf3, [('subject_id', 'subject_id')]),
#                        (sf3, register_qt12, [('qt1_reor', 'in_file')]),
#                        (sf3, register_qt12, [('t1w', 'reference')]),
#                        (sf3, extract_lhipp, [('aseg', 'in_file')]),
#                        (sf3, extract_rhipp, [('aseg', 'in_file')]),
#                        (sf3, extract_lamyg, [('aseg', 'in_file')]),
#                        (sf3, extract_ramyg, [('aseg', 'in_file')]),
#                        (sf3, extract_lput, [('aseg', 'in_file')]),
#                        (sf3, extract_rput, [('aseg', 'in_file')]),
#                        (sf3, extract_lnacc, [('aseg', 'in_file')]),
#                        (sf3, extract_rnacc, [('aseg', 'in_file')]),
#                        (sf3, extract_lcaud, [('aseg', 'in_file')]),
#                        (sf3, extract_rcaud, [('aseg', 'in_file')]),
#                        (extract_lhipp, datasink, [('out_file', '1_check_alignment')]),
#                        (extract_rhipp, datasink, [('out_file', '1_check_alignment.@par')]),
#                        (extract_lamyg, datasink, [('out_file', '1_check_alignment.@par.@par')]),
#                        (extract_ramyg, datasink, [('out_file', '1_check_alignment.@par.@par.@par')]),
#                        (extract_lput, datasink, [('out_file', '1_check_alignment.@par.@par.@par.@par')]),
#                        (extract_rput, datasink, [('out_file', '1_check_alignment.@par.@par.@par.@par.@par')]),
#                        (extract_lnacc, datasink, [('out_file', 
#                                                    '1_check_alignment.@par.@par.@par.@par.@par.@par')]),
#                        (extract_rnacc, datasink, [('out_file', 
#                                                    '1_check_alignment.@par.@par.@par.@par.@par.@par.@par')]),
#                        (extract_lcaud, datasink, [('out_file', 
#                                                    '1_check_alignment.@par.@par.@par.@par.@par.@par.@par.@par')]),
#                        (extract_rcaud, datasink, [('out_file', 
#                                                    '1_check_alignment.@par.@par.@par.@par.@par.@par.@par.@par.@par')]),
#                        (register_qt12, datasink,[('out_file', '1_check_alignment.@par.@par.@par.@par.@par.@par.@par.@par.@par.@par')]),
#                        (register_qt12, get_voxRhipp, [('out_file', 'in_file')]),
#                        (extract_rhipp, get_voxRhipp, [('out_file', 'mask')]),
#                        (register_qt12, get_voxLhipp, [('out_file', 'in_file')]),
#                        (extract_lhipp, get_voxLhipp, [('out_file', 'mask')]),
                       
#                        (register_qt12, get_voxRamyg, [('out_file', 'in_file')]),
#                        (extract_ramyg, get_voxRamyg, [('out_file', 'mask')]),
#                        (register_qt12, get_voxLamyg, [('out_file', 'in_file')]),
#                        (extract_lamyg, get_voxLamyg, [('out_file', 'mask')]),
                       
#                        (register_qt12, get_voxRput, [('out_file', 'in_file')]),
#                        (extract_rput, get_voxRput, [('out_file', 'mask')]),
#                        (register_qt12, get_voxLput, [('out_file', 'in_file')]),
#                        (extract_lput, get_voxLput, [('out_file', 'mask')]),
                       
#                        (register_qt12, get_voxRcaud, [('out_file', 'in_file')]),
#                        (extract_rcaud, get_voxRcaud, [('out_file', 'mask')]),
#                        (register_qt12, get_voxLcaud, [('out_file', 'in_file')]),
#                        (extract_lcaud, get_voxLcaud, [('out_file', 'mask')]),
                       
#                        (register_qt12, get_voxRnacc, [('out_file', 'in_file')]),
#                        (extract_rnacc, get_voxRnacc, [('out_file', 'mask')]),
#                        (register_qt12, get_voxLnacc, [('out_file', 'in_file')]),
#                        (extract_lnacc, get_voxLnacc, [('out_file', 'mask')]),
                       
#                        (get_voxLhipp, datasink, [('out_file', '2_Extracted_Stats')]),
#                        (get_voxRhipp, datasink, [('out_file', '2_Extracted_Stats.@par')]),
#                        (get_voxLamyg, datasink, [('out_file', '2_Extracted_Stats.@par.@par')]),
#                        (get_voxRamyg, datasink, [('out_file', '2_Extracted_Stats.@par.@par.@par')]),
#                        (get_voxLput, datasink, [('out_file', '2_Extracted_Stats.@par.@par.@par.@par')]),
#                        (get_voxRput, datasink, [('out_file', '2_Extracted_Stats.@par.@par.@par.@par.@par')]),
#                        (get_voxLnacc, datasink, [('out_file', '2_Extracted_Stats.@par.@par.@par.@par.@par.@par')]),
#                        (get_voxRnacc, datasink, [('out_file', '2_Extracted_Stats.@par.@par.@par.@par.@par.@par.@par')]),
#                        (get_voxLcaud, datasink, [('out_file', '2_Extracted_Stats.@par.@par.@par.@par.@par.@par.@par.@par')]),
#                        (get_voxRcaud, datasink, [('out_file', '2_Extracted_Stats.@par.@par.@par.@par.@par.@par.@par.@par.@par')])
#                       ])

# hippdata_flow.base_dir = workflow_dir
# hippdata_flow.write_graph(graph2use='flat')
# preproc = hippdata_flow.run('MultiProc', plugin_args={'n_procs': 4})
