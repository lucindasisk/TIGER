# %%
from nipype.interfaces.io import DataSink, SelectFiles, DataGrabber 
from nipype.interfaces.utility import IdentityInterface, Function    
from nipype.pipeline.engine import Node, Workflow, JoinNode, MapNode
from nipype.interfaces import fsl
from nipype.interfaces import freesurfer as fsr
from nipype.interfaces import brainsuite
from nipype.interfaces.io import SelectFiles, DataSink, DataGrabber
from shutil import copyfile
import pandas as pd
from glob import glob
from os.path import abspath, expanduser, join
from os import chdir, remove, getcwd
from nipype import config, logging
from datetime import date
today = str(date.today())
config.enable_debug_mode()

# %%
#Set variables
# subject_list = ['02-T2', '06-T1', '07-T2','08-T1', '09-T2', '10-T1', '11-T1', '12-T1', '13-T1', '15-T1', '16-T1', '17-T1',
#                 '18-T1', '19-T1', '20-T1', '21-T1', '22-T1', '23-T1', '24-T1', '29-T1', '30-T1', '31-T1', '32-T1',
#                 '35-T1', '36-T1', '37-T1', '38-T1', '40-T1', '102-T1', '103-T1', '104-T1', '105-T1', '106-T1', '107-T1', '108-T1', '109-T1',
#                 '110-T1', '111-T1']

#subject_list = ['08-T1']#, '20-T1','22-T1','29-T1','31-T1','35-T1']

home = '/Volumes/group/proc/TIGERanalysis'
fpath = join(home, 'qT1/subjDir')
workflow_dir = join(home, 'qT1/workflow')
data_dir = join(home, 'qT1/data')
data = '/Users/lucindasisk/Box/LS_Folders/TIGER_qT1_SOBP'

# subs = glob(data + '/*-*')
# subject_list = pd.Series(subs).str.replace(data + '/', '')
# subject_list

subs = pd.read_csv(home + '/qT1/scripts/qt1_sublist_03.31.20.txt', sep = ' ', header=None)
subject_list = subs[0].tolist()

#subject_list = ['097-T3']

# %%
#Setup Datasink, Infosource, Selectfiles

datasink = Node(DataSink(base_directory = data_dir),
                   name='datasink')

#Set infosource iterables
infosource = Node(IdentityInterface(fields=['subject_id']),
                  name="infosource")
infosource.iterables = [('subject_id', subject_list)]

#SelectFiles
template = dict(t1=fpath+'/{subject_id}/T1_acpc.nii.gz',
               qt1=data+'/{subject_id}/fw_qT1_t1fit_final.nii.gz')

sf = Node(SelectFiles(template, 
                      base_directory = fpath),
          name = 'sf')

# %%
#Skullstrip T1w image
stripT1 = Node(fsl.BET(out_file = 'T1_acpc_bet.nii.gz'),
             name = 'stripT1')

#Reorient qT1 to standard orientation
reorient = Node(fsl.Reorient2Std(out_file = 'reoriented_qT1.nii.gz',
                              output_type = 'NIFTI_GZ'),
                    name = 'reorient')

#Register qT1 to T1w
register_qt1 = Node(fsl.FLIRT(out_file = 'registered_qT1_T1acpc.nii.gz',
                              output_type = 'NIFTI_GZ',
                              out_matrix_file = 'flirt_transform_qt1.mat'),
                    name = 'register_qt1')

#Extract voxel values from qT1 beneath overlaid mask - Left Uncinate
get_voxLUF = Node(fsl.ImageMeants(show_all = True,
                               out_file = 'ROI_voxel-contrasts_LeftUncinate.txt'),
               name = 'get_voxLUF')

#Extract voxel values from qT1 beneath overlaid mask - Left Cingulum Cingulate
get_voxLCC = Node(fsl.ImageMeants(show_all = True,
                               out_file = 'ROI_voxel-contrasts_LeftCC.txt'),
               name = 'get_voxLCC')

#Extract voxel values from qT1 beneath overlaid mask - Right Uncinate
get_voxRUF = Node(fsl.ImageMeants(show_all = True,
                               out_file = 'ROI_voxel-contrasts_RightHipp.txt'),
               name = 'get_voxRUF')

#Extract voxel values from qT1 beneath overlaid mask - Right Cingulum Cingulate
get_voxRCC = Node(fsl.ImageMeants(show_all = True,
                               out_file = 'ROI_voxel-contrasts_LeftHipp.txt'),
               name = 'get_voxRCC')

# %%
qt1proc_flow = Workflow(name='qt1proc_flow')
qt1proc_flow.connect([(infosource, sf, [('subject_id', 'subject_id')]),
                      (sf, stripT1, [('t1', 'in_file')]),
                      (stripT1, datasink, [('out_file', '1_check_alignment')]),
                      (sf, reorient, [('qt1', 'in_file')]),
                      (reorient, datasink, [
                       ('out_file', '1_check_alignment.@par')]),
                      (reorient, register_qt1, [('out_file', 'in_file')]),
                      (stripT1, register_qt1, [('out_file', 'reference')]),
                      (register_qt1, datasink, [
                       ('out_file', '1_check_alignment.@par.@par')])
                      ])

qt1proc_flow.base_dir = workflow_dir
qt1proc_flow.write_graph(graph2use='flat')
preproc = qt1proc_flow.run('MultiProc', plugin_args={'n_procs': 4})

# %%
#SelectFiles
template2 = dict(qt1r=data_dir+'/1_check_alignment/_subject_id_{subject_id}/registered_qT1.nii.gz',
               unc_maskL = fpath+'/{subject_id}/Left_Uncinate.nii.gz',
               unc_maskR = fpath+'/{subject_id}/Right_Uncinate.nii.gz',
               cc_maskL = fpath+'/{subject_id}/Left_Cingulum_Cingulate.nii.gz',
               cc_maskR = fpath+'/{subject_id}/Right_Cingulum_Cingulate.nii.gz')

# 
#             bval=fpath+'/{subject_id}/dti.bval',
#             bvec=fpath+'/{subject_id}/dti.bvec'

sf2 = Node(SelectFiles(template2, 
                      base_directory = fpath),
          name = 'sf2')

# %%
get_stats=Workflow(name='get_stats')
get_stats.connect([(infosource, sf2, [('subject_id','subject_id')]),
                   (sf2, get_voxLUF, [('qt1r', 'in_file')]),
                   (sf2, get_voxLUF, [('unc_maskL', 'mask')]),
                   (get_voxLUF, datasink, [('out_file', '2_Extracted_Stats')]),
                   (sf2, get_voxLCC, [('qt1r', 'in_file')]),
                   (sf2, get_voxLCC, [('cc_maskL', 'mask')]),
                   (get_voxLCC, datasink, [('out_file', '2_Extracted_Stats.@par')]),
                   (sf2, get_voxRUF, [('qt1r', 'in_file')]),
                   (sf2, get_voxRUF, [('unc_maskR', 'mask')]),
                   (get_voxRUF, datasink, [('out_file', '2_Extracted_Stats.@par.@par')]),
                   (sf2, get_voxRCC, [('qt1r', 'in_file')]),
                   (sf2, get_voxRCC, [('cc_maskR', 'mask')]),
                   (get_voxRCC, datasink, [('out_file', '2_Extracted_Stats.@par.@par.@par')])
                  ])
get_stats.base_dir = workflow_dir
get_stats.write_graph(graph2use = 'flat')
preproc = get_stats.run('MultiProc', plugin_args={'n_procs': 4})

# %%
#SelectFiles
template3 = dict(t1w = home+'/TIGER_FreeSurfer/TIGER_FS_subjDir/{subject_id}/mri/brain.mgz',
                aseg = home + '/TIGER_FreeSurfer/TIGER_FS_subjDir/{subject_id}/mri/aparc.a2009s+aseg.mgz',
                qt1_reor = data_dir+'/1_check_alignment/_subject_id_{subject_id}/reoriented_qT1.nii.gz')       


sf3 = Node(SelectFiles(template3, 
                      base_directory = fpath),
          name = 'sf3')

# %%
#MRI Convert Nodes
convert_wb = Node(fsr.MRIConvert(in_type='mgz',
                               out_file = 'brain.nii.gz'),
               name = 'convert_wb')

convert_aseg = Node(fsr.MRIConvert(in_type='mgz',
                               out_file = 'aparc.a2009s+aseg.nii.gz'),
               name = 'convert_aseg')

# %%
#Extract left hippocampus - seg value 17
extract_lhipp = Node(fsl.Threshold(thresh = 16.5, 
                                   direction = 'below', 
                                   args = '-uthr 17.5',
                                   output_type = 'NIFTI_GZ',
                                   out_file = 'left_hippocampus.nii.gz'),
                        name = 'extract_lhipp')
#Extract right hippocampus - seg value 53
extract_rhipp = Node(fsl.Threshold(thresh = 52.5, 
                                   direction = 'below', 
                                   args = '-uthr 53.5',
                                   output_type = 'NIFTI_GZ',
                                   out_file = 'right_hippocampus.nii.gz'),
                    name='extract_rhipp')

# %%
#Extract left amygdala - seg value 18
extract_lamyg = Node(fsl.Threshold(thresh = 17.5, 
                                   direction = 'below', 
                                   args = '-uthr 18.5',
                                   output_type = 'NIFTI_GZ',
                                   out_file = 'left_amygdala.nii.gz'),
                        name = 'extract_lamyg')
#Extract right amygdala - seg value 54
extract_ramyg = Node(fsl.Threshold(thresh = 53.5, 
                                   direction = 'below', 
                                   args = '-uthr 54.5',
                                   output_type = 'NIFTI_GZ',
                                   out_file = 'right_amygdala.nii.gz'),
                    name='extract_ramyg')

# %%
#Extract left caudate - seg value 11
extract_lcaud = Node(fsl.Threshold(thresh = 10.5, 
                                   direction = 'below', 
                                   args = '-uthr 11.5',
                                   output_type = 'NIFTI_GZ',
                                   out_file = 'left_caudate.nii.gz'),
                        name = 'extract_lcaud')

#Extract right caudate - seg value 50
extract_rcaud = Node(fsl.Threshold(thresh = 49.5, 
                                   direction = 'below', 
                                   args = '-uthr 50.5',
                                   output_type = 'NIFTI_GZ',
                                   out_file = 'right_caudate.nii.gz'),
                    name='extract_rcaud')

# %%
#Extract left nucleus accumbens - seg value 26
extract_lnacc  = Node(fsl.Threshold(thresh = 25.5, 
                                   direction = 'below', 
                                   args = '-uthr 26.5',
                                   output_type = 'NIFTI_GZ',
                                   out_file = 'left_nAcc.nii.gz'),
                        name = 'extract_lnacc')

#Extract right caudate - seg value 58
extract_rnacc = Node(fsl.Threshold(thresh = 57.5, 
                                   direction = 'below', 
                                   args = '-uthr 58.5',
                                   output_type = 'NIFTI_GZ',
                                   out_file = 'right_nAcc.nii.gz'),
                    name='extract_rnacc')

# %%
#Extract left putamen - seg value 26
extract_lput  = Node(fsl.Threshold(thresh = 11.5, 
                                   direction = 'below', 
                                   args = '-uthr 12.5',
                                   output_type = 'NIFTI_GZ',
                                   out_file = 'left_putamen.nii.gz'),
                        name = 'extract_lput')

#Extract right caudate - seg value 51
extract_rput = Node(fsl.Threshold(thresh = 50.5, 
                                   direction = 'below', 
                                   args = '-uthr 51.5',
                                   output_type = 'NIFTI_GZ',
                                   out_file = 'right_putamen.nii.gz'),
                    name='extract_rput')

# %%
#Extract voxel values from qT1 beneath overlaid mask - Left Hippocampus
get_voxRhipp = Node(fsl.ImageMeants(show_all = True,
                               out_file = 'ROI_voxel-contrasts_RightHippocampus.txt'),
               name = 'get_voxRhipp')

#Extract voxel values from qT1 beneath overlaid mask - Right Hippocampus
get_voxLhipp = Node(fsl.ImageMeants(show_all = True,
                               out_file = 'ROI_voxel-contrasts_LeftHippocampus.txt'),
               name = 'get_voxLhipp')

# %%
#Extract voxel values from qT1 beneath overlaid mask - Left Amygdala
get_voxRamyg = Node(fsl.ImageMeants(show_all = True,
                               out_file = 'ROI_voxel-contrasts_RightAmygdala.txt'),
               name = 'get_voxRamyg')

#Extract voxel values from qT1 beneath overlaid mask - Right Amygdala
get_voxLamyg = Node(fsl.ImageMeants(show_all = True,
                               out_file = 'ROI_voxel-contrasts_LeftAmygdala.txt'),
               name = 'get_voxLamyg')

# %%
#Extract voxel values from qT1 beneath overlaid mask - Left Putamen
get_voxRput = Node(fsl.ImageMeants(show_all = True,
                               out_file = 'ROI_voxel-contrasts_RightPutamen.txt'),
               name = 'get_voxRput')

#Extract voxel values from qT1 beneath overlaid mask - Right Putamen
get_voxLput = Node(fsl.ImageMeants(show_all = True,
                               out_file = 'ROI_voxel-contrasts_LeftPutamen.txt'),
               name = 'get_voxLput')

# %%
#Extract voxel values from qT1 beneath overlaid mask - Left NAcc
get_voxRnacc = Node(fsl.ImageMeants(show_all = True,
                               out_file = 'ROI_voxel-contrasts_RightNAcc.txt'),
               name = 'get_voxRnacc')

#Extract voxel values from qT1 beneath overlaid mask - Right NAcc
get_voxLnacc = Node(fsl.ImageMeants(show_all = True,
                               out_file = 'ROI_voxel-contrasts_LeftNAcc.txt'),
               name = 'get_voxLnacc')

# %%
#Extract voxel values from qT1 beneath overlaid mask - Left Caudate
get_voxRcaud = Node(fsl.ImageMeants(show_all = True,
                               out_file = 'ROI_voxel-contrasts_RightCaudate.txt'),
               name = 'get_voxRcaud')

#Extract voxel values from qT1 beneath overlaid mask - Right Caudate
get_voxLcaud = Node(fsl.ImageMeants(show_all = True,
                               out_file = 'ROI_voxel-contrasts_LeftCaudate.txt'),
               name = 'get_voxLcaud')

# %%
#Reorient qT1 to standard orientation
reorient2 = Node(fsl.Reorient2Std(out_file = 'reoriented_qT1.nii.gz',
                              output_type = 'NIFTI_GZ'),
                    name = 'reorient2')
#Register qT1 to T1w
register_qt12 = Node(fsl.FLIRT(out_file = 'registered_qT1_toFreesurfer.nii.gz',
                              output_type = 'NIFTI_GZ',
                              out_matrix_file = 'flirt_transform_qt1.mat'),
                    name = 'register_qt12')

# %%
hippdata_flow = Workflow(name='hippdata_flow')
hippdata_flow.connect([(infosource, sf3, [('subject_id', 'subject_id')]),
                       (sf3, convert_wb, [('t1w', 'in_file')]),
                       (sf3, convert_aseg, [('aseg', 'in_file')]),
                       (sf3, register_qt12, [('qt1_reor', 'in_file')]),
                       (convert_wb, register_qt12, [('out_file', 'reference')]),
                       (convert_aseg, extract_lhipp, [('out_file', 'in_file')]),
                       (convert_aseg, extract_rhipp, [('out_file', 'in_file')]),
                       (convert_aseg, extract_lamyg, [('out_file', 'in_file')]),
                       (convert_aseg, extract_ramyg, [('out_file', 'in_file')]),
                       (convert_aseg, extract_lput, [('out_file', 'in_file')]),
                       (convert_aseg, extract_rput, [('out_file', 'in_file')]),
                       (convert_aseg, extract_lnacc, [('out_file', 'in_file')]),
                       (convert_aseg, extract_rnacc, [('out_file', 'in_file')]),
                       (convert_aseg, extract_lcaud, [('out_file', 'in_file')]),
                       (convert_aseg, extract_rcaud, [('out_file', 'in_file')]),
                       (extract_lhipp, datasink, [('out_file', '1_check_alignment')]),
                       (extract_rhipp, datasink, [('out_file', '1_check_alignment.@par')]),
                       (extract_lamyg, datasink, [('out_file', '1_check_alignment.@par.@par')]),
                       (extract_ramyg, datasink, [('out_file', '1_check_alignment.@par.@par.@par')]),
                       (extract_lput, datasink, [('out_file', '1_check_alignment.@par.@par.@par.@par')]),
                       (extract_rput, datasink, [('out_file', '1_check_alignment.@par.@par.@par.@par.@par')]),
                       (extract_lnacc, datasink, [('out_file', 
                                                   '1_check_alignment.@par.@par.@par.@par.@par.@par')]),
                       (extract_rnacc, datasink, [('out_file', 
                                                   '1_check_alignment.@par.@par.@par.@par.@par.@par.@par')]),
                       (extract_lcaud, datasink, [('out_file', 
                                                   '1_check_alignment.@par.@par.@par.@par.@par.@par.@par.@par')]),
                       (extract_rcaud, datasink, [('out_file', 
                                                   '1_check_alignment.@par.@par.@par.@par.@par.@par.@par.@par.@par')]),
                       (register_qt12, datasink,[('out_file', '1_check_alignment.@par.@par.@par.@par.@par.@par.@par.@par.@par.@par')]),
                       (register_qt12, get_voxRhipp, [('out_file', 'in_file')]),
                       (extract_rhipp, get_voxRhipp, [('out_file', 'mask')]),
                       (register_qt12, get_voxLhipp, [('out_file', 'in_file')]),
                       (extract_lhipp, get_voxLhipp, [('out_file', 'mask')]),
                       
                       (register_qt12, get_voxRamyg, [('out_file', 'in_file')]),
                       (extract_ramyg, get_voxRamyg, [('out_file', 'mask')]),
                       (register_qt12, get_voxLamyg, [('out_file', 'in_file')]),
                       (extract_lamyg, get_voxLamyg, [('out_file', 'mask')]),
                       
                       (register_qt12, get_voxRput, [('out_file', 'in_file')]),
                       (extract_rput, get_voxRput, [('out_file', 'mask')]),
                       (register_qt12, get_voxLput, [('out_file', 'in_file')]),
                       (extract_lput, get_voxLput, [('out_file', 'mask')]),
                       
                       (register_qt12, get_voxRcaud, [('out_file', 'in_file')]),
                       (extract_rcaud, get_voxRcaud, [('out_file', 'mask')]),
                       (register_qt12, get_voxLcaud, [('out_file', 'in_file')]),
                       (extract_lcaud, get_voxLcaud, [('out_file', 'mask')]),
                       
                       (register_qt12, get_voxRnacc, [('out_file', 'in_file')]),
                       (extract_rnacc, get_voxRnacc, [('out_file', 'mask')]),
                       (register_qt12, get_voxLnacc, [('out_file', 'in_file')]),
                       (extract_lnacc, get_voxLnacc, [('out_file', 'mask')]),
                       
                       (get_voxLhipp, datasink, [('out_file', '2_Extracted_Stats')]),
                       (get_voxRhipp, datasink, [('out_file', '2_Extracted_Stats.@par')]),
                       (get_voxLamyg, datasink, [('out_file', '2_Extracted_Stats.@par.@par')]),
                       (get_voxRamyg, datasink, [('out_file', '2_Extracted_Stats.@par.@par.@par')]),
                       (get_voxLput, datasink, [('out_file', '2_Extracted_Stats.@par.@par.@par.@par')]),
                       (get_voxRput, datasink, [('out_file', '2_Extracted_Stats.@par.@par.@par.@par.@par')]),
                       (get_voxLnacc, datasink, [('out_file', '2_Extracted_Stats.@par.@par.@par.@par.@par.@par')]),
                       (get_voxRnacc, datasink, [('out_file', '2_Extracted_Stats.@par.@par.@par.@par.@par.@par.@par')]),
                       (get_voxLcaud, datasink, [('out_file', '2_Extracted_Stats.@par.@par.@par.@par.@par.@par.@par.@par')]),
                       (get_voxRcaud, datasink, [('out_file', '2_Extracted_Stats.@par.@par.@par.@par.@par.@par.@par.@par.@par')])
                      ])

hippdata_flow.base_dir = workflow_dir
hippdata_flow.write_graph(graph2use='flat')
preproc = hippdata_flow.run('MultiProc', plugin_args={'n_procs': 4})
# Out:
# 200331-19:38:23,26 nipype.workflow DEBUG:
# 	 (hippdata_flow.infosource, hippdata_flow.sf3): No edge data
# 200331-19:38:23,27 nipype.workflow DEBUG:
# 	 (hippdata_flow.infosource, hippdata_flow.sf3): new edge data: {'connect': [('subject_id', 'subject_id')]}
# 200331-19:38:23,28 nipype.workflow DEBUG:
# 	 (hippdata_flow.sf3, hippdata_flow.convert_wb): No edge data
# 200331-19:38:23,29 nipype.workflow DEBUG:
# 	 (hippdata_flow.sf3, hippdata_flow.convert_wb): new edge data: {'connect': [('t1w', 'in_file')]}
# 200331-19:38:23,30 nipype.workflow DEBUG:
# 	 (hippdata_flow.sf3, hippdata_flow.convert_aseg): No edge data
# 200331-19:38:23,31 nipype.workflow DEBUG:
# 	 (hippdata_flow.sf3, hippdata_flow.convert_aseg): new edge data: {'connect': [('aseg', 'in_file')]}
# 200331-19:38:23,32 nipype.workflow DEBUG:
# 	 (hippdata_flow.sf3, hippdata_flow.register_qt12): No edge data
# 200331-19:38:23,33 nipype.workflow DEBUG:
# 	 (hippdata_flow.sf3, hippdata_flow.register_qt12): new edge data: {'connect': [('qt1_reor', 'in_file')]}
# 200331-19:38:23,34 nipype.workflow DEBUG:
# 	 (hippdata_flow.convert_wb, hippdata_flow.register_qt12): No edge data
# 200331-19:38:23,35 nipype.workflow DEBUG:
# 	 (hippdata_flow.convert_wb, hippdata_flow.register_qt12): new edge data: {'connect': [('out_file', 'reference')]}
# 200331-19:38:23,36 nipype.workflow DEBUG:
# 	 (hippdata_flow.convert_aseg, hippdata_flow.extract_lhipp): No edge data
# 200331-19:38:23,37 nipype.workflow DEBUG:
# 	 (hippdata_flow.convert_aseg, hippdata_flow.extract_lhipp): new edge data: {'connect': [('out_file', 'in_file')]}
# 200331-19:38:23,37 nipype.workflow DEBUG:
# 	 (hippdata_flow.convert_aseg, hippdata_flow.extract_rhipp): No edge data
# 200331-19:38:23,38 nipype.workflow DEBUG:
# 	 (hippdata_flow.convert_aseg, hippdata_flow.extract_rhipp): new edge data: {'connect': [('out_file', 'in_file')]}
# 200331-19:38:23,39 nipype.workflow DEBUG:
# 	 (hippdata_flow.convert_aseg, hippdata_flow.extract_lamyg): No edge data
# 200331-19:38:23,39 nipype.workflow DEBUG:
# 	 (hippdata_flow.convert_aseg, hippdata_flow.extract_lamyg): new edge data: {'connect': [('out_file', 'in_file')]}
# 200331-19:38:23,40 nipype.workflow DEBUG:
# 	 (hippdata_flow.convert_aseg, hippdata_flow.extract_ramyg): No edge data
# 200331-19:38:23,41 nipype.workflow DEBUG:
# 	 (hippdata_flow.convert_aseg, hippdata_flow.extract_ramyg): new edge data: {'connect': [('out_file', 'in_file')]}
# 200331-19:38:23,42 nipype.workflow DEBUG:
# 	 (hippdata_flow.convert_aseg, hippdata_flow.extract_lput): No edge data
# 200331-19:38:23,42 nipype.workflow DEBUG:
# 	 (hippdata_flow.convert_aseg, hippdata_flow.extract_lput): new edge data: {'connect': [('out_file', 'in_file')]}
# 200331-19:38:23,43 nipype.workflow DEBUG:
# 	 (hippdata_flow.convert_aseg, hippdata_flow.extract_rput): No edge data
# 200331-19:38:23,44 nipype.workflow DEBUG:
# 	 (hippdata_flow.convert_aseg, hippdata_flow.extract_rput): new edge data: {'connect': [('out_file', 'in_file')]}
# 200331-19:38:23,44 nipype.workflow DEBUG:
# 	 (hippdata_flow.convert_aseg, hippdata_flow.extract_lnacc): No edge data
# 200331-19:38:23,45 nipype.workflow DEBUG:
# 	 (hippdata_flow.convert_aseg, hippdata_flow.extract_lnacc): new edge data: {'connect': [('out_file', 'in_file')]}
# 200331-19:38:23,46 nipype.workflow DEBUG:
# 	 (hippdata_flow.convert_aseg, hippdata_flow.extract_rnacc): No edge data
# 200331-19:38:23,46 nipype.workflow DEBUG:
# 	 (hippdata_flow.convert_aseg, hippdata_flow.extract_rnacc): new edge data: {'connect': [('out_file', 'in_file')]}
# 200331-19:38:23,47 nipype.workflow DEBUG:
# 	 (hippdata_flow.convert_aseg, hippdata_flow.extract_lcaud): No edge data
# 200331-19:38:23,48 nipype.workflow DEBUG:
# 	 (hippdata_flow.convert_aseg, hippdata_flow.extract_lcaud): new edge data: {'connect': [('out_file', 'in_file')]}
# 200331-19:38:23,48 nipype.workflow DEBUG:
# 	 (hippdata_flow.convert_aseg, hippdata_flow.extract_rcaud): No edge data
# 200331-19:38:23,49 nipype.workflow DEBUG:
# 	 (hippdata_flow.convert_aseg, hippdata_flow.extract_rcaud): new edge data: {'connect': [('out_file', 'in_file')]}
# 200331-19:38:23,50 nipype.workflow DEBUG:
# 	 (hippdata_flow.extract_lhipp, hippdata_flow.datasink): No edge data
# 200331-19:38:23,51 nipype.workflow DEBUG:
# 	 (hippdata_flow.extract_lhipp, hippdata_flow.datasink): new edge data: {'connect': [('out_file', '1_check_alignment')]}
# 200331-19:38:23,52 nipype.workflow DEBUG:
# 	 (hippdata_flow.extract_rhipp, hippdata_flow.datasink): No edge data
# 200331-19:38:23,53 nipype.workflow DEBUG:
# 	 (hippdata_flow.extract_rhipp, hippdata_flow.datasink): new edge data: {'connect': [('out_file', '1_check_alignment.@par')]}
# 200331-19:38:23,54 nipype.workflow DEBUG:
# 	 (hippdata_flow.extract_lamyg, hippdata_flow.datasink): No edge data
# 200331-19:38:23,54 nipype.workflow DEBUG:
# 	 (hippdata_flow.extract_lamyg, hippdata_flow.datasink): new edge data: {'connect': [('out_file', '1_check_alignment.@par.@par')]}
# 200331-19:38:23,58 nipype.workflow DEBUG:
# 	 (hippdata_flow.extract_ramyg, hippdata_flow.datasink): No edge data
# 200331-19:38:23,59 nipype.workflow DEBUG:
# 	 (hippdata_flow.extract_ramyg, hippdata_flow.datasink): new edge data: {'connect': [('out_file', '1_check_alignment.@par.@par.@par')]}
# 200331-19:38:23,60 nipype.workflow DEBUG:
# 	 (hippdata_flow.extract_lput, hippdata_flow.datasink): No edge data
# 200331-19:38:23,61 nipype.workflow DEBUG:
# 	 (hippdata_flow.extract_lput, hippdata_flow.datasink): new edge data: {'connect': [('out_file', '1_check_alignment.@par.@par.@par.@par')]}
# 200331-19:38:23,62 nipype.workflow DEBUG:
# 	 (hippdata_flow.extract_rput, hippdata_flow.datasink): No edge data
# 200331-19:38:23,63 nipype.workflow DEBUG:
# 	 (hippdata_flow.extract_rput, hippdata_flow.datasink): new edge data: {'connect': [('out_file', '1_check_alignment.@par.@par.@par.@par.@par')]}
# 200331-19:38:23,64 nipype.workflow DEBUG:
# 	 (hippdata_flow.extract_lnacc, hippdata_flow.datasink): No edge data
# 200331-19:38:23,65 nipype.workflow DEBUG:
# 	 (hippdata_flow.extract_lnacc, hippdata_flow.datasink): new edge data: {'connect': [('out_file', '1_check_alignment.@par.@par.@par.@par.@par.@par')]}
# 200331-19:38:23,66 nipype.workflow DEBUG:
# 	 (hippdata_flow.extract_rnacc, hippdata_flow.datasink): No edge data
# 200331-19:38:23,66 nipype.workflow DEBUG:
# 	 (hippdata_flow.extract_rnacc, hippdata_flow.datasink): new edge data: {'connect': [('out_file', '1_check_alignment.@par.@par.@par.@par.@par.@par.@par')]}
# 200331-19:38:23,67 nipype.workflow DEBUG:
# 	 (hippdata_flow.extract_lcaud, hippdata_flow.datasink): No edge data
# 200331-19:38:23,68 nipype.workflow DEBUG:
# 	 (hippdata_flow.extract_lcaud, hippdata_flow.datasink): new edge data: {'connect': [('out_file', '1_check_alignment.@par.@par.@par.@par.@par.@par.@par.@par')]}
# 200331-19:38:23,69 nipype.workflow DEBUG:
# 	 (hippdata_flow.extract_rcaud, hippdata_flow.datasink): No edge data
# 200331-19:38:23,70 nipype.workflow DEBUG:
# 	 (hippdata_flow.extract_rcaud, hippdata_flow.datasink): new edge data: {'connect': [('out_file', '1_check_alignment.@par.@par.@par.@par.@par.@par.@par.@par.@par')]}
# 200331-19:38:23,70 nipype.workflow DEBUG:
# 	 (hippdata_flow.register_qt12, hippdata_flow.datasink): No edge data
# 200331-19:38:23,71 nipype.workflow DEBUG:
# 	 (hippdata_flow.register_qt12, hippdata_flow.datasink): new edge data: {'connect': [('out_file', '1_check_alignment.@par.@par.@par.@par.@par.@par.@par.@par.@par.@par')]}
# 200331-19:38:23,71 nipype.workflow DEBUG:
# 	 (hippdata_flow.register_qt12, hippdata_flow.get_voxRhipp): No edge data
# 200331-19:38:23,72 nipype.workflow DEBUG:
# 	 (hippdata_flow.register_qt12, hippdata_flow.get_voxRhipp): new edge data: {'connect': [('out_file', 'in_file')]}
# 200331-19:38:23,73 nipype.workflow DEBUG:
# 	 (hippdata_flow.extract_rhipp, hippdata_flow.get_voxRhipp): No edge data
# 200331-19:38:23,74 nipype.workflow DEBUG:
# 	 (hippdata_flow.extract_rhipp, hippdata_flow.get_voxRhipp): new edge data: {'connect': [('out_file', 'mask')]}
# 200331-19:38:23,74 nipype.workflow DEBUG:
# 	 (hippdata_flow.register_qt12, hippdata_flow.get_voxLhipp): No edge data
# 200331-19:38:23,75 nipype.workflow DEBUG:
# 	 (hippdata_flow.register_qt12, hippdata_flow.get_voxLhipp): new edge data: {'connect': [('out_file', 'in_file')]}
# 200331-19:38:23,76 nipype.workflow DEBUG:
# 	 (hippdata_flow.extract_lhipp, hippdata_flow.get_voxLhipp): No edge data
# 200331-19:38:23,76 nipype.workflow DEBUG:
# 	 (hippdata_flow.extract_lhipp, hippdata_flow.get_voxLhipp): new edge data: {'connect': [('out_file', 'mask')]}
# 200331-19:38:23,77 nipype.workflow DEBUG:
# 	 (hippdata_flow.register_qt12, hippdata_flow.get_voxRamyg): No edge data
# 200331-19:38:23,78 nipype.workflow DEBUG:
# 	 (hippdata_flow.register_qt12, hippdata_flow.get_voxRamyg): new edge data: {'connect': [('out_file', 'in_file')]}
# 200331-19:38:23,78 nipype.workflow DEBUG:
# 	 (hippdata_flow.extract_ramyg, hippdata_flow.get_voxRamyg): No edge data
# 200331-19:38:23,79 nipype.workflow DEBUG:
# 	 (hippdata_flow.extract_ramyg, hippdata_flow.get_voxRamyg): new edge data: {'connect': [('out_file', 'mask')]}
# 200331-19:38:23,79 nipype.workflow DEBUG:
# 	 (hippdata_flow.register_qt12, hippdata_flow.get_voxLamyg): No edge data
# 200331-19:38:23,80 nipype.workflow DEBUG:
# 	 (hippdata_flow.register_qt12, hippdata_flow.get_voxLamyg): new edge data: {'connect': [('out_file', 'in_file')]}
# 200331-19:38:23,80 nipype.workflow DEBUG:
# 	 (hippdata_flow.extract_lamyg, hippdata_flow.get_voxLamyg): No edge data
# 200331-19:38:23,81 nipype.workflow DEBUG:
# 	 (hippdata_flow.extract_lamyg, hippdata_flow.get_voxLamyg): new edge data: {'connect': [('out_file', 'mask')]}
# 200331-19:38:23,82 nipype.workflow DEBUG:
# 	 (hippdata_flow.register_qt12, hippdata_flow.get_voxRput): No edge data
# 200331-19:38:23,82 nipype.workflow DEBUG:
# 	 (hippdata_flow.register_qt12, hippdata_flow.get_voxRput): new edge data: {'connect': [('out_file', 'in_file')]}
# 200331-19:38:23,83 nipype.workflow DEBUG:
# 	 (hippdata_flow.extract_rput, hippdata_flow.get_voxRput): No edge data
# 200331-19:38:23,83 nipype.workflow DEBUG:
# 	 (hippdata_flow.extract_rput, hippdata_flow.get_voxRput): new edge data: {'connect': [('out_file', 'mask')]}
# 200331-19:38:23,84 nipype.workflow DEBUG:
# 	 (hippdata_flow.register_qt12, hippdata_flow.get_voxLput): No edge data
# 200331-19:38:23,84 nipype.workflow DEBUG:
# 	 (hippdata_flow.register_qt12, hippdata_flow.get_voxLput): new edge data: {'connect': [('out_file', 'in_file')]}
# 200331-19:38:23,85 nipype.workflow DEBUG:
# 	 (hippdata_flow.extract_lput, hippdata_flow.get_voxLput): No edge data
# 200331-19:38:23,85 nipype.workflow DEBUG:
# 	 (hippdata_flow.extract_lput, hippdata_flow.get_voxLput): new edge data: {'connect': [('out_file', 'mask')]}
# 200331-19:38:23,86 nipype.workflow DEBUG:
# 	 (hippdata_flow.register_qt12, hippdata_flow.get_voxRcaud): No edge data
# 200331-19:38:23,87 nipype.workflow DEBUG:
# 	 (hippdata_flow.register_qt12, hippdata_flow.get_voxRcaud): new edge data: {'connect': [('out_file', 'in_file')]}
# 200331-19:38:23,88 nipype.workflow DEBUG:
# 	 (hippdata_flow.extract_rcaud, hippdata_flow.get_voxRcaud): No edge data
# 200331-19:38:23,88 nipype.workflow DEBUG:
# 	 (hippdata_flow.extract_rcaud, hippdata_flow.get_voxRcaud): new edge data: {'connect': [('out_file', 'mask')]}
# 200331-19:38:23,89 nipype.workflow DEBUG:
# 	 (hippdata_flow.register_qt12, hippdata_flow.get_voxLcaud): No edge data
# 200331-19:38:23,89 nipype.workflow DEBUG:
# 	 (hippdata_flow.register_qt12, hippdata_flow.get_voxLcaud): new edge data: {'connect': [('out_file', 'in_file')]}
# 200331-19:38:23,90 nipype.workflow DEBUG:
# 	 (hippdata_flow.extract_lcaud, hippdata_flow.get_voxLcaud): No edge data
# 200331-19:38:23,90 nipype.workflow DEBUG:
# 	 (hippdata_flow.extract_lcaud, hippdata_flow.get_voxLcaud): new edge data: {'connect': [('out_file', 'mask')]}
# 200331-19:38:23,91 nipype.workflow DEBUG:
# 	 (hippdata_flow.register_qt12, hippdata_flow.get_voxRnacc): No edge data
# 200331-19:38:23,91 nipype.workflow DEBUG:
# 	 (hippdata_flow.register_qt12, hippdata_flow.get_voxRnacc): new edge data: {'connect': [('out_file', 'in_file')]}
# 200331-19:38:23,92 nipype.workflow DEBUG:
# 	 (hippdata_flow.extract_rnacc, hippdata_flow.get_voxRnacc): No edge data
# 200331-19:38:23,92 nipype.workflow DEBUG:
# 	 (hippdata_flow.extract_rnacc, hippdata_flow.get_voxRnacc): new edge data: {'connect': [('out_file', 'mask')]}
# 200331-19:38:23,93 nipype.workflow DEBUG:
# 	 (hippdata_flow.register_qt12, hippdata_flow.get_voxLnacc): No edge data
# 200331-19:38:23,93 nipype.workflow DEBUG:
# 	 (hippdata_flow.register_qt12, hippdata_flow.get_voxLnacc): new edge data: {'connect': [('out_file', 'in_file')]}
# 200331-19:38:23,94 nipype.workflow DEBUG:
# 	 (hippdata_flow.extract_lnacc, hippdata_flow.get_voxLnacc): No edge data
# 200331-19:38:23,95 nipype.workflow DEBUG:
# 	 (hippdata_flow.extract_lnacc, hippdata_flow.get_voxLnacc): new edge data: {'connect': [('out_file', 'mask')]}
# 200331-19:38:23,95 nipype.workflow DEBUG:
# 	 (hippdata_flow.get_voxLhipp, hippdata_flow.datasink): No edge data
# 200331-19:38:23,96 nipype.workflow DEBUG:
# 	 (hippdata_flow.get_voxLhipp, hippdata_flow.datasink): new edge data: {'connect': [('out_file', '2_Extracted_Stats')]}
# 200331-19:38:23,96 nipype.workflow DEBUG:
# 	 (hippdata_flow.get_voxRhipp, hippdata_flow.datasink): No edge data
# 200331-19:38:23,97 nipype.workflow DEBUG:
# 	 (hippdata_flow.get_voxRhipp, hippdata_flow.datasink): new edge data: {'connect': [('out_file', '2_Extracted_Stats.@par')]}
# 200331-19:38:23,97 nipype.workflow DEBUG:
# 	 (hippdata_flow.get_voxLamyg, hippdata_flow.datasink): No edge data
# 200331-19:38:23,98 nipype.workflow DEBUG:
# 	 (hippdata_flow.get_voxLamyg, hippdata_flow.datasink): new edge data: {'connect': [('out_file', '2_Extracted_Stats.@par.@par')]}
# 200331-19:38:23,98 nipype.workflow DEBUG:
# 	 (hippdata_flow.get_voxRamyg, hippdata_flow.datasink): No edge data
# 200331-19:38:23,99 nipype.workflow DEBUG:
# 	 (hippdata_flow.get_voxRamyg, hippdata_flow.datasink): new edge data: {'connect': [('out_file', '2_Extracted_Stats.@par.@par.@par')]}
# 200331-19:38:23,100 nipype.workflow DEBUG:
# 	 (hippdata_flow.get_voxLput, hippdata_flow.datasink): No edge data
# 200331-19:38:23,100 nipype.workflow DEBUG:
# 	 (hippdata_flow.get_voxLput, hippdata_flow.datasink): new edge data: {'connect': [('out_file', '2_Extracted_Stats.@par.@par.@par.@par')]}
# 200331-19:38:23,101 nipype.workflow DEBUG:
# 	 (hippdata_flow.get_voxRput, hippdata_flow.datasink): No edge data
# 200331-19:38:23,101 nipype.workflow DEBUG:
# 	 (hippdata_flow.get_voxRput, hippdata_flow.datasink): new edge data: {'connect': [('out_file', '2_Extracted_Stats.@par.@par.@par.@par.@par')]}
# 200331-19:38:23,102 nipype.workflow DEBUG:
# 	 (hippdata_flow.get_voxLnacc, hippdata_flow.datasink): No edge data
# 200331-19:38:23,102 nipype.workflow DEBUG:
# 	 (hippdata_flow.get_voxLnacc, hippdata_flow.datasink): new edge data: {'connect': [('out_file', '2_Extracted_Stats.@par.@par.@par.@par.@par.@par')]}
# 200331-19:38:23,103 nipype.workflow DEBUG:
# 	 (hippdata_flow.get_voxRnacc, hippdata_flow.datasink): No edge data
# 200331-19:38:23,104 nipype.workflow DEBUG:
# 	 (hippdata_flow.get_voxRnacc, hippdata_flow.datasink): new edge data: {'connect': [('out_file', '2_Extracted_Stats.@par.@par.@par.@par.@par.@par.@par')]}
# 200331-19:38:23,104 nipype.workflow DEBUG:
# 	 (hippdata_flow.get_voxLcaud, hippdata_flow.datasink): No edge data
# 200331-19:38:23,105 nipype.workflow DEBUG:
# 	 (hippdata_flow.get_voxLcaud, hippdata_flow.datasink): new edge data: {'connect': [('out_file', '2_Extracted_Stats.@par.@par.@par.@par.@par.@par.@par.@par')]}
# 200331-19:38:23,105 nipype.workflow DEBUG:
# 	 (hippdata_flow.get_voxRcaud, hippdata_flow.datasink): No edge data
# 200331-19:38:23,106 nipype.workflow DEBUG:
# 	 (hippdata_flow.get_voxRcaud, hippdata_flow.datasink): new edge data: {'connect': [('out_file', '2_Extracted_Stats.@par.@par.@par.@par.@par.@par.@par.@par.@par')]}
# 200331-19:38:23,287 nipype.workflow DEBUG:
# 	 Creating flat graph for workflow: hippdata_flow
# 200331-19:38:23,399 nipype.workflow DEBUG:
# 	 expanding workflow: hippdata_flow
# 200331-19:38:23,401 nipype.workflow DEBUG:
# 	 processing node: hippdata_flow.infosource
# 200331-19:38:23,402 nipype.workflow DEBUG:
# 	 processing node: hippdata_flow.sf3
# 200331-19:38:23,402 nipype.workflow DEBUG:
# 	 processing node: hippdata_flow.convert_aseg
# 200331-19:38:23,403 nipype.workflow DEBUG:
# 	 processing node: hippdata_flow.extract_rcaud
# 200331-19:38:23,404 nipype.workflow DEBUG:
# 	 processing node: hippdata_flow.extract_lcaud
# 200331-19:38:23,405 nipype.workflow DEBUG:
# 	 processing node: hippdata_flow.extract_rnacc
# 200331-19:38:23,405 nipype.workflow DEBUG:
# 	 processing node: hippdata_flow.extract_lnacc
# 200331-19:38:23,406 nipype.workflow DEBUG:
# 	 processing node: hippdata_flow.extract_rput
# 200331-19:38:23,407 nipype.workflow DEBUG:
# 	 processing node: hippdata_flow.extract_lput
# 200331-19:38:23,407 nipype.workflow DEBUG:
# 	 processing node: hippdata_flow.extract_ramyg
# 200331-19:38:23,408 nipype.workflow DEBUG:
# 	 processing node: hippdata_flow.extract_lamyg
# 200331-19:38:23,408 nipype.workflow DEBUG:
# 	 processing node: hippdata_flow.extract_rhipp
# 200331-19:38:23,409 nipype.workflow DEBUG:
# 	 processing node: hippdata_flow.extract_lhipp
# 200331-19:38:23,410 nipype.workflow DEBUG:
# 	 processing node: hippdata_flow.convert_wb
# 200331-19:38:23,410 nipype.workflow DEBUG:
# 	 processing node: hippdata_flow.register_qt12
# 200331-19:38:23,411 nipype.workflow DEBUG:
# 	 processing node: hippdata_flow.get_voxLnacc
# 200331-19:38:23,411 nipype.workflow DEBUG:
# 	 processing node: hippdata_flow.get_voxRnacc
# 200331-19:38:23,412 nipype.workflow DEBUG:
# 	 processing node: hippdata_flow.get_voxLcaud
# 200331-19:38:23,413 nipype.workflow DEBUG:
# 	 processing node: hippdata_flow.get_voxRcaud
# 200331-19:38:23,413 nipype.workflow DEBUG:
# 	 processing node: hippdata_flow.get_voxLput
# 200331-19:38:23,414 nipype.workflow DEBUG:
# 	 processing node: hippdata_flow.get_voxRput
# 200331-19:38:23,415 nipype.workflow DEBUG:
# 	 processing node: hippdata_flow.get_voxLamyg
# 200331-19:38:23,415 nipype.workflow DEBUG:
# 	 processing node: hippdata_flow.get_voxRamyg
# 200331-19:38:23,416 nipype.workflow DEBUG:
# 	 processing node: hippdata_flow.get_voxLhipp
# 200331-19:38:23,416 nipype.workflow DEBUG:
# 	 processing node: hippdata_flow.get_voxRhipp
# 200331-19:38:23,417 nipype.workflow DEBUG:
# 	 processing node: hippdata_flow.datasink
# 200331-19:38:23,417 nipype.workflow DEBUG:
# 	 finished expanding workflow: hippdata_flow
# 200331-19:38:23,425 nipype.workflow DEBUG:
# 	 using input graph
# 200331-19:38:27,730 nipype.workflow DEBUG:
# 	 creating dot graph
# 200331-19:38:44,101 nipype.workflow INFO:
# 	 Generated workflow graph: /Volumes/group/proc/TIGERanalysis/qT1/workflow/hippdata_flow/graph.png (graph2use=flat, simple_form=True).
# 200331-19:38:44,116 nipype.workflow DEBUG:
# 	 [MultiProc] Starting (n_procs=4, mem_gb=28.80, cwd=/Users/lucindasisk/Dropbox/Github/TIGER)
# 200331-19:38:44,118 nipype.workflow DEBUG:
# 	 Creating flat graph for workflow: hippdata_flow
# 200331-19:38:44,221 nipype.workflow DEBUG:
# 	 expanding workflow: hippdata_flow
# 200331-19:38:44,222 nipype.workflow DEBUG:
# 	 processing node: hippdata_flow.infosource
# 200331-19:38:44,223 nipype.workflow DEBUG:
# 	 processing node: hippdata_flow.sf3
# 200331-19:38:44,223 nipype.workflow DEBUG:
# 	 processing node: hippdata_flow.convert_aseg
# 200331-19:38:44,224 nipype.workflow DEBUG:
# 	 processing node: hippdata_flow.extract_rcaud
# 200331-19:38:44,225 nipype.workflow DEBUG:
# 	 processing node: hippdata_flow.extract_lcaud
# 200331-19:38:44,226 nipype.workflow DEBUG:
# 	 processing node: hippdata_flow.extract_rnacc
# 200331-19:38:44,227 nipype.workflow DEBUG:
# 	 processing node: hippdata_flow.extract_lnacc
# 200331-19:38:44,228 nipype.workflow DEBUG:
# 	 processing node: hippdata_flow.extract_rput
# 200331-19:38:44,228 nipype.workflow DEBUG:
# 	 processing node: hippdata_flow.extract_lput
# 200331-19:38:44,229 nipype.workflow DEBUG:
# 	 processing node: hippdata_flow.extract_ramyg
# 200331-19:38:44,230 nipype.workflow DEBUG:
# 	 processing node: hippdata_flow.extract_lamyg
# 200331-19:38:44,231 nipype.workflow DEBUG:
# 	 processing node: hippdata_flow.extract_rhipp
# 200331-19:38:44,231 nipype.workflow DEBUG:
# 	 processing node: hippdata_flow.extract_lhipp
# 200331-19:38:44,232 nipype.workflow DEBUG:
# 	 processing node: hippdata_flow.convert_wb
# 200331-19:38:44,233 nipype.workflow DEBUG:
# 	 processing node: hippdata_flow.register_qt12
# 200331-19:38:44,233 nipype.workflow DEBUG:
# 	 processing node: hippdata_flow.get_voxLnacc
# 200331-19:38:44,234 nipype.workflow DEBUG:
# 	 processing node: hippdata_flow.get_voxRnacc
# 200331-19:38:44,235 nipype.workflow DEBUG:
# 	 processing node: hippdata_flow.get_voxLcaud
# 200331-19:38:44,236 nipype.workflow DEBUG:
# 	 processing node: hippdata_flow.get_voxRcaud
# 200331-19:38:44,236 nipype.workflow DEBUG:
# 	 processing node: hippdata_flow.get_voxLput
# 200331-19:38:44,237 nipype.workflow DEBUG:
# 	 processing node: hippdata_flow.get_voxRput
# 200331-19:38:44,237 nipype.workflow DEBUG:
# 	 processing node: hippdata_flow.get_voxLamyg
# 200331-19:38:44,238 nipype.workflow DEBUG:
# 	 processing node: hippdata_flow.get_voxRamyg
# 200331-19:38:44,239 nipype.workflow DEBUG:
# 	 processing node: hippdata_flow.get_voxLhipp
# 200331-19:38:44,239 nipype.workflow DEBUG:
# 	 processing node: hippdata_flow.get_voxRhipp
# 200331-19:38:44,240 nipype.workflow DEBUG:
# 	 processing node: hippdata_flow.datasink
# 200331-19:38:44,241 nipype.workflow DEBUG:
# 	 finished expanding workflow: hippdata_flow
# 200331-19:38:44,241 nipype.workflow INFO:
# 	 Workflow hippdata_flow settings: ['check', 'execution', 'logging', 'monitoring']
# 200331-19:38:44,249 nipype.workflow DEBUG:
# 	 PE: expanding iterables
# 200331-19:38:44,251 nipype.workflow DEBUG:
# 	 Detected iterable nodes [hippdata_flow.infosource]
# 200331-19:38:44,251 nipype.workflow DEBUG:
# 	 Expanding the iterable node hippdata_flow.infosource...
# 200331-19:38:44,252 nipype.workflow DEBUG:
# 	 node: hippdata_flow.infosource iterables: {'subject_id': <function _standardize_iterables.<locals>.make_field_func.<locals>.<lambda> at 0x7ff660ba26a8>}
# 200331-19:38:44,253 nipype.workflow DEBUG:
# 	 ('subnodes:', [hippdata_flow.infosource, hippdata_flow.sf3, hippdata_flow.convert_wb, hippdata_flow.register_qt12, hippdata_flow.datasink, hippdata_flow.get_voxRhipp, hippdata_flow.get_voxLhipp, hippdata_flow.get_voxRamyg, hippdata_flow.get_voxLamyg, hippdata_flow.get_voxRput, hippdata_flow.get_voxLput, hippdata_flow.get_voxRcaud, hippdata_flow.get_voxLcaud, hippdata_flow.get_voxRnacc, hippdata_flow.get_voxLnacc, hippdata_flow.convert_aseg, hippdata_flow.extract_lhipp, hippdata_flow.extract_rhipp, hippdata_flow.extract_lamyg, hippdata_flow.extract_ramyg, hippdata_flow.extract_lput, hippdata_flow.extract_rput, hippdata_flow.extract_lnacc, hippdata_flow.extract_rnacc, hippdata_flow.extract_lcaud, hippdata_flow.extract_rcaud])
# 200331-19:38:44,261 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input subject_id = 02-T2
# 200331-19:38:44,262 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_subject_id_02-T2
# 200331-19:38:44,269 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input subject_id = 021-T3
# 200331-19:38:44,270 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_subject_id_021-T3
# 200331-19:38:44,277 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input subject_id = 06-T1
# 200331-19:38:44,278 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_subject_id_06-T1
# 200331-19:38:44,286 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input subject_id = 07-T2
# 200331-19:38:44,286 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_subject_id_07-T2
# 200331-19:38:44,294 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input subject_id = 08-T1
# 200331-19:38:44,294 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_subject_id_08-T1
# 200331-19:38:44,301 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input subject_id = 09-T2
# 200331-19:38:44,302 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_subject_id_09-T2
# 200331-19:38:44,309 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input subject_id = 097-T3
# 200331-19:38:44,310 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_subject_id_097-T3
# 200331-19:38:44,317 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input subject_id = 10-T1
# 200331-19:38:44,318 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_subject_id_10-T1
# 200331-19:38:44,325 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input subject_id = 103-T1
# 200331-19:38:44,325 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_subject_id_103-T1
# 200331-19:38:44,331 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input subject_id = 104-T1
# 200331-19:38:44,331 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_subject_id_104-T1
# 200331-19:38:44,337 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input subject_id = 105-T1
# 200331-19:38:44,338 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_subject_id_105-T1
# 200331-19:38:44,343 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input subject_id = 106-T1
# 200331-19:38:44,344 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_subject_id_106-T1
# 200331-19:38:44,349 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input subject_id = 107-T1
# 200331-19:38:44,350 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_subject_id_107-T1
# 200331-19:38:44,356 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input subject_id = 108-T1
# 200331-19:38:44,356 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_subject_id_108-T1
# 200331-19:38:44,362 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input subject_id = 109-T1
# 200331-19:38:44,363 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_subject_id_109-T1
# 200331-19:38:44,368 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input subject_id = 109-T3
# 200331-19:38:44,368 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_subject_id_109-T3
# 200331-19:38:44,373 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input subject_id = 11-T1
# 200331-19:38:44,374 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_subject_id_11-T1
# 200331-19:38:44,380 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input subject_id = 110-T1
# 200331-19:38:44,380 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_subject_id_110-T1
# 200331-19:38:44,385 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input subject_id = 111-T1
# 200331-19:38:44,386 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_subject_id_111-T1
# 200331-19:38:44,391 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input subject_id = 112-T1
# 200331-19:38:44,392 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_subject_id_112-T1
# 200331-19:38:44,397 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input subject_id = 113-T1
# 200331-19:38:44,398 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_subject_id_113-T1
# 200331-19:38:44,403 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input subject_id = 115-T1
# 200331-19:38:44,404 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_subject_id_115-T1
# 200331-19:38:44,410 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input subject_id = 116-T1
# 200331-19:38:44,411 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_subject_id_116-T1
# 200331-19:38:44,417 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input subject_id = 118-T1
# 200331-19:38:44,417 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_subject_id_118-T1
# 200331-19:38:44,422 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input subject_id = 119-T1
# 200331-19:38:44,424 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_subject_id_119-T1
# 200331-19:38:44,429 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input subject_id = 12-T1
# 200331-19:38:44,430 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_subject_id_12-T1
# 200331-19:38:44,435 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input subject_id = 120-T1
# 200331-19:38:44,437 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_subject_id_120-T1
# 200331-19:38:44,442 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input subject_id = 123-T1
# 200331-19:38:44,443 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_subject_id_123-T1
# 200331-19:38:44,449 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input subject_id = 124-T1
# 200331-19:38:44,450 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_subject_id_124-T1
# 200331-19:38:44,456 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input subject_id = 124-T3
# 200331-19:38:44,457 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_subject_id_124-T3
# 200331-19:38:44,463 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input subject_id = 13-T1
# 200331-19:38:44,463 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_subject_id_13-T1
# 200331-19:38:44,469 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input subject_id = 130-T3
# 200331-19:38:44,469 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_subject_id_130-T3
# 200331-19:38:44,475 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input subject_id = 134x-T3
# 200331-19:38:44,476 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_subject_id_134x-T3
# 200331-19:38:44,482 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input subject_id = 145-T3
# 200331-19:38:44,484 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_subject_id_145-T3
# 200331-19:38:44,489 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input subject_id = 147-T3
# 200331-19:38:44,490 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_subject_id_147-T3
# 200331-19:38:44,496 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input subject_id = 15-T1
# 200331-19:38:44,496 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_subject_id_15-T1
# 200331-19:38:44,502 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input subject_id = 159-T3
# 200331-19:38:44,503 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_subject_id_159-T3
# 200331-19:38:44,510 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input subject_id = 16-T1
# 200331-19:38:44,512 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_subject_id_16-T1
# 200331-19:38:44,518 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input subject_id = 162-T3
# 200331-19:38:44,519 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_subject_id_162-T3
# 200331-19:38:44,526 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input subject_id = 168-T3
# 200331-19:38:44,527 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_subject_id_168-T3
# 200331-19:38:44,534 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input subject_id = 17-T1
# 200331-19:38:44,535 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_subject_id_17-T1
# 200331-19:38:44,541 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input subject_id = 170-T3
# 200331-19:38:44,542 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_subject_id_170-T3
# 200331-19:38:44,549 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input subject_id = 171-T3
# 200331-19:38:44,550 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_subject_id_171-T3
# 200331-19:38:44,558 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input subject_id = 178-T3
# 200331-19:38:44,559 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_subject_id_178-T3
# 200331-19:38:44,566 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input subject_id = 18-T1
# 200331-19:38:44,566 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_subject_id_18-T1
# 200331-19:38:44,572 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input subject_id = 182-T3
# 200331-19:38:44,574 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_subject_id_182-T3
# 200331-19:38:44,579 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input subject_id = 186-T3
# 200331-19:38:44,580 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_subject_id_186-T3
# 200331-19:38:44,585 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input subject_id = 187-T3
# 200331-19:38:44,586 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_subject_id_187-T3
# 200331-19:38:44,592 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input subject_id = 19-T1
# 200331-19:38:44,593 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_subject_id_19-T1
# 200331-19:38:44,598 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input subject_id = 191-T3
# 200331-19:38:44,599 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_subject_id_191-T3
# 200331-19:38:44,606 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input subject_id = 20-T1
# 200331-19:38:44,607 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_subject_id_20-T1
# 200331-19:38:44,613 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input subject_id = 202-T3
# 200331-19:38:44,613 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_subject_id_202-T3
# 200331-19:38:44,619 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input subject_id = 205-T3
# 200331-19:38:44,620 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_subject_id_205-T3
# 200331-19:38:44,627 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input subject_id = 21-T1
# 200331-19:38:44,628 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_subject_id_21-T1
# 200331-19:38:44,633 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input subject_id = 215-T3
# 200331-19:38:44,634 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_subject_id_215-T3
# 200331-19:38:44,640 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input subject_id = 22-T1
# 200331-19:38:44,641 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_subject_id_22-T1
# 200331-19:38:44,648 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input subject_id = 23-T1
# 200331-19:38:44,649 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_subject_id_23-T1
# 200331-19:38:44,655 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input subject_id = 24-T1
# 200331-19:38:44,656 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_subject_id_24-T1
# 200331-19:38:44,661 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input subject_id = 28-T2
# 200331-19:38:44,662 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_subject_id_28-T2
# 200331-19:38:44,667 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input subject_id = 29-T1
# 200331-19:38:44,668 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_subject_id_29-T1
# 200331-19:38:44,673 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input subject_id = 30-T1
# 200331-19:38:44,674 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_subject_id_30-T1
# 200331-19:38:44,682 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input subject_id = 31-T1
# 200331-19:38:44,684 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_subject_id_31-T1
# 200331-19:38:44,691 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input subject_id = 32-T1
# 200331-19:38:44,692 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_subject_id_32-T1
# 200331-19:38:44,698 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input subject_id = 34-T2
# 200331-19:38:44,699 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_subject_id_34-T2
# 200331-19:38:44,706 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input subject_id = 35-T1
# 200331-19:38:44,706 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_subject_id_35-T1
# 200331-19:38:44,712 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input subject_id = 36-T1
# 200331-19:38:44,714 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_subject_id_36-T1
# 200331-19:38:44,719 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input subject_id = 38-T1
# 200331-19:38:44,720 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_subject_id_38-T1
# 200331-19:38:44,727 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input subject_id = 39-T1
# 200331-19:38:44,727 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_subject_id_39-T1
# 200331-19:38:44,733 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input subject_id = 40-T1
# 200331-19:38:44,735 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_subject_id_40-T1
# 200331-19:38:44,740 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input subject_id = 41-T1
# 200331-19:38:44,742 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_subject_id_41-T1
# 200331-19:38:44,748 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input subject_id = 42-T1
# 200331-19:38:44,750 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_subject_id_42-T1
# 200331-19:38:44,756 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input subject_id = 43-T1
# 200331-19:38:44,757 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_subject_id_43-T1
# 200331-19:38:44,765 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input subject_id = 44-T1
# 200331-19:38:44,767 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_subject_id_44-T1
# 200331-19:38:44,774 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input subject_id = 45-T1
# 200331-19:38:44,776 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_subject_id_45-T1
# 200331-19:38:44,784 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input subject_id = 46-T1
# 200331-19:38:44,785 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_subject_id_46-T1
# 200331-19:38:44,792 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input subject_id = 48-T1
# 200331-19:38:44,793 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_subject_id_48-T1
# 200331-19:38:44,800 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input subject_id = 49-T1
# 200331-19:38:44,801 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_subject_id_49-T1
# 200331-19:38:44,808 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input subject_id = 50-T1
# 200331-19:38:44,809 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_subject_id_50-T1
# 200331-19:38:44,817 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input subject_id = 51-T1
# 200331-19:38:44,819 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_subject_id_51-T1
# 200331-19:38:44,825 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input subject_id = 52-T1
# 200331-19:38:44,828 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_subject_id_52-T1
# 200331-19:38:44,835 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input subject_id = 53-T1
# 200331-19:38:44,836 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_subject_id_53-T1
# 200331-19:38:44,843 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input subject_id = 54-T1
# 200331-19:38:44,844 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_subject_id_54-T1
# 200331-19:38:44,851 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input subject_id = 55-T1
# 200331-19:38:44,852 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_subject_id_55-T1
# 200331-19:38:44,860 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input subject_id = 56-T1
# 200331-19:38:44,861 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_subject_id_56-T1
# 200331-19:38:44,881 nipype.workflow DEBUG:
# 	 PE: expanding iterables ... done
# 200331-19:38:44,899 nipype.workflow DEBUG:
# 	 [Node] sf3 - setting input subject_id = 56-T1
# 200331-19:38:44,901 nipype.workflow DEBUG:
# 	 Removed the identity node hippdata_flow.infosource from the graph.
# 200331-19:38:44,902 nipype.workflow DEBUG:
# 	 [Node] sf3 - setting input subject_id = 55-T1
# 200331-19:38:44,902 nipype.workflow DEBUG:
# 	 Removed the identity node hippdata_flow.infosource from the graph.
# 200331-19:38:44,903 nipype.workflow DEBUG:
# 	 [Node] sf3 - setting input subject_id = 54-T1
# 200331-19:38:44,904 nipype.workflow DEBUG:
# 	 Removed the identity node hippdata_flow.infosource from the graph.
# 200331-19:38:44,904 nipype.workflow DEBUG:
# 	 [Node] sf3 - setting input subject_id = 53-T1
# 200331-19:38:44,905 nipype.workflow DEBUG:
# 	 Removed the identity node hippdata_flow.infosource from the graph.
# 200331-19:38:44,905 nipype.workflow DEBUG:
# 	 [Node] sf3 - setting input subject_id = 52-T1
# 200331-19:38:44,906 nipype.workflow DEBUG:
# 	 Removed the identity node hippdata_flow.infosource from the graph.
# 200331-19:38:44,907 nipype.workflow DEBUG:
# 	 [Node] sf3 - setting input subject_id = 51-T1
# 200331-19:38:44,907 nipype.workflow DEBUG:
# 	 Removed the identity node hippdata_flow.infosource from the graph.
# 200331-19:38:44,908 nipype.workflow DEBUG:
# 	 [Node] sf3 - setting input subject_id = 50-T1
# 200331-19:38:44,908 nipype.workflow DEBUG:
# 	 Removed the identity node hippdata_flow.infosource from the graph.
# 200331-19:38:44,909 nipype.workflow DEBUG:
# 	 [Node] sf3 - setting input subject_id = 49-T1
# 200331-19:38:44,909 nipype.workflow DEBUG:
# 	 Removed the identity node hippdata_flow.infosource from the graph.
# 200331-19:38:44,910 nipype.workflow DEBUG:
# 	 [Node] sf3 - setting input subject_id = 48-T1
# 200331-19:38:44,911 nipype.workflow DEBUG:
# 	 Removed the identity node hippdata_flow.infosource from the graph.
# 200331-19:38:44,912 nipype.workflow DEBUG:
# 	 [Node] sf3 - setting input subject_id = 46-T1
# 200331-19:38:44,912 nipype.workflow DEBUG:
# 	 Removed the identity node hippdata_flow.infosource from the graph.
# 200331-19:38:44,913 nipype.workflow DEBUG:
# 	 [Node] sf3 - setting input subject_id = 45-T1
# 200331-19:38:44,914 nipype.workflow DEBUG:
# 	 Removed the identity node hippdata_flow.infosource from the graph.
# 200331-19:38:44,914 nipype.workflow DEBUG:
# 	 [Node] sf3 - setting input subject_id = 44-T1
# 200331-19:38:44,915 nipype.workflow DEBUG:
# 	 Removed the identity node hippdata_flow.infosource from the graph.
# 200331-19:38:44,915 nipype.workflow DEBUG:
# 	 [Node] sf3 - setting input subject_id = 43-T1
# 200331-19:38:44,916 nipype.workflow DEBUG:
# 	 Removed the identity node hippdata_flow.infosource from the graph.
# 200331-19:38:44,916 nipype.workflow DEBUG:
# 	 [Node] sf3 - setting input subject_id = 42-T1
# 200331-19:38:44,917 nipype.workflow DEBUG:
# 	 Removed the identity node hippdata_flow.infosource from the graph.
# 200331-19:38:44,917 nipype.workflow DEBUG:
# 	 [Node] sf3 - setting input subject_id = 41-T1
# 200331-19:38:44,918 nipype.workflow DEBUG:
# 	 Removed the identity node hippdata_flow.infosource from the graph.
# 200331-19:38:44,919 nipype.workflow DEBUG:
# 	 [Node] sf3 - setting input subject_id = 40-T1
# 200331-19:38:44,919 nipype.workflow DEBUG:
# 	 Removed the identity node hippdata_flow.infosource from the graph.
# 200331-19:38:44,920 nipype.workflow DEBUG:
# 	 [Node] sf3 - setting input subject_id = 39-T1
# 200331-19:38:44,920 nipype.workflow DEBUG:
# 	 Removed the identity node hippdata_flow.infosource from the graph.
# 200331-19:38:44,921 nipype.workflow DEBUG:
# 	 [Node] sf3 - setting input subject_id = 38-T1
# 200331-19:38:44,921 nipype.workflow DEBUG:
# 	 Removed the identity node hippdata_flow.infosource from the graph.
# 200331-19:38:44,922 nipype.workflow DEBUG:
# 	 [Node] sf3 - setting input subject_id = 36-T1
# 200331-19:38:44,922 nipype.workflow DEBUG:
# 	 Removed the identity node hippdata_flow.infosource from the graph.
# 200331-19:38:44,923 nipype.workflow DEBUG:
# 	 [Node] sf3 - setting input subject_id = 35-T1
# 200331-19:38:44,923 nipype.workflow DEBUG:
# 	 Removed the identity node hippdata_flow.infosource from the graph.
# 200331-19:38:44,924 nipype.workflow DEBUG:
# 	 [Node] sf3 - setting input subject_id = 34-T2
# 200331-19:38:44,924 nipype.workflow DEBUG:
# 	 Removed the identity node hippdata_flow.infosource from the graph.
# 200331-19:38:44,924 nipype.workflow DEBUG:
# 	 [Node] sf3 - setting input subject_id = 32-T1
# 200331-19:38:44,925 nipype.workflow DEBUG:
# 	 Removed the identity node hippdata_flow.infosource from the graph.
# 200331-19:38:44,925 nipype.workflow DEBUG:
# 	 [Node] sf3 - setting input subject_id = 31-T1
# 200331-19:38:44,926 nipype.workflow DEBUG:
# 	 Removed the identity node hippdata_flow.infosource from the graph.
# 200331-19:38:44,926 nipype.workflow DEBUG:
# 	 [Node] sf3 - setting input subject_id = 30-T1
# 200331-19:38:44,927 nipype.workflow DEBUG:
# 	 Removed the identity node hippdata_flow.infosource from the graph.
# 200331-19:38:44,927 nipype.workflow DEBUG:
# 	 [Node] sf3 - setting input subject_id = 29-T1
# 200331-19:38:44,928 nipype.workflow DEBUG:
# 	 Removed the identity node hippdata_flow.infosource from the graph.
# 200331-19:38:44,928 nipype.workflow DEBUG:
# 	 [Node] sf3 - setting input subject_id = 28-T2
# 200331-19:38:44,929 nipype.workflow DEBUG:
# 	 Removed the identity node hippdata_flow.infosource from the graph.
# 200331-19:38:44,929 nipype.workflow DEBUG:
# 	 [Node] sf3 - setting input subject_id = 24-T1
# 200331-19:38:44,930 nipype.workflow DEBUG:
# 	 Removed the identity node hippdata_flow.infosource from the graph.
# 200331-19:38:44,930 nipype.workflow DEBUG:
# 	 [Node] sf3 - setting input subject_id = 23-T1
# 200331-19:38:44,930 nipype.workflow DEBUG:
# 	 Removed the identity node hippdata_flow.infosource from the graph.
# 200331-19:38:44,931 nipype.workflow DEBUG:
# 	 [Node] sf3 - setting input subject_id = 22-T1
# 200331-19:38:44,931 nipype.workflow DEBUG:
# 	 Removed the identity node hippdata_flow.infosource from the graph.
# 200331-19:38:44,932 nipype.workflow DEBUG:
# 	 [Node] sf3 - setting input subject_id = 215-T3
# 200331-19:38:44,932 nipype.workflow DEBUG:
# 	 Removed the identity node hippdata_flow.infosource from the graph.
# 200331-19:38:44,933 nipype.workflow DEBUG:
# 	 [Node] sf3 - setting input subject_id = 21-T1
# 200331-19:38:44,933 nipype.workflow DEBUG:
# 	 Removed the identity node hippdata_flow.infosource from the graph.
# 200331-19:38:44,934 nipype.workflow DEBUG:
# 	 [Node] sf3 - setting input subject_id = 205-T3
# 200331-19:38:44,934 nipype.workflow DEBUG:
# 	 Removed the identity node hippdata_flow.infosource from the graph.
# 200331-19:38:44,934 nipype.workflow DEBUG:
# 	 [Node] sf3 - setting input subject_id = 202-T3
# 200331-19:38:44,935 nipype.workflow DEBUG:
# 	 Removed the identity node hippdata_flow.infosource from the graph.
# 200331-19:38:44,935 nipype.workflow DEBUG:
# 	 [Node] sf3 - setting input subject_id = 20-T1
# 200331-19:38:44,936 nipype.workflow DEBUG:
# 	 Removed the identity node hippdata_flow.infosource from the graph.
# 200331-19:38:44,936 nipype.workflow DEBUG:
# 	 [Node] sf3 - setting input subject_id = 191-T3
# 200331-19:38:44,937 nipype.workflow DEBUG:
# 	 Removed the identity node hippdata_flow.infosource from the graph.
# 200331-19:38:44,937 nipype.workflow DEBUG:
# 	 [Node] sf3 - setting input subject_id = 19-T1
# 200331-19:38:44,938 nipype.workflow DEBUG:
# 	 Removed the identity node hippdata_flow.infosource from the graph.
# 200331-19:38:44,938 nipype.workflow DEBUG:
# 	 [Node] sf3 - setting input subject_id = 187-T3
# 200331-19:38:44,939 nipype.workflow DEBUG:
# 	 Removed the identity node hippdata_flow.infosource from the graph.
# 200331-19:38:44,939 nipype.workflow DEBUG:
# 	 [Node] sf3 - setting input subject_id = 186-T3
# 200331-19:38:44,940 nipype.workflow DEBUG:
# 	 Removed the identity node hippdata_flow.infosource from the graph.
# 200331-19:38:44,940 nipype.workflow DEBUG:
# 	 [Node] sf3 - setting input subject_id = 182-T3
# 200331-19:38:44,940 nipype.workflow DEBUG:
# 	 Removed the identity node hippdata_flow.infosource from the graph.
# 200331-19:38:44,941 nipype.workflow DEBUG:
# 	 [Node] sf3 - setting input subject_id = 18-T1
# 200331-19:38:44,941 nipype.workflow DEBUG:
# 	 Removed the identity node hippdata_flow.infosource from the graph.
# 200331-19:38:44,941 nipype.workflow DEBUG:
# 	 [Node] sf3 - setting input subject_id = 178-T3
# 200331-19:38:44,942 nipype.workflow DEBUG:
# 	 Removed the identity node hippdata_flow.infosource from the graph.
# 200331-19:38:44,942 nipype.workflow DEBUG:
# 	 [Node] sf3 - setting input subject_id = 171-T3
# 200331-19:38:44,943 nipype.workflow DEBUG:
# 	 Removed the identity node hippdata_flow.infosource from the graph.
# 200331-19:38:44,943 nipype.workflow DEBUG:
# 	 [Node] sf3 - setting input subject_id = 170-T3
# 200331-19:38:44,944 nipype.workflow DEBUG:
# 	 Removed the identity node hippdata_flow.infosource from the graph.
# 200331-19:38:44,944 nipype.workflow DEBUG:
# 	 [Node] sf3 - setting input subject_id = 17-T1
# 200331-19:38:44,945 nipype.workflow DEBUG:
# 	 Removed the identity node hippdata_flow.infosource from the graph.
# 200331-19:38:44,945 nipype.workflow DEBUG:
# 	 [Node] sf3 - setting input subject_id = 168-T3
# 200331-19:38:44,946 nipype.workflow DEBUG:
# 	 Removed the identity node hippdata_flow.infosource from the graph.
# 200331-19:38:44,946 nipype.workflow DEBUG:
# 	 [Node] sf3 - setting input subject_id = 162-T3
# 200331-19:38:44,946 nipype.workflow DEBUG:
# 	 Removed the identity node hippdata_flow.infosource from the graph.
# 200331-19:38:44,947 nipype.workflow DEBUG:
# ...
# 	 Cannot allocate job 1025 (0.20GB, 1 threads).
# 200331-20:47:12,610 nipype.workflow DEBUG:
# 	 Cannot allocate job 1050 (0.20GB, 1 threads).
# 200331-20:47:12,611 nipype.workflow DEBUG:
# 	 Cannot allocate job 1075 (0.20GB, 1 threads).
# 200331-20:47:12,612 nipype.workflow DEBUG:
# 	 Cannot allocate job 1100 (0.20GB, 1 threads).
# 200331-20:47:12,612 nipype.workflow DEBUG:
# 	 Cannot allocate job 1125 (0.20GB, 1 threads).
# 200331-20:47:12,613 nipype.workflow DEBUG:
# 	 Cannot allocate job 1150 (0.20GB, 1 threads).
# 200331-20:47:12,614 nipype.workflow DEBUG:
# 	 Cannot allocate job 1175 (0.20GB, 1 threads).
# 200331-20:47:12,615 nipype.workflow DEBUG:
# 	 Cannot allocate job 1200 (0.20GB, 1 threads).
# 200331-20:47:12,615 nipype.workflow DEBUG:
# 	 Cannot allocate job 1225 (0.20GB, 1 threads).
# 200331-20:47:12,616 nipype.workflow DEBUG:
# 	 Cannot allocate job 1250 (0.20GB, 1 threads).
# 200331-20:47:12,617 nipype.workflow DEBUG:
# 	 Cannot allocate job 1275 (0.20GB, 1 threads).
# 200331-20:47:12,618 nipype.workflow DEBUG:
# 	 Cannot allocate job 1300 (0.20GB, 1 threads).
# 200331-20:47:12,618 nipype.workflow DEBUG:
# 	 Cannot allocate job 1325 (0.20GB, 1 threads).
# 200331-20:47:12,619 nipype.workflow DEBUG:
# 	 Cannot allocate job 1350 (0.20GB, 1 threads).
# 200331-20:47:12,619 nipype.workflow DEBUG:
# 	 Cannot allocate job 1375 (0.20GB, 1 threads).
# 200331-20:47:12,620 nipype.workflow DEBUG:
# 	 Cannot allocate job 1400 (0.20GB, 1 threads).
# 200331-20:47:12,620 nipype.workflow DEBUG:
# 	 Cannot allocate job 1425 (0.20GB, 1 threads).
# 200331-20:47:12,621 nipype.workflow DEBUG:
# 	 Cannot allocate job 1450 (0.20GB, 1 threads).
# 200331-20:47:12,621 nipype.workflow DEBUG:
# 	 Cannot allocate job 1475 (0.20GB, 1 threads).
# 200331-20:47:12,622 nipype.workflow DEBUG:
# 	 Cannot allocate job 1500 (0.20GB, 1 threads).
# 200331-20:47:12,622 nipype.workflow DEBUG:
# 	 Cannot allocate job 1525 (0.20GB, 1 threads).
# 200331-20:47:12,623 nipype.workflow DEBUG:
# 	 Cannot allocate job 1550 (0.20GB, 1 threads).
# 200331-20:47:12,623 nipype.workflow DEBUG:
# 	 Cannot allocate job 1575 (0.20GB, 1 threads).
# 200331-20:47:12,624 nipype.workflow DEBUG:
# 	 Cannot allocate job 1600 (0.20GB, 1 threads).
# 200331-20:47:12,625 nipype.workflow DEBUG:
# 	 Cannot allocate job 1625 (0.20GB, 1 threads).
# 200331-20:47:12,625 nipype.workflow DEBUG:
# 	 Cannot allocate job 1650 (0.20GB, 1 threads).
# 200331-20:47:12,626 nipype.workflow DEBUG:
# 	 Cannot allocate job 1675 (0.20GB, 1 threads).
# 200331-20:47:12,627 nipype.workflow DEBUG:
# 	 Cannot allocate job 1700 (0.20GB, 1 threads).
# 200331-20:47:12,627 nipype.workflow DEBUG:
# 	 Cannot allocate job 1725 (0.20GB, 1 threads).
# 200331-20:47:12,628 nipype.workflow DEBUG:
# 	 Cannot allocate job 1750 (0.20GB, 1 threads).
# 200331-20:47:12,628 nipype.workflow DEBUG:
# 	 Cannot allocate job 1775 (0.20GB, 1 threads).
# 200331-20:47:12,629 nipype.workflow DEBUG:
# 	 Cannot allocate job 1800 (0.20GB, 1 threads).
# 200331-20:47:12,630 nipype.workflow DEBUG:
# 	 Cannot allocate job 1825 (0.20GB, 1 threads).
# 200331-20:47:12,630 nipype.workflow DEBUG:
# 	 Cannot allocate job 1850 (0.20GB, 1 threads).
# 200331-20:47:12,631 nipype.workflow DEBUG:
# 	 Cannot allocate job 1875 (0.20GB, 1 threads).
# 200331-20:47:12,631 nipype.workflow DEBUG:
# 	 Cannot allocate job 1900 (0.20GB, 1 threads).
# 200331-20:47:12,632 nipype.workflow DEBUG:
# 	 Cannot allocate job 1925 (0.20GB, 1 threads).
# 200331-20:47:12,632 nipype.workflow DEBUG:
# 	 Cannot allocate job 1950 (0.20GB, 1 threads).
# 200331-20:47:12,633 nipype.workflow DEBUG:
# 	 Cannot allocate job 1975 (0.20GB, 1 threads).
# 200331-20:47:12,634 nipype.workflow DEBUG:
# 	 Cannot allocate job 2000 (0.20GB, 1 threads).
# 200331-20:47:12,635 nipype.workflow DEBUG:
# 	 Cannot allocate job 2025 (0.20GB, 1 threads).
# 200331-20:47:12,635 nipype.workflow DEBUG:
# 	 Cannot allocate job 2050 (0.20GB, 1 threads).
# 200331-20:47:12,636 nipype.workflow DEBUG:
# 	 Cannot allocate job 2075 (0.20GB, 1 threads).
# 200331-20:47:12,645 nipype.workflow DEBUG:
# 	 Progress: 2100 jobs, 284/3/73 (done/running/ready), 3/1813 (pending_tasks/waiting).
# 200331-20:47:12,646 nipype.workflow DEBUG:
# 	 Tasks currently running: 3. Pending: 3.
# 200331-20:47:12,654 nipype.workflow INFO:
# 	 [MultiProc] Running 3 tasks, and 73 jobs ready. Free memory (GB): 28.20/28.80, Free processors: 1/4.
#                      Currently running:
#                        * hippdata_flow.datasink
#                        * hippdata_flow.datasink
#                        * hippdata_flow.datasink
# 200331-20:47:12,712 nipype.workflow DEBUG:
# 	 Allocating hippdata_flow.convert_wb ID=287 (0.20GB, 1 threads). Free: 28.00GB, 0 threads.
# 200331-20:47:12,713 nipype.workflow DEBUG:
# 	 Setting node inputs
# 200331-20:47:12,714 nipype.workflow DEBUG:
# 	 input: in_file
# 200331-20:47:12,715 nipype.workflow DEBUG:
# 	 results file: /Volumes/group/proc/TIGERanalysis/qT1/workflow/hippdata_flow/_subject_id_44-T1/sf3/result_sf3.pklz
# 200331-20:47:12,716 nipype.utils DEBUG:
# 	 Loading pkl: /Volumes/group/proc/TIGERanalysis/qT1/workflow/hippdata_flow/_subject_id_44-T1/sf3/result_sf3.pklz
# 200331-20:47:13,227 nipype.utils DEBUG:
# 	 File: /Volumes/group/proc/TIGERanalysis/qT1/data/2_Extracted_Stats/_subject_id_46-T1/ROI_voxel-contrasts_LeftHippocampus.txt already exists,f9bfe036e0543615da533e449f21ef2f, copy:1
# 200331-20:47:13,450 nipype.workflow DEBUG:
# 	 output: t1w
# 200331-20:47:13,452 nipype.workflow DEBUG:
# 	 [Node] convert_wb - setting input in_file = /Volumes/group/proc/TIGERanalysis/TIGER_FreeSurfer/TIGER_FS_subjDir/44-T1/mri/brain.mgz
# 200331-20:47:14,191 nipype.workflow INFO:
# 	 [Node] Finished "hippdata_flow.datasink".
# 200331-20:47:33,271 nipype.utils DEBUG:
# 	 File: /Volumes/group/proc/TIGERanalysis/qT1/data/2_Extracted_Stats/_subject_id_46-T1/ROI_voxel-contrasts_LeftHippocampus.txt already exists, not overwriting, copy:1
# 200331-20:47:33,277 nipype.utils DEBUG:
# 	 /Volumes/group/proc/TIGERanalysis/qT1/data/2_Extracted_Stats/_subject_id_46-T1/ROI_voxel-contrasts_LeftHippocampus.txt
# 200331-20:48:15,782 nipype.utils DEBUG:
# 	 File: /Volumes/group/proc/TIGERanalysis/qT1/data/1_check_alignment/_subject_id_45-T1/registered_qT1_toFreesurfer.nii.gz already exists,5e4068c89a0e3375fd391bcf2cdbea27, copy:1
# 200331-20:48:15,864 nipype.workflow DEBUG:
# 	 [Node] Hashes: [('in_file', ('/Volumes/group/proc/TIGERanalysis/TIGER_FreeSurfer/TIGER_FS_subjDir/44-T1/mri/brain.mgz', 'a8b2830c20852e2bcd1996a266412320')), ('in_type', 'mgz'), ('out_file', 'brain.nii.gz'), ('subjects_dir', '/Applications/freesurfer/subjects')], 4bedbc515a501b68ccd766ef68357f8d, /Volumes/group/proc/TIGERanalysis/qT1/workflow/hippdata_flow/_subject_id_44-T1/convert_wb/_0x4bedbc515a501b68ccd766ef68357f8d.json, ['/Volumes/group/proc/TIGERanalysis/qT1/workflow/hippdata_flow/_subject_id_44-T1/convert_wb/_0x4bedbc515a501b68ccd766ef68357f8d.json']
# 200331-20:48:15,865 nipype.workflow DEBUG:
# 	 [Node] Up-to-date cache found for "hippdata_flow.convert_wb".
# 200331-20:48:15,865 nipype.workflow DEBUG:
# 	 Checking hash "hippdata_flow.convert_wb" locally: cached=True, updated=True.
# 200331-20:48:15,866 nipype.workflow DEBUG:
# 	 Skipping cached node hippdata_flow.convert_wb with ID 287.
# 200331-20:48:15,867 nipype.workflow INFO:
# 	 [Job 287] Cached (hippdata_flow.convert_wb).
# 200331-20:48:15,870 nipype.workflow DEBUG:
# 	 Cannot allocate job 300 (0.20GB, 1 threads).
# 200331-20:48:15,871 nipype.workflow DEBUG:
# 	 Cannot allocate job 325 (0.20GB, 1 threads).
# 200331-20:48:15,871 nipype.workflow DEBUG:
# 	 Cannot allocate job 350 (0.20GB, 1 threads).
# 200331-20:48:15,872 nipype.workflow DEBUG:
# 	 Cannot allocate job 375 (0.20GB, 1 threads).
# 200331-20:48:15,873 nipype.workflow DEBUG:
# 	 Cannot allocate job 400 (0.20GB, 1 threads).
# 200331-20:48:15,873 nipype.workflow DEBUG:
# 	 Cannot allocate job 425 (0.20GB, 1 threads).
# 200331-20:48:15,874 nipype.workflow DEBUG:
# 	 Cannot allocate job 450 (0.20GB, 1 threads).
# 200331-20:48:15,875 nipype.workflow DEBUG:
# 	 Cannot allocate job 475 (0.20GB, 1 threads).
# 200331-20:48:15,875 nipype.workflow DEBUG:
# 	 Cannot allocate job 500 (0.20GB, 1 threads).
# 200331-20:48:15,876 nipype.workflow DEBUG:
# 	 Cannot allocate job 525 (0.20GB, 1 threads).
# 200331-20:48:15,876 nipype.workflow DEBUG:
# 	 Cannot allocate job 550 (0.20GB, 1 threads).
# 200331-20:48:15,877 nipype.workflow DEBUG:
# 	 Cannot allocate job 575 (0.20GB, 1 threads).
# 200331-20:48:15,877 nipype.workflow DEBUG:
# 	 Cannot allocate job 600 (0.20GB, 1 threads).
# 200331-20:48:15,878 nipype.workflow DEBUG:
# 	 Cannot allocate job 625 (0.20GB, 1 threads).
# 200331-20:48:15,878 nipype.workflow DEBUG:
# 	 Cannot allocate job 650 (0.20GB, 1 threads).
# 200331-20:48:15,879 nipype.workflow DEBUG:
# 	 Cannot allocate job 675 (0.20GB, 1 threads).
# 200331-20:48:15,879 nipype.workflow DEBUG:
# 	 Cannot allocate job 700 (0.20GB, 1 threads).
# 200331-20:48:15,880 nipype.workflow DEBUG:
# 	 Cannot allocate job 725 (0.20GB, 1 threads).
# 200331-20:48:15,881 nipype.workflow DEBUG:
# 	 Cannot allocate job 750 (0.20GB, 1 threads).
# 200331-20:48:15,881 nipype.workflow DEBUG:
# 	 Cannot allocate job 775 (0.20GB, 1 threads).
# 200331-20:48:15,882 nipype.workflow DEBUG:
# 	 Cannot allocate job 800 (0.20GB, 1 threads).
# 200331-20:48:15,883 nipype.workflow DEBUG:
# 	 Cannot allocate job 825 (0.20GB, 1 threads).
# 200331-20:48:15,884 nipype.workflow DEBUG:
# 	 Cannot allocate job 850 (0.20GB, 1 threads).
# 200331-20:48:15,885 nipype.workflow DEBUG:
# 	 Cannot allocate job 875 (0.20GB, 1 threads).
# 200331-20:48:15,885 nipype.workflow DEBUG:
# 	 Cannot allocate job 900 (0.20GB, 1 threads).
# 200331-20:48:15,886 nipype.workflow DEBUG:
# 	 Cannot allocate job 925 (0.20GB, 1 threads).
# 200331-20:48:15,887 nipype.workflow DEBUG:
# 	 Cannot allocate job 950 (0.20GB, 1 threads).
# 200331-20:48:15,887 nipype.workflow DEBUG:
# 	 Cannot allocate job 975 (0.20GB, 1 threads).
# 200331-20:48:15,888 nipype.workflow DEBUG:
# 	 Cannot allocate job 1000 (0.20GB, 1 threads).
# 200331-20:48:15,889 nipype.workflow DEBUG:
# 	 Cannot allocate job 1025 (0.20GB, 1 threads).
# 200331-20:48:15,890 nipype.workflow DEBUG:
# 	 Cannot allocate job 1050 (0.20GB, 1 threads).
# 200331-20:48:15,891 nipype.workflow DEBUG:
# 	 Cannot allocate job 1075 (0.20GB, 1 threads).
# 200331-20:48:15,892 nipype.workflow DEBUG:
# 	 Cannot allocate job 1100 (0.20GB, 1 threads).
# 200331-20:48:15,893 nipype.workflow DEBUG:
# 	 Cannot allocate job 1125 (0.20GB, 1 threads).
# 200331-20:48:15,894 nipype.workflow DEBUG:
# 	 Cannot allocate job 1150 (0.20GB, 1 threads).
# 200331-20:48:15,895 nipype.workflow DEBUG:
# 	 Cannot allocate job 1175 (0.20GB, 1 threads).
# 200331-20:48:15,895 nipype.workflow DEBUG:
# 	 Cannot allocate job 1200 (0.20GB, 1 threads).
# 200331-20:48:15,896 nipype.workflow DEBUG:
# 	 Cannot allocate job 1225 (0.20GB, 1 threads).
# 200331-20:48:15,897 nipype.workflow DEBUG:
# 	 Cannot allocate job 1250 (0.20GB, 1 threads).
# 200331-20:48:15,897 nipype.workflow DEBUG:
# 	 Cannot allocate job 1275 (0.20GB, 1 threads).
# 200331-20:48:15,898 nipype.workflow DEBUG:
# 	 Cannot allocate job 1300 (0.20GB, 1 threads).
# 200331-20:48:15,899 nipype.workflow DEBUG:
# 	 Cannot allocate job 1325 (0.20GB, 1 threads).
# 200331-20:48:15,900 nipype.workflow DEBUG:
# 	 Cannot allocate job 1350 (0.20GB, 1 threads).
# 200331-20:48:15,900 nipype.workflow DEBUG:
# 	 Cannot allocate job 1375 (0.20GB, 1 threads).
# 200331-20:48:15,901 nipype.workflow DEBUG:
# 	 Cannot allocate job 1400 (0.20GB, 1 threads).
# 200331-20:48:15,902 nipype.workflow DEBUG:
# 	 Cannot allocate job 1425 (0.20GB, 1 threads).
# 200331-20:48:15,903 nipype.workflow DEBUG:
# 	 Cannot allocate job 1450 (0.20GB, 1 threads).
# 200331-20:48:15,903 nipype.workflow DEBUG:
# 	 Cannot allocate job 1475 (0.20GB, 1 threads).
# 200331-20:48:15,904 nipype.workflow DEBUG:
# 	 Cannot allocate job 1500 (0.20GB, 1 threads).
# 200331-20:48:15,904 nipype.workflow DEBUG:
# 	 Cannot allocate job 1525 (0.20GB, 1 threads).
# 200331-20:48:15,905 nipype.workflow DEBUG:
# 	 Cannot allocate job 1550 (0.20GB, 1 threads).
# 200331-20:48:15,906 nipype.workflow DEBUG:
# 	 Cannot allocate job 1575 (0.20GB, 1 threads).
# 200331-20:48:15,907 nipype.workflow DEBUG:
# 	 Cannot allocate job 1600 (0.20GB, 1 threads).
# 200331-20:48:15,907 nipype.workflow DEBUG:
# 	 Cannot allocate job 1625 (0.20GB, 1 threads).
# 200331-20:48:15,908 nipype.workflow DEBUG:
# 	 Cannot allocate job 1650 (0.20GB, 1 threads).
# 200331-20:48:15,909 nipype.workflow DEBUG:
# 	 Cannot allocate job 1675 (0.20GB, 1 threads).
# 200331-20:48:15,910 nipype.workflow DEBUG:
# 	 Cannot allocate job 1700 (0.20GB, 1 threads).
# 200331-20:48:15,910 nipype.workflow DEBUG:
# 	 Cannot allocate job 1725 (0.20GB, 1 threads).
# 200331-20:48:15,911 nipype.workflow DEBUG:
# 	 Cannot allocate job 1750 (0.20GB, 1 threads).
# 200331-20:48:15,912 nipype.workflow DEBUG:
# 	 Cannot allocate job 1775 (0.20GB, 1 threads).
# 200331-20:48:15,912 nipype.workflow DEBUG:
# 	 Cannot allocate job 1800 (0.20GB, 1 threads).
# 200331-20:48:15,913 nipype.workflow DEBUG:
# 	 Cannot allocate job 1825 (0.20GB, 1 threads).
# 200331-20:48:15,914 nipype.workflow DEBUG:
# 	 Cannot allocate job 1850 (0.20GB, 1 threads).
# 200331-20:48:15,914 nipype.workflow DEBUG:
# 	 Cannot allocate job 1875 (0.20GB, 1 threads).
# 200331-20:48:15,915 nipype.workflow DEBUG:
# 	 Cannot allocate job 1900 (0.20GB, 1 threads).
# 200331-20:48:15,916 nipype.workflow DEBUG:
# 	 Cannot allocate job 1925 (0.20GB, 1 threads).
# 200331-20:48:15,917 nipype.workflow DEBUG:
# 	 Cannot allocate job 1950 (0.20GB, 1 threads).
# 200331-20:48:15,917 nipype.workflow DEBUG:
# 	 Cannot allocate job 1975 (0.20GB, 1 threads).
# 200331-20:48:15,918 nipype.workflow DEBUG:
# 	 Cannot allocate job 2000 (0.20GB, 1 threads).
# 200331-20:48:15,919 nipype.workflow DEBUG:
# 	 Cannot allocate job 2025 (0.20GB, 1 threads).
# 200331-20:48:15,919 nipype.workflow DEBUG:
# 	 Cannot allocate job 2050 (0.20GB, 1 threads).
# 200331-20:48:15,920 nipype.workflow DEBUG:
# 	 Cannot allocate job 2075 (0.20GB, 1 threads).
# 200331-20:48:15,930 nipype.workflow DEBUG:
# 	 Progress: 2100 jobs, 285/3/73 (done/running/ready), 3/1812 (pending_tasks/waiting).
# 200331-20:48:15,931 nipype.workflow INFO:
# 	 [Job 224] Completed (hippdata_flow.datasink).
# 200331-20:48:15,935 nipype.workflow DEBUG:
# 	 Tasks currently running: 2. Pending: 2.
# 200331-20:48:15,945 nipype.workflow INFO:
# 	 [MultiProc] Running 2 tasks, and 73 jobs ready. Free memory (GB): 28.40/28.80, Free processors: 2/4.
#                      Currently running:
#                        * hippdata_flow.datasink
#                        * hippdata_flow.datasink
# 200331-20:48:16,6 nipype.workflow DEBUG:
# 	 Allocating hippdata_flow.register_qt12 ID=288 (0.20GB, 1 threads). Free: 28.20GB, 1 threads.
# 200331-20:48:16,7 nipype.workflow DEBUG:
# 	 Setting node inputs
# 200331-20:48:16,8 nipype.workflow DEBUG:
# 	 input: in_file
# 200331-20:48:16,9 nipype.workflow DEBUG:
# 	 results file: /Volumes/group/proc/TIGERanalysis/qT1/workflow/hippdata_flow/_subject_id_44-T1/sf3/result_sf3.pklz
# 200331-20:48:16,9 nipype.utils DEBUG:
# 	 Loading pkl: /Volumes/group/proc/TIGERanalysis/qT1/workflow/hippdata_flow/_subject_id_44-T1/sf3/result_sf3.pklz
# 200331-20:48:16,620 nipype.workflow DEBUG:
# 	 output: qt1_reor
# 200331-20:48:16,621 nipype.workflow DEBUG:
# 	 [Node] register_qt12 - setting input in_file = /Volumes/group/proc/TIGERanalysis/qT1/data/1_check_alignment/_subject_id_44-T1/reoriented_qT1.nii.gz
# 200331-20:48:17,175 nipype.workflow DEBUG:
# 	 input: reference
# 200331-20:48:17,176 nipype.workflow DEBUG:
# 	 results file: /Volumes/group/proc/TIGERanalysis/qT1/workflow/hippdata_flow/_subject_id_44-T1/convert_wb/result_convert_wb.pklz
# 200331-20:48:17,176 nipype.utils DEBUG:
# 	 Loading pkl: /Volumes/group/proc/TIGERanalysis/qT1/workflow/hippdata_flow/_subject_id_44-T1/convert_wb/result_convert_wb.pklz
# 200331-20:48:18,97 nipype.utils DEBUG:
# 	 File: /Volumes/group/proc/TIGERanalysis/qT1/data/2_Extracted_Stats/_subject_id_46-T1/ROI_voxel-contrasts_LeftHippocampus.txt already exists,f9bfe036e0543615da533e449f21ef2f, copy:1
# 200331-20:48:20,891 nipype.workflow DEBUG:
# 	 output: out_file
# 200331-20:48:20,893 nipype.workflow DEBUG:
# 	 [Node] register_qt12 - setting input reference = /Volumes/group/proc/TIGERanalysis/qT1/workflow/hippdata_flow/_subject_id_44-T1/convert_wb/brain.nii.gz
