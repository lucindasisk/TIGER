# %%
from nipype.interfaces.io import DataSink, SelectFiles, DataGrabber 
from nipype.interfaces.utility import IdentityInterface, Function    
from nipype.pipeline.engine import Node, Workflow, JoinNode, MapNode
from nipype.interfaces import fsl
from nipype.interfaces import freesurfer as fsr
from nipype.interfaces import brainsuite
from nipype.interfaces.io import SelectFiles, DataSink, DataGrabber
from shutil import copyfile
import pandas as pd
from glob import glob
from os.path import abspath, expanduser, join
from os import chdir, remove, getcwd
from nipype import config, logging
from datetime import date
today = str(date.today())
config.enable_debug_mode()

# %%
#Set variables
# subject_list = ['02-T2', '06-T1', '07-T2','08-T1', '09-T2', '10-T1', '11-T1', '12-T1', '13-T1', '15-T1', '16-T1', '17-T1',
#                 '18-T1', '19-T1', '20-T1', '21-T1', '22-T1', '23-T1', '24-T1', '29-T1', '30-T1', '31-T1', '32-T1',
#                 '35-T1', '36-T1', '37-T1', '38-T1', '40-T1', '102-T1', '103-T1', '104-T1', '105-T1', '106-T1', '107-T1', '108-T1', '109-T1',
#                 '110-T1', '111-T1']

subject_list = ['17-T1', '16-T1'] # '02-T2']#, '20-T1','22-T1','29-T1','31-T1','35-T1']
#subject_list = ['123-T1', '124-T1']#, '20-T1','22-T1','29-T1','31-T1','35-T1']

home = '/Users/lucindasisk/Documents/qT1'
fpath = home + '/subjDir'
workflow_dir = home + '/workflow'
data_dir = home + '/data'
data = home + '/flywheel_subjDir'

# subs = glob(data + '/*-*')
# subject_list = pd.Series(subs).str.replace(data + '/', '')
# subject_list

subs = pd.read_csv(home + '/files/Gsheet_QCDONE_finalSubjList_10.22.20.csv', header=0)
#subject_list = subs['ID'].tolist()

#subject_list = ['097-T3']

# %%
#Setup Datasink, Infosource, Selectfiles

datasink = Node(DataSink(base_directory = data_dir,
                        substitutions=[('_subject_id_', '')]),
                   name='datasink')

#Set infosource iterables
infosource = Node(IdentityInterface(fields=['subject_id']),
                  name="infosource")
infosource.iterables = [('subject_id', subject_list)]

#SelectFiles
template = dict(t1 = fpath + '/{subject_id}/T1_acpc.nii.gz',
               qt1 = data + '/{subject_id}/fw_qT1_t1fit_final.nii.gz')

sf = Node(SelectFiles(template, 
                      base_directory = fpath),
          name = 'sf')

# %%
#Skullstrip T1w image
stripT1 = Node(fsl.BET(out_file = 'T1_acpc_bet.nii.gz'),
             name = 'stripT1')

#Reorient qT1 to standard orientation
reorient = Node(fsl.Reorient2Std(out_file = 'reoriented_qT1.nii.gz',
                              output_type = 'NIFTI_GZ'),
                    name = 'reorient')

#Register qT1 to T1w
register_qt1 = Node(fsl.FLIRT(out_file = 'registered_qT1_T1acpc.nii.gz',
                              output_type = 'NIFTI_GZ',
                              out_matrix_file = 'flirt_transform_qt1.mat'),
                    name = 'register_qt1')

#Extract voxel values from qT1 beneath overlaid mask - Left Uncinate
get_voxLUF = Node(fsl.ImageMeants(show_all = True,
                               out_file = 'ROI_voxel-contrasts_LeftUF.txt'),
               name = 'get_voxLUF')

#Extract voxel values from qT1 beneath overlaid mask - Right Uncinate
get_voxRUF = Node(fsl.ImageMeants(show_all = True,
                               out_file = 'ROI_voxel-contrasts_RightUF.txt'),
               name = 'get_voxRUF')

#Extract voxel values from qT1 beneath overlaid mask - Left Cingulum Cingulate
get_voxLCC = Node(fsl.ImageMeants(show_all = True,
                               out_file = 'ROI_voxel-contrasts_LeftCC.txt'),
               name = 'get_voxLCC')

#Extract voxel values from qT1 beneath overlaid mask - Right Cingulum Cingulate
get_voxRCC = Node(fsl.ImageMeants(show_all = True,
                               out_file = 'ROI_voxel-contrasts_RightCC.txt'),
               name = 'get_voxRCC')

#Extract voxel values from qT1 beneath overlaid mask - Left Corticosponal
get_voxLCST = Node(fsl.ImageMeants(show_all = True,
                               out_file = 'ROI_voxel-contrasts_LeftCST.txt'),
               name = 'get_voxLCST')

#Extract voxel values from qT1 beneath overlaid mask - Right Corticospinal
get_voxRCST = Node(fsl.ImageMeants(show_all = True,
                               out_file = 'ROI_voxel-contrasts_RightCST.txt'),
               name = 'get_voxRCST')

# %%
qt1proc_flow = Workflow(name='qt1proc_flow')
qt1proc_flow.connect([(infosource, sf, [('subject_id', 'subject_id')]),
                      (sf, stripT1, [('t1', 'in_file')]),
                      (stripT1, datasink, [('out_file', '1_check_alignment')]),
                      (sf, reorient, [('qt1', 'in_file')]),
                      (reorient, datasink, [
                       ('out_file', '1_check_alignment.@par')]),
                      (reorient, register_qt1, [('out_file', 'in_file')]),
                      (stripT1, register_qt1, [('out_file', 'reference')]),
                      (register_qt1, datasink, [
                       ('out_file', '1_check_alignment.@par.@par')])
                      ])

qt1proc_flow.base_dir = workflow_dir
qt1proc_flow.write_graph(graph2use='flat')
preproc = qt1proc_flow.run('MultiProc', plugin_args={'n_procs': 4})

# %%
#SelectFiles
template2 = dict(qt1r=data_dir+'/1_check_alignment/{subject_id}/registered_qT1_T1acpc.nii.gz',
               unc_maskL = fpath+'/{subject_id}/Left_Uncinate.nii.gz',
               unc_maskR = fpath+'/{subject_id}/Right_Uncinate.nii.gz',
               cc_maskL = fpath+'/{subject_id}/Left_Cingulum_Cingulate.nii.gz',
               cc_maskR = fpath+'/{subject_id}/Right_Cingulum_Cingulate.nii.gz',
               cst_maskL = fpath+'/{subject_id}/Left_Corticospinal.nii.gz',
               cst_maskR = fpath+'/{subject_id}/Right_Corticospinal.nii.gz')

# 
#             bval=fpath+'/{subject_id}/dti.bval',
#             bvec=fpath+'/{subject_id}/dti.bvec'

sf2 = Node(SelectFiles(template2, 
                      base_directory = fpath),
          name = 'sf2')

# %%
get_stats=Workflow(name='get_stats')
get_stats.connect([(infosource, sf2, [('subject_id','subject_id')]),
                   #Left UF
                   (sf2, get_voxLUF, [('qt1r', 'in_file')]),
                   (sf2, get_voxLUF, [('unc_maskL', 'mask')]),
                   (get_voxLUF, datasink, [('out_file', '2_Extracted_Stats')]),
                   #Left Cingulum
                   (sf2, get_voxLCC, [('qt1r', 'in_file')]),
                   (sf2, get_voxLCC, [('cc_maskL', 'mask')]),
                   (get_voxLCC, datasink, [('out_file', '2_Extracted_Stats.@par')]),
                   #Left Corticospinal
                   (sf2, get_voxLCST, [('qt1r', 'in_file')]),
                   (sf2, get_voxLCST, [('cst_maskL', 'mask')]),
                   (get_voxLCST, datasink, [('out_file', '2_Extracted_Stats.@par.@par')]),
                   #Right UF
                   (sf2, get_voxRUF, [('qt1r', 'in_file')]),
                   (sf2, get_voxRUF, [('unc_maskR', 'mask')]),
                   (get_voxRUF, datasink, [('out_file', '2_Extracted_Stats.@par.@par.@par')]),
                   #Right Cingulum
                   (sf2, get_voxRCC, [('qt1r', 'in_file')]),
                   (sf2, get_voxRCC, [('cc_maskR', 'mask')]),
                   (get_voxRCC, datasink, [('out_file', '2_Extracted_Stats.@par.@par.@par.@par')]),
                   #Right Corticospinal
                   (sf2, get_voxRCST, [('qt1r', 'in_file')]),
                   (sf2, get_voxRCST, [('cst_maskR', 'mask')]),
                   (get_voxRCST, datasink, [('out_file', '2_Extracted_Stats.@par.@par.@par.@par.@par')])
                  ])
get_stats.base_dir = workflow_dir
get_stats.write_graph(graph2use = 'flat')
preproc = get_stats.run('MultiProc', plugin_args={'n_procs': 4})
# Out:
# 201022-12:52:36,614 nipype.workflow DEBUG:
# 	 (get_stats.infosource, get_stats.sf2): No edge data
# 201022-12:52:36,615 nipype.workflow DEBUG:
# 	 (get_stats.infosource, get_stats.sf2): new edge data: {'connect': [('subject_id', 'subject_id')]}
# 201022-12:52:36,616 nipype.workflow DEBUG:
# 	 (get_stats.sf2, get_stats.get_voxLUF): No edge data
# 201022-12:52:36,617 nipype.workflow DEBUG:
# 	 (get_stats.sf2, get_stats.get_voxLUF): new edge data: {'connect': [('qt1r', 'in_file')]}
# 201022-12:52:36,617 nipype.workflow DEBUG:
# 	 (get_stats.sf2, get_stats.get_voxLUF): Edge data exists: {'connect': [('qt1r', 'in_file')]}
# 201022-12:52:36,618 nipype.workflow DEBUG:
# 	 (get_stats.sf2, get_stats.get_voxLUF): new edge data: {'connect': [('qt1r', 'in_file'), ('unc_maskL', 'mask')]}
# 201022-12:52:36,619 nipype.workflow DEBUG:
# 	 (get_stats.get_voxLUF, get_stats.datasink): No edge data
# 201022-12:52:36,619 nipype.workflow DEBUG:
# 	 (get_stats.get_voxLUF, get_stats.datasink): new edge data: {'connect': [('out_file', '2_Extracted_Stats')]}
# 201022-12:52:36,620 nipype.workflow DEBUG:
# 	 (get_stats.sf2, get_stats.get_voxLCC): No edge data
# 201022-12:52:36,620 nipype.workflow DEBUG:
# 	 (get_stats.sf2, get_stats.get_voxLCC): new edge data: {'connect': [('qt1r', 'in_file')]}
# 201022-12:52:36,621 nipype.workflow DEBUG:
# 	 (get_stats.sf2, get_stats.get_voxLCC): Edge data exists: {'connect': [('qt1r', 'in_file')]}
# 201022-12:52:36,621 nipype.workflow DEBUG:
# 	 (get_stats.sf2, get_stats.get_voxLCC): new edge data: {'connect': [('qt1r', 'in_file'), ('cc_maskL', 'mask')]}
# 201022-12:52:36,622 nipype.workflow DEBUG:
# 	 (get_stats.get_voxLCC, get_stats.datasink): No edge data
# 201022-12:52:36,623 nipype.workflow DEBUG:
# 	 (get_stats.get_voxLCC, get_stats.datasink): new edge data: {'connect': [('out_file', '2_Extracted_Stats.@par')]}
# 201022-12:52:36,623 nipype.workflow DEBUG:
# 	 (get_stats.sf2, get_stats.get_voxLCST): No edge data
# 201022-12:52:36,624 nipype.workflow DEBUG:
# 	 (get_stats.sf2, get_stats.get_voxLCST): new edge data: {'connect': [('qt1r', 'in_file')]}
# 201022-12:52:36,624 nipype.workflow DEBUG:
# 	 (get_stats.sf2, get_stats.get_voxLCST): Edge data exists: {'connect': [('qt1r', 'in_file')]}
# 201022-12:52:36,625 nipype.workflow DEBUG:
# 	 (get_stats.sf2, get_stats.get_voxLCST): new edge data: {'connect': [('qt1r', 'in_file'), ('cst_maskL', 'mask')]}
# 201022-12:52:36,625 nipype.workflow DEBUG:
# 	 (get_stats.get_voxLCST, get_stats.datasink): No edge data
# 201022-12:52:36,626 nipype.workflow DEBUG:
# 	 (get_stats.get_voxLCST, get_stats.datasink): new edge data: {'connect': [('out_file', '2_Extracted_Stats.@par.@par')]}
# 201022-12:52:36,627 nipype.workflow DEBUG:
# 	 (get_stats.sf2, get_stats.get_voxRUF): No edge data
# 201022-12:52:36,627 nipype.workflow DEBUG:
# 	 (get_stats.sf2, get_stats.get_voxRUF): new edge data: {'connect': [('qt1r', 'in_file')]}
# 201022-12:52:36,628 nipype.workflow DEBUG:
# 	 (get_stats.sf2, get_stats.get_voxRUF): Edge data exists: {'connect': [('qt1r', 'in_file')]}
# 201022-12:52:36,628 nipype.workflow DEBUG:
# 	 (get_stats.sf2, get_stats.get_voxRUF): new edge data: {'connect': [('qt1r', 'in_file'), ('unc_maskR', 'mask')]}
# 201022-12:52:36,629 nipype.workflow DEBUG:
# 	 (get_stats.get_voxRUF, get_stats.datasink): No edge data
# 201022-12:52:36,629 nipype.workflow DEBUG:
# 	 (get_stats.get_voxRUF, get_stats.datasink): new edge data: {'connect': [('out_file', '2_Extracted_Stats.@par.@par.@par')]}
# 201022-12:52:36,630 nipype.workflow DEBUG:
# 	 (get_stats.sf2, get_stats.get_voxRCC): No edge data
# 201022-12:52:36,631 nipype.workflow DEBUG:
# 	 (get_stats.sf2, get_stats.get_voxRCC): new edge data: {'connect': [('qt1r', 'in_file')]}
# 201022-12:52:36,631 nipype.workflow DEBUG:
# 	 (get_stats.sf2, get_stats.get_voxRCC): Edge data exists: {'connect': [('qt1r', 'in_file')]}
# 201022-12:52:36,632 nipype.workflow DEBUG:
# 	 (get_stats.sf2, get_stats.get_voxRCC): new edge data: {'connect': [('qt1r', 'in_file'), ('cc_maskR', 'mask')]}
# 201022-12:52:36,632 nipype.workflow DEBUG:
# 	 (get_stats.get_voxRCC, get_stats.datasink): No edge data
# 201022-12:52:36,633 nipype.workflow DEBUG:
# 	 (get_stats.get_voxRCC, get_stats.datasink): new edge data: {'connect': [('out_file', '2_Extracted_Stats.@par.@par.@par.@par')]}
# 201022-12:52:36,633 nipype.workflow DEBUG:
# 	 (get_stats.sf2, get_stats.get_voxRCST): No edge data
# 201022-12:52:36,634 nipype.workflow DEBUG:
# 	 (get_stats.sf2, get_stats.get_voxRCST): new edge data: {'connect': [('qt1r', 'in_file')]}
# 201022-12:52:36,634 nipype.workflow DEBUG:
# 	 (get_stats.sf2, get_stats.get_voxRCST): Edge data exists: {'connect': [('qt1r', 'in_file')]}
# 201022-12:52:36,635 nipype.workflow DEBUG:
# 	 (get_stats.sf2, get_stats.get_voxRCST): new edge data: {'connect': [('qt1r', 'in_file'), ('cst_maskR', 'mask')]}
# 201022-12:52:36,635 nipype.workflow DEBUG:
# 	 (get_stats.get_voxRCST, get_stats.datasink): No edge data
# 201022-12:52:36,636 nipype.workflow DEBUG:
# 	 (get_stats.get_voxRCST, get_stats.datasink): new edge data: {'connect': [('out_file', '2_Extracted_Stats.@par.@par.@par.@par.@par')]}
# 201022-12:52:36,637 nipype.workflow DEBUG:
# 	 Creating flat graph for workflow: get_stats
# 201022-12:52:36,641 nipype.workflow DEBUG:
# 	 expanding workflow: get_stats
# 201022-12:52:36,641 nipype.workflow DEBUG:
# 	 processing node: get_stats.infosource
# 201022-12:52:36,642 nipype.workflow DEBUG:
# 	 processing node: get_stats.sf2
# 201022-12:52:36,643 nipype.workflow DEBUG:
# 	 processing node: get_stats.get_voxRCST
# 201022-12:52:36,643 nipype.workflow DEBUG:
# 	 processing node: get_stats.get_voxRCC
# 201022-12:52:36,644 nipype.workflow DEBUG:
# 	 processing node: get_stats.get_voxRUF
# 201022-12:52:36,644 nipype.workflow DEBUG:
# 	 processing node: get_stats.get_voxLCST
# 201022-12:52:36,645 nipype.workflow DEBUG:
# 	 processing node: get_stats.get_voxLCC
# 201022-12:52:36,645 nipype.workflow DEBUG:
# 	 processing node: get_stats.get_voxLUF
# 201022-12:52:36,646 nipype.workflow DEBUG:
# 	 processing node: get_stats.datasink
# 201022-12:52:36,646 nipype.workflow DEBUG:
# 	 finished expanding workflow: get_stats
# 201022-12:52:36,650 nipype.workflow DEBUG:
# 	 using input graph
# 201022-12:52:37,27 nipype.workflow DEBUG:
# 	 creating dot graph
# 201022-12:52:37,349 nipype.workflow INFO:
# 	 Generated workflow graph: /Users/lucindasisk/Documents/qT1/workflow/get_stats/graph.png (graph2use=flat, simple_form=True).
# 201022-12:52:37,361 nipype.workflow DEBUG:
# 	 [MultiProc] Starting (n_procs=4, mem_gb=28.80, cwd=/Users/lucindasisk/Dropbox/Github/TIGER_qT1_Tracts)
# 201022-12:52:37,363 nipype.workflow DEBUG:
# 	 Creating flat graph for workflow: get_stats
# 201022-12:52:37,368 nipype.workflow DEBUG:
# 	 expanding workflow: get_stats
# 201022-12:52:37,369 nipype.workflow DEBUG:
# 	 processing node: get_stats.infosource
# 201022-12:52:37,371 nipype.workflow DEBUG:
# 	 processing node: get_stats.sf2
# 201022-12:52:37,372 nipype.workflow DEBUG:
# 	 processing node: get_stats.get_voxRCST
# 201022-12:52:37,372 nipype.workflow DEBUG:
# 	 processing node: get_stats.get_voxRCC
# 201022-12:52:37,373 nipype.workflow DEBUG:
# 	 processing node: get_stats.get_voxRUF
# 201022-12:52:37,374 nipype.workflow DEBUG:
# 	 processing node: get_stats.get_voxLCST
# 201022-12:52:37,374 nipype.workflow DEBUG:
# 	 processing node: get_stats.get_voxLCC
# 201022-12:52:37,375 nipype.workflow DEBUG:
# 	 processing node: get_stats.get_voxLUF
# 201022-12:52:37,376 nipype.workflow DEBUG:
# 	 processing node: get_stats.datasink
# 201022-12:52:37,377 nipype.workflow DEBUG:
# 	 finished expanding workflow: get_stats
# 201022-12:52:37,377 nipype.workflow INFO:
# 	 Workflow get_stats settings: ['check', 'execution', 'logging', 'monitoring']
# 201022-12:52:37,382 nipype.workflow DEBUG:
# 	 PE: expanding iterables
# 201022-12:52:37,383 nipype.workflow DEBUG:
# 	 Detected iterable nodes [get_stats.infosource]
# 201022-12:52:37,383 nipype.workflow DEBUG:
# 	 Expanding the iterable node get_stats.infosource...
# 201022-12:52:37,384 nipype.workflow DEBUG:
# 	 node: get_stats.infosource iterables: {'subject_id': <function _standardize_iterables.<locals>.make_field_func.<locals>.<lambda> at 0x7f85690f49e0>}
# 201022-12:52:37,385 nipype.workflow DEBUG:
# 	 ('subnodes:', [get_stats.infosource, get_stats.sf2, get_stats.get_voxLUF, get_stats.datasink, get_stats.get_voxLCC, get_stats.get_voxLCST, get_stats.get_voxRUF, get_stats.get_voxRCC, get_stats.get_voxRCST])
# 201022-12:52:37,392 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input subject_id = 17-T1
# 201022-12:52:37,393 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_subject_id_17-T1
# 201022-12:52:37,397 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input subject_id = 16-T1
# 201022-12:52:37,398 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_subject_id_16-T1
# 201022-12:52:37,402 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input subject_id = 15-T1
# 201022-12:52:37,403 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_subject_id_15-T1
# 201022-12:52:37,409 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input subject_id = 13-T1
# 201022-12:52:37,409 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_subject_id_13-T1
# 201022-12:52:37,414 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input subject_id = 12-T1
# 201022-12:52:37,414 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_subject_id_12-T1
# 201022-12:52:37,418 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input subject_id = 11-T1
# 201022-12:52:37,419 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_subject_id_11-T1
# 201022-12:52:37,424 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input subject_id = 10-T1
# 201022-12:52:37,425 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_subject_id_10-T1
# 201022-12:52:37,430 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input subject_id = 09-T2
# 201022-12:52:37,430 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_subject_id_09-T2
# 201022-12:52:37,435 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input subject_id = 08-T1
# 201022-12:52:37,435 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_subject_id_08-T1
# 201022-12:52:37,440 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input subject_id = 07-T2
# 201022-12:52:37,442 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_subject_id_07-T2
# 201022-12:52:37,446 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input subject_id = 06-T1
# 201022-12:52:37,446 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_subject_id_06-T1
# 201022-12:52:37,450 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input subject_id = 02-T2
# 201022-12:52:37,451 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_subject_id_02-T2
# 201022-12:52:37,453 nipype.workflow DEBUG:
# 	 PE: expanding iterables ... done
# 201022-12:52:37,455 nipype.workflow DEBUG:
# 	 [Node] sf2 - setting input subject_id = 02-T2
# 201022-12:52:37,456 nipype.workflow DEBUG:
# 	 Removed the identity node get_stats.infosource from the graph.
# 201022-12:52:37,456 nipype.workflow DEBUG:
# 	 [Node] sf2 - setting input subject_id = 06-T1
# 201022-12:52:37,457 nipype.workflow DEBUG:
# 	 Removed the identity node get_stats.infosource from the graph.
# 201022-12:52:37,458 nipype.workflow DEBUG:
# 	 [Node] sf2 - setting input subject_id = 07-T2
# 201022-12:52:37,459 nipype.workflow DEBUG:
# 	 Removed the identity node get_stats.infosource from the graph.
# 201022-12:52:37,459 nipype.workflow DEBUG:
# 	 [Node] sf2 - setting input subject_id = 08-T1
# 201022-12:52:37,460 nipype.workflow DEBUG:
# 	 Removed the identity node get_stats.infosource from the graph.
# 201022-12:52:37,461 nipype.workflow DEBUG:
# 	 [Node] sf2 - setting input subject_id = 09-T2
# 201022-12:52:37,461 nipype.workflow DEBUG:
# 	 Removed the identity node get_stats.infosource from the graph.
# 201022-12:52:37,462 nipype.workflow DEBUG:
# 	 [Node] sf2 - setting input subject_id = 10-T1
# 201022-12:52:37,463 nipype.workflow DEBUG:
# 	 Removed the identity node get_stats.infosource from the graph.
# 201022-12:52:37,463 nipype.workflow DEBUG:
# 	 [Node] sf2 - setting input subject_id = 11-T1
# 201022-12:52:37,464 nipype.workflow DEBUG:
# 	 Removed the identity node get_stats.infosource from the graph.
# 201022-12:52:37,465 nipype.workflow DEBUG:
# 	 [Node] sf2 - setting input subject_id = 12-T1
# 201022-12:52:37,465 nipype.workflow DEBUG:
# 	 Removed the identity node get_stats.infosource from the graph.
# 201022-12:52:37,466 nipype.workflow DEBUG:
# 	 [Node] sf2 - setting input subject_id = 13-T1
# 201022-12:52:37,466 nipype.workflow DEBUG:
# 	 Removed the identity node get_stats.infosource from the graph.
# 201022-12:52:37,467 nipype.workflow DEBUG:
# 	 [Node] sf2 - setting input subject_id = 15-T1
# 201022-12:52:37,468 nipype.workflow DEBUG:
# 	 Removed the identity node get_stats.infosource from the graph.
# 201022-12:52:37,468 nipype.workflow DEBUG:
# 	 [Node] sf2 - setting input subject_id = 16-T1
# 201022-12:52:37,469 nipype.workflow DEBUG:
# 	 Removed the identity node get_stats.infosource from the graph.
# 201022-12:52:37,469 nipype.workflow DEBUG:
# 	 [Node] sf2 - setting input subject_id = 17-T1
# 201022-12:52:37,470 nipype.workflow DEBUG:
# 	 Removed the identity node get_stats.infosource from the graph.
# 201022-12:52:37,506 nipype.workflow DEBUG:
# 	 Performing depth first search
# 201022-12:52:37,519 nipype.workflow INFO:
# 	 Running in parallel.
# 201022-12:52:37,523 nipype.workflow DEBUG:
# 	 Progress: 96 jobs, 0/0/12 (done/running/ready), 0/96 (pending_tasks/waiting).
# 201022-12:52:37,524 nipype.workflow DEBUG:
# 	 Tasks currently running: 0. Pending: 0.
# 201022-12:52:37,525 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 12 jobs ready. Free memory (GB): 28.80/28.80, Free processors: 4/4.
# 201022-12:52:37,586 nipype.workflow DEBUG:
# 	 Allocating get_stats.sf2 ID=0 (0.20GB, 1 threads). Free: 28.60GB, 3 threads.
# 201022-12:52:37,587 nipype.workflow DEBUG:
# 	 [Node] Not cached "/Users/lucindasisk/Documents/qT1/workflow/get_stats/_subject_id_02-T2/sf2".
# 201022-12:52:37,588 nipype.workflow DEBUG:
# 	 Checking hash "get_stats.sf2" locally: cached=False, updated=False.
# 201022-12:52:37,607 nipype.workflow DEBUG:
# 	 [MultiProc] Submitted task get_stats.sf2 (taskid=1).
# 201022-12:52:37,612 nipype.workflow DEBUG:
# 	 Allocating get_stats.sf2 ID=8 (0.20GB, 1 threads). Free: 28.40GB, 2 threads.
# 201022-12:52:37,613 nipype.workflow DEBUG:
# 	 [Node] Not cached "/Users/lucindasisk/Documents/qT1/workflow/get_stats/_subject_id_06-T1/sf2".
# 201022-12:52:37,614 nipype.workflow DEBUG:
# 	 Checking hash "get_stats.sf2" locally: cached=False, updated=False.
# 201022-12:52:37,616 nipype.workflow DEBUG:
# 	 [MultiProc] Submitted task get_stats.sf2 (taskid=2).
# 201022-12:52:37,614 nipype.workflow INFO:
# 	 [Node] Setting-up "get_stats.sf2" in "/Users/lucindasisk/Documents/qT1/workflow/get_stats/_subject_id_02-T2/sf2".
# 201022-12:52:37,618 nipype.workflow DEBUG:
# 	 Allocating get_stats.sf2 ID=16 (0.20GB, 1 threads). Free: 28.20GB, 1 threads.
# 201022-12:52:37,620 nipype.workflow DEBUG:
# 	 [Node] Not cached "/Users/lucindasisk/Documents/qT1/workflow/get_stats/_subject_id_07-T2/sf2".
# 201022-12:52:37,621 nipype.workflow DEBUG:
# 	 Checking hash "get_stats.sf2" locally: cached=False, updated=False.
# 201022-12:52:37,619 nipype.workflow DEBUG:
# 	 [Node] Not cached "/Users/lucindasisk/Documents/qT1/workflow/get_stats/_subject_id_02-T2/sf2".
# 201022-12:52:37,623 nipype.workflow DEBUG:
# 	 [MultiProc] Submitted task get_stats.sf2 (taskid=3).
# 201022-12:52:37,619 nipype.workflow INFO:
# 	 [Node] Setting-up "get_stats.sf2" in "/Users/lucindasisk/Documents/qT1/workflow/get_stats/_subject_id_06-T1/sf2".
# 201022-12:52:37,625 nipype.workflow DEBUG:
# 	 Allocating get_stats.sf2 ID=24 (0.20GB, 1 threads). Free: 28.00GB, 0 threads.
# 201022-12:52:37,624 nipype.utils DEBUG:
# 	 Removing contents of /Users/lucindasisk/Documents/qT1/workflow/get_stats/_subject_id_02-T2/sf2
# 201022-12:52:37,626 nipype.workflow DEBUG:
# 	 [Node] Not cached "/Users/lucindasisk/Documents/qT1/workflow/get_stats/_subject_id_08-T1/sf2".
# 201022-12:52:37,624 nipype.workflow DEBUG:
# 	 [Node] Not cached "/Users/lucindasisk/Documents/qT1/workflow/get_stats/_subject_id_06-T1/sf2".
# 201022-12:52:37,627 nipype.workflow DEBUG:
# 	 Checking hash "get_stats.sf2" locally: cached=False, updated=False.
# 201022-12:52:37,628 nipype.utils DEBUG:
# 	 Removing contents of /Users/lucindasisk/Documents/qT1/workflow/get_stats/_subject_id_06-T1/sf2
# 201022-12:52:37,630 nipype.workflow DEBUG:
# 	 [MultiProc] Submitted task get_stats.sf2 (taskid=4).
# 201022-12:52:37,627 nipype.workflow INFO:
# 	 [Node] Setting-up "get_stats.sf2" in "/Users/lucindasisk/Documents/qT1/workflow/get_stats/_subject_id_07-T2/sf2".
# 201022-12:52:37,628 nipype.workflow DEBUG:
# 	 [Node] Writing pre-exec report to "/Users/lucindasisk/Documents/qT1/workflow/get_stats/_subject_id_02-T2/sf2/_report/report.rst"
# 201022-12:52:37,632 nipype.workflow DEBUG:
# 	 Cannot allocate job 32 (0.20GB, 1 threads).
# 201022-12:52:37,633 nipype.workflow DEBUG:
# 	 Cannot allocate job 40 (0.20GB, 1 threads).
# 201022-12:52:37,632 nipype.workflow DEBUG:
# 	 [Node] Writing pre-exec report to "/Users/lucindasisk/Documents/qT1/workflow/get_stats/_subject_id_06-T1/sf2/_report/report.rst"
# 201022-12:52:37,634 nipype.workflow DEBUG:
# 	 Cannot allocate job 48 (0.20GB, 1 threads).
# 201022-12:52:37,632 nipype.workflow DEBUG:
# 	 [Node] Not cached "/Users/lucindasisk/Documents/qT1/workflow/get_stats/_subject_id_07-T2/sf2".
# 201022-12:52:37,636 nipype.workflow DEBUG:
# 	 Cannot allocate job 56 (0.20GB, 1 threads).
# 201022-12:52:37,635 nipype.workflow INFO:
# 	 [Node] Running "sf2" ("nipype.interfaces.io.SelectFiles")
# 201022-12:52:37,637 nipype.workflow DEBUG:
# 	 Cannot allocate job 64 (0.20GB, 1 threads).
# 201022-12:52:37,638 nipype.workflow DEBUG:
# 	 Cannot allocate job 72 (0.20GB, 1 threads).
# 201022-12:52:37,637 nipype.utils DEBUG:
# 	 Removing contents of /Users/lucindasisk/Documents/qT1/workflow/get_stats/_subject_id_07-T2/sf2
# 201022-12:52:37,635 nipype.workflow INFO:
# 	 [Node] Setting-up "get_stats.sf2" in "/Users/lucindasisk/Documents/qT1/workflow/get_stats/_subject_id_08-T1/sf2".
# 201022-12:52:37,640 nipype.workflow DEBUG:
# 	 Cannot allocate job 80 (0.20GB, 1 threads).
# 201022-12:52:37,638 nipype.workflow INFO:
# 	 [Node] Running "sf2" ("nipype.interfaces.io.SelectFiles")
# 201022-12:52:37,642 nipype.workflow DEBUG:
# 	 Cannot allocate job 88 (0.20GB, 1 threads).
# 201022-12:52:37,641 nipype.workflow DEBUG:
# 	 [Node] Not cached "/Users/lucindasisk/Documents/qT1/workflow/get_stats/_subject_id_08-T1/sf2".
# 201022-12:52:37,642 nipype.workflow DEBUG:
# 	 [Node] Writing pre-exec report to "/Users/lucindasisk/Documents/qT1/workflow/get_stats/_subject_id_07-T2/sf2/_report/report.rst"
# 201022-12:52:37,647 nipype.utils DEBUG:
# 	 Removing contents of /Users/lucindasisk/Documents/qT1/workflow/get_stats/_subject_id_08-T1/sf2
# 201022-12:52:37,650 nipype.workflow INFO:
# 	 [Node] Running "sf2" ("nipype.interfaces.io.SelectFiles")
# 201022-12:52:37,652 nipype.workflow DEBUG:
# 	 Needed files: /Users/lucindasisk/Documents/qT1/data/1_check_alignment/02-T2/registered_qT1_T1acpc.nii.gz;/Users/lucindasisk/Documents/qT1/subjDir/02-T2/Left_Uncinate.nii.gz;/Users/lucindasisk/Documents/qT1/subjDir/02-T2/Right_Uncinate.nii.gz;/Users/lucindasisk/Documents/qT1/subjDir/02-T2/Left_Cingulum_Cingulate.nii.gz;/Users/lucindasisk/Documents/qT1/subjDir/02-T2/Right_Cingulum_Cingulate.nii.gz;/Users/lucindasisk/Documents/qT1/subjDir/02-T2/Left_Corticospinal.nii.gz;/Users/lucindasisk/Documents/qT1/subjDir/02-T2/Right_Corticospinal.nii.gz;/Users/lucindasisk/Documents/qT1/workflow/get_stats/_subject_id_02-T2/sf2/_0xfd70c5f9d1ec980e8251df8af289c201_unfinished.json;/Users/lucindasisk/Documents/qT1/workflow/get_stats/_subject_id_02-T2/sf2/_inputs.pklz;/Users/lucindasisk/Documents/qT1/workflow/get_stats/_subject_id_02-T2/sf2/_node.pklz
# 201022-12:52:37,655 nipype.workflow DEBUG:
# 	 Needed dirs: /Users/lucindasisk/Documents/qT1/workflow/get_stats/_subject_id_02-T2/sf2/_report
# 201022-12:52:37,655 nipype.workflow DEBUG:
# 	 [Node] Writing pre-exec report to "/Users/lucindasisk/Documents/qT1/workflow/get_stats/_subject_id_08-T1/sf2/_report/report.rst"
# 201022-12:52:37,655 nipype.workflow DEBUG:
# 	 Needed files: /Users/lucindasisk/Documents/qT1/data/1_check_alignment/06-T1/registered_qT1_T1acpc.nii.gz;/Users/lucindasisk/Documents/qT1/subjDir/06-T1/Left_Uncinate.nii.gz;/Users/lucindasisk/Documents/qT1/subjDir/06-T1/Right_Uncinate.nii.gz;/Users/lucindasisk/Documents/qT1/subjDir/06-T1/Left_Cingulum_Cingulate.nii.gz;/Users/lucindasisk/Documents/qT1/subjDir/06-T1/Right_Cingulum_Cingulate.nii.gz;/Users/lucindasisk/Documents/qT1/subjDir/06-T1/Left_Corticospinal.nii.gz;/Users/lucindasisk/Documents/qT1/subjDir/06-T1/Right_Corticospinal.nii.gz;/Users/lucindasisk/Documents/qT1/workflow/get_stats/_subject_id_06-T1/sf2/_0xfa735424226c4b3141d162586adcd08b_unfinished.json;/Users/lucindasisk/Documents/qT1/workflow/get_stats/_subject_id_06-T1/sf2/_inputs.pklz;/Users/lucindasisk/Documents/qT1/workflow/get_stats/_subject_id_06-T1/sf2/_node.pklz
# 201022-12:52:37,658 nipype.workflow DEBUG:
# 	 Needed dirs: /Users/lucindasisk/Documents/qT1/workflow/get_stats/_subject_id_06-T1/sf2/_report
# 201022-12:52:37,658 nipype.workflow DEBUG:
# 	 Removing files:
# 201022-12:52:37,661 nipype.workflow DEBUG:
# 	 Removing files:
# 201022-12:52:37,661 nipype.workflow DEBUG:
# 	 Saving results file: '/Users/lucindasisk/Documents/qT1/workflow/get_stats/_subject_id_02-T2/sf2/result_sf2.pklz'
# 201022-12:52:37,662 nipype.workflow INFO:
# 	 [Node] Running "sf2" ("nipype.interfaces.io.SelectFiles")
# 201022-12:52:37,663 nipype.workflow DEBUG:
# 	 Saving results file: '/Users/lucindasisk/Documents/qT1/workflow/get_stats/_subject_id_06-T1/sf2/result_sf2.pklz'
# 201022-12:52:37,665 nipype.workflow DEBUG:
# 	 Needed files: /Users/lucindasisk/Documents/qT1/data/1_check_alignment/07-T2/registered_qT1_T1acpc.nii.gz;/Users/lucindasisk/Documents/qT1/subjDir/07-T2/Left_Uncinate.nii.gz;/Users/lucindasisk/Documents/qT1/subjDir/07-T2/Right_Uncinate.nii.gz;/Users/lucindasisk/Documents/qT1/subjDir/07-T2/Left_Cingulum_Cingulate.nii.gz;/Users/lucindasisk/Documents/qT1/subjDir/07-T2/Right_Cingulum_Cingulate.nii.gz;/Users/lucindasisk/Documents/qT1/subjDir/07-T2/Left_Corticospinal.nii.gz;/Users/lucindasisk/Documents/qT1/subjDir/07-T2/Right_Corticospinal.nii.gz;/Users/lucindasisk/Documents/qT1/workflow/get_stats/_subject_id_07-T2/sf2/_0xb0cd43dc4caf45d308f01871b978b734_unfinished.json;/Users/lucindasisk/Documents/qT1/workflow/get_stats/_subject_id_07-T2/sf2/_inputs.pklz;/Users/lucindasisk/Documents/qT1/workflow/get_stats/_subject_id_07-T2/sf2/_node.pklz
# 201022-12:52:37,665 nipype.workflow DEBUG:
# 	 [Node] Writing post-exec report to "/Users/lucindasisk/Documents/qT1/workflow/get_stats/_subject_id_02-T2/sf2/_report/report.rst"
# 201022-12:52:37,668 nipype.workflow DEBUG:
# 	 Needed dirs: /Users/lucindasisk/Documents/qT1/workflow/get_stats/_subject_id_07-T2/sf2/_report
# 201022-12:52:37,668 nipype.workflow DEBUG:
# 	 [Node] Writing post-exec report to "/Users/lucindasisk/Documents/qT1/workflow/get_stats/_subject_id_06-T1/sf2/_report/report.rst"
# 201022-12:52:37,669 nipype.workflow INFO:
# 	 [Node] Finished "get_stats.sf2".
# 201022-12:52:37,671 nipype.workflow DEBUG:
# 	 Removing files:
# 201022-12:52:37,672 nipype.workflow INFO:
# 	 [Node] Finished "get_stats.sf2".
# 201022-12:52:37,674 nipype.workflow DEBUG:
# 	 Saving results file: '/Users/lucindasisk/Documents/qT1/workflow/get_stats/_subject_id_07-T2/sf2/result_sf2.pklz'
# 201022-12:52:37,677 nipype.workflow DEBUG:
# 	 Needed files: /Users/lucindasisk/Documents/qT1/data/1_check_alignment/08-T1/registered_qT1_T1acpc.nii.gz;/Users/lucindasisk/Documents/qT1/subjDir/08-T1/Left_Uncinate.nii.gz;/Users/lucindasisk/Documents/qT1/subjDir/08-T1/Right_Uncinate.nii.gz;/Users/lucindasisk/Documents/qT1/subjDir/08-T1/Left_Cingulum_Cingulate.nii.gz;/Users/lucindasisk/Documents/qT1/subjDir/08-T1/Right_Cingulum_Cingulate.nii.gz;/Users/lucindasisk/Documents/qT1/subjDir/08-T1/Left_Corticospinal.nii.gz;/Users/lucindasisk/Documents/qT1/subjDir/08-T1/Right_Corticospinal.nii.gz;/Users/lucindasisk/Documents/qT1/workflow/get_stats/_subject_id_08-T1/sf2/_0xb15882fef203aea16a0d66d8f5849979_unfinished.json;/Users/lucindasisk/Documents/qT1/workflow/get_stats/_subject_id_08-T1/sf2/_inputs.pklz;/Users/lucindasisk/Documents/qT1/workflow/get_stats/_subject_id_08-T1/sf2/_node.pklz
# 201022-12:52:37,679 nipype.workflow DEBUG:
# 	 [Node] Writing post-exec report to "/Users/lucindasisk/Documents/qT1/workflow/get_stats/_subject_id_07-T2/sf2/_report/report.rst"
# 201022-12:52:37,679 nipype.workflow DEBUG:
# 	 Needed dirs: /Users/lucindasisk/Documents/qT1/workflow/get_stats/_subject_id_08-T1/sf2/_report
# 201022-12:52:37,681 nipype.workflow DEBUG:
# 	 Removing files:
# 201022-12:52:37,682 nipype.workflow INFO:
# 	 [Node] Finished "get_stats.sf2".
# 201022-12:52:37,684 nipype.workflow DEBUG:
# 	 Saving results file: '/Users/lucindasisk/Documents/qT1/workflow/get_stats/_subject_id_08-T1/sf2/result_sf2.pklz'
# 201022-12:52:37,689 nipype.workflow DEBUG:
# 	 [Node] Writing post-exec report to "/Users/lucindasisk/Documents/qT1/workflow/get_stats/_subject_id_08-T1/sf2/_report/report.rst"
# 201022-12:52:37,692 nipype.workflow INFO:
# 	 [Node] Finished "get_stats.sf2".
# 201022-12:52:39,527 nipype.workflow DEBUG:
# 	 Progress: 96 jobs, 0/4/8 (done/running/ready), 4/92 (pending_tasks/waiting).
# 201022-12:52:39,528 nipype.workflow INFO:
# 	 [Job 0] Completed (get_stats.sf2).
# 201022-12:52:39,530 nipype.workflow INFO:
# 	 [Job 8] Completed (get_stats.sf2).
# 201022-12:52:39,532 nipype.workflow INFO:
# 	 [Job 16] Completed (get_stats.sf2).
# 201022-12:52:39,534 nipype.workflow INFO:
# 	 [Job 24] Completed (get_stats.sf2).
# 201022-12:52:39,536 nipype.workflow DEBUG:
# 	 Tasks currently running: 0. Pending: 0.
# 201022-12:52:39,538 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 32 jobs ready. Free memory (GB): 28.80/28.80, Free processors: 4/4.
# 201022-12:52:39,629 nipype.workflow DEBUG:
# 	 Allocating get_stats.get_voxRCST ID=1 (0.20GB, 1 threads). Free: 28.60GB, 3 threads.
# 201022-12:52:39,630 nipype.workflow DEBUG:
# 	 [Node] Not cached "/Users/lucindasisk/Documents/qT1/workflow/get_stats/_subject_id_02-T2/get_voxRCST".
# 201022-12:52:39,631 nipype.workflow DEBUG:
# 	 Checking hash "get_stats.get_voxRCST" locally: cached=False, updated=False.
# 201022-12:52:39,632 nipype.workflow DEBUG:
# 	 [MultiProc] Submitted task get_stats.get_voxRCST (taskid=5).
# 201022-12:52:39,634 nipype.workflow DEBUG:
# 	 Allocating get_stats.get_voxRCC ID=2 (0.20GB, 1 threads). Free: 28.40GB, 2 threads.
# 201022-12:52:39,635 nipype.workflow DEBUG:
# 	 [Node] Not cached "/Users/lucindasisk/Documents/qT1/workflow/get_stats/_subject_id_02-T2/get_voxRCC".
# 201022-12:52:39,635 nipype.workflow DEBUG:
# 	 Checking hash "get_stats.get_voxRCC" locally: cached=False, updated=False.
# 201022-12:52:39,634 nipype.workflow INFO:
# 	 [Node] Setting-up "get_stats.get_voxRCST" in "/Users/lucindasisk/Documents/qT1/workflow/get_stats/_subject_id_02-T2/get_voxRCST".
# 201022-12:52:39,637 nipype.workflow DEBUG:
# 	 [MultiProc] Submitted task get_stats.get_voxRCC (taskid=6).
# 201022-12:52:39,637 nipype.workflow DEBUG:
# 	 [Node] Not cached "/Users/lucindasisk/Documents/qT1/workflow/get_stats/_subject_id_02-T2/get_voxRCST".
# 201022-12:52:39,639 nipype.workflow DEBUG:
# 	 Allocating get_stats.get_voxRUF ID=3 (0.20GB, 1 threads). Free: 28.20GB, 1 threads.
# 201022-12:52:39,639 nipype.workflow DEBUG:
# 	 [Node] Not cached "/Users/lucindasisk/Documents/qT1/workflow/get_stats/_subject_id_02-T2/get_voxRUF".
# 201022-12:52:39,639 nipype.workflow INFO:
# 	 [Node] Setting-up "get_stats.get_voxRCC" in "/Users/lucindasisk/Documents/qT1/workflow/get_stats/_subject_id_02-T2/get_voxRCC".
# 201022-12:52:39,641 nipype.workflow DEBUG:
# 	 Checking hash "get_stats.get_voxRUF" locally: cached=False, updated=False.
# 201022-12:52:39,639 nipype.workflow DEBUG:
# 	 [Node] Setting 2 connected inputs of node "get_voxRCST" from 1 previous nodes.
# 201022-12:52:39,642 nipype.workflow DEBUG:
# 	 [MultiProc] Submitted task get_stats.get_voxRUF (taskid=7).
# 201022-12:52:39,641 nipype.utils DEBUG:
# 	 Loading pkl: /Users/lucindasisk/Documents/qT1/workflow/get_stats/_subject_id_02-T2/sf2/result_sf2.pklz
# 201022-12:52:39,641 nipype.workflow DEBUG:
# 	 [Node] Not cached "/Users/lucindasisk/Documents/qT1/workflow/get_stats/_subject_id_02-T2/get_voxRCC".
# 201022-12:52:39,644 nipype.workflow DEBUG:
# 	 Allocating get_stats.get_voxLCST ID=4 (0.20GB, 1 threads). Free: 28.00GB, 0 threads.
# 201022-12:52:39,643 nipype.workflow DEBUG:
# 	 [Node] Setting 2 connected inputs of node "get_voxRCC" from 1 previous nodes.
# 201022-12:52:39,645 nipype.workflow DEBUG:
# 	 [Node] Not cached "/Users/lucindasisk/Documents/qT1/workflow/get_stats/_subject_id_02-T2/get_voxLCST".
# 201022-12:52:39,644 nipype.workflow INFO:
# 	 [Node] Setting-up "get_stats.get_voxRUF" in "/Users/lucindasisk/Documents/qT1/workflow/get_stats/_subject_id_02-T2/get_voxRUF".
# 201022-12:52:39,646 nipype.workflow DEBUG:
# 	 Checking hash "get_stats.get_voxLCST" locally: cached=False, updated=False.
# 201022-12:52:39,644 nipype.workflow DEBUG:
# 	 Resolving paths in outputs loaded from results file.
# 201022-12:52:39,648 nipype.workflow DEBUG:
# 	 [MultiProc] Submitted task get_stats.get_voxLCST (taskid=8).
# 201022-12:52:39,646 nipype.utils DEBUG:
# 	 Loading pkl: /Users/lucindasisk/Documents/qT1/workflow/get_stats/_subject_id_02-T2/sf2/result_sf2.pklz
# 201022-12:52:39,650 nipype.workflow DEBUG:
# 	 Cannot allocate job 5 (0.20GB, 1 threads).
# 201022-12:52:39,646 nipype.workflow DEBUG:
# 	 output: qt1r
# 201022-12:52:39,647 nipype.workflow DEBUG:
# 	 [Node] Not cached "/Users/lucindasisk/Documents/qT1/workflow/get_stats/_subject_id_02-T2/get_voxRUF".
# 201022-12:52:39,651 nipype.workflow DEBUG:
# 	 Cannot allocate job 6 (0.20GB, 1 threads).
# 201022-12:52:39,648 nipype.workflow DEBUG:
# 	 [Node] get_voxRCST - setting input in_file = /Users/lucindasisk/Documents/qT1/data/1_check_alignment/02-T2/registered_qT1_T1acpc.nii.gz
# 201022-12:52:39,649 nipype.workflow DEBUG:
# 	 [Node] Setting 2 connected inputs of node "get_voxRUF" from 1 previous nodes.
# 201022-12:52:39,653 nipype.workflow DEBUG:
# 	 Cannot allocate job 9 (0.20GB, 1 threads).
# 201022-12:52:39,649 nipype.workflow DEBUG:
# 	 Resolving paths in outputs loaded from results file.
# 201022-12:52:39,650 nipype.workflow INFO:
# 	 [Node] Setting-up "get_stats.get_voxLCST" in "/Users/lucindasisk/Documents/qT1/workflow/get_stats/_subject_id_02-T2/get_voxLCST".
# 201022-12:52:39,654 nipype.workflow DEBUG:
# 	 Cannot allocate job 10 (0.20GB, 1 threads).
# 201022-12:52:39,651 nipype.workflow DEBUG:
# 	 output: cst_maskR
# 201022-12:52:39,652 nipype.utils DEBUG:
# 	 Loading pkl: /Users/lucindasisk/Documents/qT1/workflow/get_stats/_subject_id_02-T2/sf2/result_sf2.pklz
# 201022-12:52:39,656 nipype.workflow DEBUG:
# 	 Cannot allocate job 11 (0.20GB, 1 threads).
# 201022-12:52:39,652 nipype.workflow DEBUG:
# 	 output: qt1r
# 201022-12:52:39,653 nipype.workflow DEBUG:
# 	 [Node] Not cached "/Users/lucindasisk/Documents/qT1/workflow/get_stats/_subject_id_02-T2/get_voxLCST".
# 201022-12:52:39,658 nipype.workflow DEBUG:
# 	 Cannot allocate job 12 (0.20GB, 1 threads).
# 201022-12:52:39,654 nipype.workflow DEBUG:
# 	 [Node] get_voxRCST - setting input mask = /Users/lucindasisk/Documents/qT1/subjDir/02-T2/Right_Corticospinal.nii.gz
# 201022-12:52:39,655 nipype.workflow DEBUG:
# 	 [Node] get_voxRCC - setting input in_file = /Users/lucindasisk/Documents/qT1/data/1_check_alignment/02-T2/registered_qT1_T1acpc.nii.gz
# 201022-12:52:39,660 nipype.workflow DEBUG:
# 	 Cannot allocate job 13 (0.20GB, 1 threads).
# 201022-12:52:39,655 nipype.workflow DEBUG:
# 	 [Node] Setting 2 connected inputs of node "get_voxLCST" from 1 previous nodes.
# 201022-12:52:39,656 nipype.workflow DEBUG:
# 	 Resolving paths in outputs loaded from results file.
# 201022-12:52:39,662 nipype.workflow DEBUG:
# 	 Cannot allocate job 14 (0.20GB, 1 threads).
# 201022-12:52:39,658 nipype.utils DEBUG:
# 	 Removing contents of /Users/lucindasisk/Documents/qT1/workflow/get_stats/_subject_id_02-T2/get_voxRCST
# 201022-12:52:39,658 nipype.workflow DEBUG:
# 	 output: cc_maskR
# 201022-12:52:39,658 nipype.utils DEBUG:
# 	 Loading pkl: /Users/lucindasisk/Documents/qT1/workflow/get_stats/_subject_id_02-T2/sf2/result_sf2.pklz
# 201022-12:52:39,663 nipype.workflow DEBUG:
# 	 Cannot allocate job 17 (0.20GB, 1 threads).
# 201022-12:52:39,659 nipype.workflow DEBUG:
# 	 output: qt1r
# 201022-12:52:39,660 nipype.workflow DEBUG:
# 	 [Node] get_voxRCC - setting input mask = /Users/lucindasisk/Documents/qT1/subjDir/02-T2/Right_Cingulum_Cingulate.nii.gz
# 201022-12:52:39,662 nipype.workflow DEBUG:
# 	 [Node] Writing pre-exec report to "/Users/lucindasisk/Documents/qT1/workflow/get_stats/_subject_id_02-T2/get_voxRCST/_report/report.rst"
# 201022-12:52:39,662 nipype.workflow DEBUG:
# 	 [Node] get_voxRUF - setting input in_file = /Users/lucindasisk/Documents/qT1/data/1_check_alignment/02-T2/registered_qT1_T1acpc.nii.gz
# 201022-12:52:39,665 nipype.workflow DEBUG:
# 	 Cannot allocate job 18 (0.20GB, 1 threads).
# 201022-12:52:39,663 nipype.workflow DEBUG:
# 	 Resolving paths in outputs loaded from results file.
# 201022-12:52:39,665 nipype.workflow DEBUG:
# 	 output: unc_maskR
# 201022-12:52:39,665 nipype.utils DEBUG:
# 	 Removing contents of /Users/lucindasisk/Documents/qT1/workflow/get_stats/_subject_id_02-T2/get_voxRCC
# 201022-12:52:39,666 nipype.workflow DEBUG:
# 	 output: qt1r
# 201022-12:52:39,667 nipype.workflow DEBUG:
# 	 Cannot allocate job 19 (0.20GB, 1 threads).
# 201022-12:52:39,667 nipype.workflow DEBUG:
# 	 [Node] get_voxRUF - setting input mask = /Users/lucindasisk/Documents/qT1/subjDir/02-T2/Right_Uncinate.nii.gz
# 201022-12:52:39,668 nipype.interface DEBUG:
# 	 in_file_/Users/lucindasisk/Documents/qT1/data/1_check_alignment/02-T2/registered_qT1_T1acpc.nii.gz
# 201022-12:52:39,668 nipype.workflow DEBUG:
# 	 [Node] get_voxLCST - setting input in_file = /Users/lucindasisk/Documents/qT1/data/1_check_alignment/02-T2/registered_qT1_T1acpc.nii.gz
# 201022-12:52:39,670 nipype.workflow DEBUG:
# 	 Cannot allocate job 20 (0.20GB, 1 threads).
# 201022-12:52:39,668 nipype.workflow DEBUG:
# 	 [Node] Writing pre-exec report to "/Users/lucindasisk/Documents/qT1/workflow/get_stats/_subject_id_02-T2/get_voxRCC/_report/report.rst"
# 201022-12:52:39,670 nipype.interface DEBUG:
# 	 mask_/Users/lucindasisk/Documents/qT1/subjDir/02-T2/Right_Corticospinal.nii.gz
# 201022-12:52:39,671 nipype.workflow DEBUG:
# 	 Cannot allocate job 21 (0.20GB, 1 threads).
# 201022-12:52:39,671 nipype.workflow DEBUG:
# 	 output: cst_maskL
# 201022-12:52:39,671 nipype.utils DEBUG:
# 	 Removing contents of /Users/lucindasisk/Documents/qT1/workflow/get_stats/_subject_id_02-T2/get_voxRUF
# 201022-12:52:39,673 nipype.workflow DEBUG:
# 	 Cannot allocate job 22 (0.20GB, 1 threads).
# 201022-12:52:39,672 nipype.interface DEBUG:
# 	 order_1
# 201022-12:52:39,674 nipype.workflow DEBUG:
# 	 Cannot allocate job 25 (0.20GB, 1 threads).
# 201022-12:52:39,673 nipype.workflow DEBUG:
# 	 [Node] get_voxLCST - setting input mask = /Users/lucindasisk/Documents/qT1/subjDir/02-T2/Left_Corticospinal.nii.gz
# 201022-12:52:39,676 nipype.workflow DEBUG:
# 	 Cannot allocate job 26 (0.20GB, 1 threads).
# 201022-12:52:39,675 nipype.workflow DEBUG:
# 	 [Node] Writing pre-exec report to "/Users/lucindasisk/Documents/qT1/workflow/get_stats/_subject_id_02-T2/get_voxRUF/_report/report.rst"
# 201022-12:52:39,677 nipype.workflow DEBUG:
# 	 Cannot allocate job 27 (0.20GB, 1 threads).
# 201022-12:52:39,675 nipype.interface DEBUG:
# 	 out_file_ROI_voxel-contrasts_RightCST.txt
# 201022-12:52:39,678 nipype.workflow DEBUG:
# 	 Cannot allocate job 28 (0.20GB, 1 threads).
# 201022-12:52:39,675 nipype.interface DEBUG:
# 	 in_file_/Users/lucindasisk/Documents/qT1/data/1_check_alignment/02-T2/registered_qT1_T1acpc.nii.gz
# 201022-12:52:39,677 nipype.interface DEBUG:
# 	 show_all_True
# 201022-12:52:39,680 nipype.workflow DEBUG:
# 	 Cannot allocate job 29 (0.20GB, 1 threads).
# 201022-12:52:39,677 nipype.utils DEBUG:
# 	 Removing contents of /Users/lucindasisk/Documents/qT1/workflow/get_stats/_subject_id_02-T2/get_voxLCST
# 201022-12:52:39,677 nipype.interface DEBUG:
# 	 mask_/Users/lucindasisk/Documents/qT1/subjDir/02-T2/Right_Cingulum_Cingulate.nii.gz
# 201022-12:52:39,681 nipype.workflow DEBUG:
# 	 Cannot allocate job 30 (0.20GB, 1 threads).
# 201022-12:52:39,679 nipype.interface DEBUG:
# 	 order_1
# 201022-12:52:39,680 nipype.workflow INFO:
# 	 [Node] Running "get_voxRCST" ("nipype.interfaces.fsl.utils.ImageMeants"), a CommandLine Interface with command:
# fslmeants -i /Users/lucindasisk/Documents/qT1/data/1_check_alignment/02-T2/registered_qT1_T1acpc.nii.gz -m /Users/lucindasisk/Documents/qT1/subjDir/02-T2/Right_Corticospinal.nii.gz --order=1 -o ROI_voxel-contrasts_RightCST.txt --showall
# 201022-12:52:39,683 nipype.workflow DEBUG:
# 	 Cannot allocate job 32 (0.20GB, 1 threads).
# 201022-12:52:39,680 nipype.workflow DEBUG:
# 	 [Node] Writing pre-exec report to "/Users/lucindasisk/Documents/qT1/workflow/get_stats/_subject_id_02-T2/get_voxLCST/_report/report.rst"
# 201022-12:52:39,682 nipype.interface DEBUG:
# 	 in_file_/Users/lucindasisk/Documents/qT1/data/1_check_alignment/02-T2/registered_qT1_T1acpc.nii.gz
# 201022-12:52:39,684 nipype.workflow DEBUG:
# 	 Cannot allocate job 40 (0.20GB, 1 threads).
# 201022-12:52:39,682 nipype.interface DEBUG:
# 	 out_file_ROI_voxel-contrasts_RightCC.txt
# 201022-12:52:39,684 nipype.interface DEBUG:
# 	 in_file_/Users/lucindasisk/Documents/qT1/data/1_check_alignment/02-T2/registered_qT1_T1acpc.nii.gz
# 201022-12:52:39,686 nipype.workflow DEBUG:
# 	 Cannot allocate job 48 (0.20GB, 1 threads).
# 201022-12:52:39,684 nipype.interface DEBUG:
# 	 mask_/Users/lucindasisk/Documents/qT1/subjDir/02-T2/Right_Uncinate.nii.gz
# 201022-12:52:39,684 nipype.interface DEBUG:
# 	 show_all_True
# 201022-12:52:39,687 nipype.workflow DEBUG:
# 	 Cannot allocate job 56 (0.20GB, 1 threads).
# 201022-12:52:39,687 nipype.interface DEBUG:
# 	 mask_/Users/lucindasisk/Documents/qT1/subjDir/02-T2/Right_Corticospinal.nii.gz
# 201022-12:52:39,687 nipype.interface DEBUG:
# 	 order_1
# 201022-12:52:39,689 nipype.workflow DEBUG:
# 	 Cannot allocate job 64 (0.20GB, 1 threads).
# 201022-12:52:39,687 nipype.interface DEBUG:
# 	 in_file_/Users/lucindasisk/Documents/qT1/data/1_check_alignment/02-T2/registered_qT1_T1acpc.nii.gz
# 201022-12:52:39,687 nipype.workflow INFO:
# 	 [Node] Running "get_voxRCC" ("nipype.interfaces.fsl.utils.ImageMeants"), a CommandLine Interface with command:
# fslmeants -i /Users/lucindasisk/Documents/qT1/data/1_check_alignment/02-T2/registered_qT1_T1acpc.nii.gz -m /Users/lucindasisk/Documents/qT1/subjDir/02-T2/Right_Cingulum_Cingulate.nii.gz --order=1 -o ROI_voxel-contrasts_RightCC.txt --showall
# 201022-12:52:39,690 nipype.workflow DEBUG:
# 	 Cannot allocate job 72 (0.20GB, 1 threads).
# 201022-12:52:39,689 nipype.interface DEBUG:
# 	 out_file_ROI_voxel-contrasts_RightUF.txt
# 201022-12:52:39,689 nipype.interface DEBUG:
# 	 order_1
# 201022-12:52:39,692 nipype.workflow DEBUG:
# 	 Cannot allocate job 80 (0.20GB, 1 threads).
# 201022-12:52:39,690 nipype.interface DEBUG:
# 	 mask_/Users/lucindasisk/Documents/qT1/subjDir/02-T2/Left_Corticospinal.nii.gz
# 201022-12:52:39,691 nipype.interface DEBUG:
# 	 out_file_ROI_voxel-contrasts_RightCST.txt
# 201022-12:52:39,693 nipype.workflow DEBUG:
# 	 Cannot allocate job 88 (0.20GB, 1 threads).
# 201022-12:52:39,691 nipype.interface DEBUG:
# 	 in_file_/Users/lucindasisk/Documents/qT1/data/1_check_alignment/02-T2/registered_qT1_T1acpc.nii.gz
# 201022-12:52:39,692 nipype.interface DEBUG:
# 	 show_all_True
# 201022-12:52:39,692 nipype.interface DEBUG:
# 	 order_1
# 201022-12:52:39,693 nipype.interface DEBUG:
# 	 mask_/Users/lucindasisk/Documents/qT1/subjDir/02-T2/Right_Cingulum_Cingulate.nii.gz
# 201022-12:52:39,694 nipype.interface DEBUG:
# 	 show_all_True
# 201022-12:52:39,694 nipype.workflow INFO:
# 	 [Node] Running "get_voxRUF" ("nipype.interfaces.fsl.utils.ImageMeants"), a CommandLine Interface with command:
# fslmeants -i /Users/lucindasisk/Documents/qT1/data/1_check_alignment/02-T2/registered_qT1_T1acpc.nii.gz -m /Users/lucindasisk/Documents/qT1/subjDir/02-T2/Right_Uncinate.nii.gz --order=1 -o ROI_voxel-contrasts_RightUF.txt --showall
# 201022-12:52:39,694 nipype.interface DEBUG:
# 	 out_file_ROI_voxel-contrasts_LeftCST.txt
# 201022-12:52:39,696 nipype.interface DEBUG:
# 	 order_1
# 201022-12:52:39,697 nipype.interface DEBUG:
# 	 show_all_True
# 201022-12:52:39,697 nipype.interface DEBUG:
# 	 in_file_/Users/lucindasisk/Documents/qT1/data/1_check_alignment/02-T2/registered_qT1_T1acpc.nii.gz
# 201022-12:52:39,698 nipype.interface DEBUG:
# 	 out_file_ROI_voxel-contrasts_RightCC.txt
# 201022-12:52:39,700 nipype.workflow INFO:
# 	 [Node] Running "get_voxLCST" ("nipype.interfaces.fsl.utils.ImageMeants"), a CommandLine Interface with command:
# fslmeants -i /Users/lucindasisk/Documents/qT1/data/1_check_alignment/02-T2/registered_qT1_T1acpc.nii.gz -m /Users/lucindasisk/Documents/qT1/subjDir/02-T2/Left_Corticospinal.nii.gz --order=1 -o ROI_voxel-contrasts_LeftCST.txt --showall
# 201022-12:52:39,700 nipype.interface DEBUG:
# 	 mask_/Users/lucindasisk/Documents/qT1/subjDir/02-T2/Right_Uncinate.nii.gz
# 201022-12:52:39,701 nipype.interface DEBUG:
# 	 show_all_True
# 201022-12:52:39,703 nipype.interface DEBUG:
# 	 order_1
# 201022-12:52:39,704 nipype.interface DEBUG:
# 	 in_file_/Users/lucindasisk/Documents/qT1/data/1_check_alignment/02-T2/registered_qT1_T1acpc.nii.gz
# 201022-12:52:39,706 nipype.interface DEBUG:
# 	 out_file_ROI_voxel-contrasts_RightUF.txt
# 201022-12:52:39,706 nipype.interface DEBUG:
# 	 mask_/Users/lucindasisk/Documents/qT1/subjDir/02-T2/Left_Corticospinal.nii.gz
# 201022-12:52:39,709 nipype.interface DEBUG:
# 	 show_all_True
# 201022-12:52:39,709 nipype.interface DEBUG:
# 	 order_1
# 201022-12:52:39,711 nipype.interface DEBUG:
# 	 out_file_ROI_voxel-contrasts_LeftCST.txt
# 201022-12:52:39,713 nipype.interface DEBUG:
# 	 show_all_True
# 201022-12:52:40,469 nipype.workflow DEBUG:
# 	 Needed files: /Users/lucindasisk/Documents/qT1/workflow/get_stats/_subject_id_02-T2/get_voxRCC/ROI_voxel-contrasts_RightCC.txt;/Users/lucindasisk/Documents/qT1/data/1_check_alignment/02-T2/registered_qT1_T1acpc.nii.gz;/Users/lucindasisk/Documents/qT1/subjDir/02-T2/Right_Cingulum_Cingulate.nii.gz;/Users/lucindasisk/Documents/qT1/workflow/get_stats/_subject_id_02-T2/get_voxRCC/_0x9d04ceeaaaf46c9cc6649271bb87b18e_unfinished.json;/Users/lucindasisk/Documents/qT1/workflow/get_stats/_subject_id_02-T2/get_voxRCC/command.txt;/Users/lucindasisk/Documents/qT1/workflow/get_stats/_subject_id_02-T2/get_voxRCC/_inputs.pklz;/Users/lucindasisk/Documents/qT1/workflow/get_stats/_subject_id_02-T2/get_voxRCC/_node.pklz
# 201022-12:52:40,473 nipype.workflow DEBUG:
# 	 Needed dirs: /Users/lucindasisk/Documents/qT1/workflow/get_stats/_subject_id_02-T2/get_voxRCC/_report
# 201022-12:52:40,476 nipype.workflow DEBUG:
# 	 Removing files:
# 201022-12:52:40,477 nipype.workflow DEBUG:
# 	 Needed files: /Users/lucindasisk/Documents/qT1/workflow/get_stats/_subject_id_02-T2/get_voxRUF/ROI_voxel-contrasts_RightUF.txt;/Users/lucindasisk/Documents/qT1/data/1_check_alignment/02-T2/registered_qT1_T1acpc.nii.gz;/Users/lucindasisk/Documents/qT1/subjDir/02-T2/Right_Uncinate.nii.gz;/Users/lucindasisk/Documents/qT1/workflow/get_stats/_subject_id_02-T2/get_voxRUF/_0x3a806fb588400b6aff6481dfe04c0a27_unfinished.json;/Users/lucindasisk/Documents/qT1/workflow/get_stats/_subject_id_02-T2/get_voxRUF/command.txt;/Users/lucindasisk/Documents/qT1/workflow/get_stats/_subject_id_02-T2/get_voxRUF/_inputs.pklz;/Users/lucindasisk/Documents/qT1/workflow/get_stats/_subject_id_02-T2/get_voxRUF/_node.pklz
# 201022-12:52:40,479 nipype.workflow DEBUG:
# 	 Saving results file: '/Users/lucindasisk/Documents/qT1/workflow/get_stats/_subject_id_02-T2/get_voxRCC/result_get_voxRCC.pklz'
# 201022-12:52:40,480 nipype.workflow DEBUG:
# 	 Needed dirs: /Users/lucindasisk/Documents/qT1/workflow/get_stats/_subject_id_02-T2/get_voxRUF/_report
# 201022-12:52:40,482 nipype.workflow DEBUG:
# 	 Removing files:
# 201022-12:52:40,484 nipype.workflow DEBUG:
# 	 [Node] Writing post-exec report to "/Users/lucindasisk/Documents/qT1/workflow/get_stats/_subject_id_02-T2/get_voxRCC/_report/report.rst"
# 201022-12:52:40,485 nipype.workflow DEBUG:
# 	 Saving results file: '/Users/lucindasisk/Documents/qT1/workflow/get_stats/_subject_id_02-T2/get_voxRUF/result_get_voxRUF.pklz'
# 201022-12:52:40,487 nipype.workflow INFO:
# 	 [Node] Finished "get_stats.get_voxRCC".
# 201022-12:52:40,490 nipype.workflow DEBUG:
# 	 [Node] Writing post-exec report to "/Users/lucindasisk/Documents/qT1/workflow/get_stats/_subject_id_02-T2/get_voxRUF/_report/report.rst"
# 201022-12:52:40,490 nipype.workflow DEBUG:
# 	 Needed files: /Users/lucindasisk/Documents/qT1/workflow/get_stats/_subject_id_02-T2/get_voxRCST/ROI_voxel-contrasts_RightCST.txt;/Users/lucindasisk/Documents/qT1/data/1_check_alignment/02-T2/registered_qT1_T1acpc.nii.gz;/Users/lucindasisk/Documents/qT1/subjDir/02-T2/Right_Corticospinal.nii.gz;/Users/lucindasisk/Documents/qT1/workflow/get_stats/_subject_id_02-T2/get_voxRCST/_0xc65f0a0af889009c7ecee6c03f00af21_unfinished.json;/Users/lucindasisk/Documents/qT1/workflow/get_stats/_subject_id_02-T2/get_voxRCST/command.txt;/Users/lucindasisk/Documents/qT1/workflow/get_stats/_subject_id_02-T2/get_voxRCST/_inputs.pklz;/Users/lucindasisk/Documents/qT1/workflow/get_stats/_subject_id_02-T2/get_voxRCST/_node.pklz
# 201022-12:52:40,492 nipype.workflow DEBUG:
# 	 Needed dirs: /Users/lucindasisk/Documents/qT1/workflow/get_stats/_subject_id_02-T2/get_voxRCST/_report
# 201022-12:52:40,493 nipype.workflow INFO:
# 	 [Node] Finished "get_stats.get_voxRUF".
# 201022-12:52:40,495 nipype.workflow DEBUG:
# 	 Removing files:
# 201022-12:52:40,497 nipype.workflow DEBUG:
# 	 Needed files: /Users/lucindasisk/Documents/qT1/workflow/get_stats/_subject_id_02-T2/get_voxLCST/ROI_voxel-contrasts_LeftCST.txt;/Users/lucindasisk/Documents/qT1/data/1_check_alignment/02-T2/registered_qT1_T1acpc.nii.gz;/Users/lucindasisk/Documents/qT1/subjDir/02-T2/Left_Corticospinal.nii.gz;/Users/lucindasisk/Documents/qT1/workflow/get_stats/_subject_id_02-T2/get_voxLCST/_0x5507af4e78a4739d9f9ced1868f29b59_unfinished.json;/Users/lucindasisk/Documents/qT1/workflow/get_stats/_subject_id_02-T2/get_voxLCST/command.txt;/Users/lucindasisk/Documents/qT1/workflow/get_stats/_subject_id_02-T2/get_voxLCST/_inputs.pklz;/Users/lucindasisk/Documents/qT1/workflow/get_stats/_subject_id_02-T2/get_voxLCST/_node.pklz
# 201022-12:52:40,498 nipype.workflow DEBUG:
# 	 Saving results file: '/Users/lucindasisk/Documents/qT1/workflow/get_stats/_subject_id_02-T2/get_voxRCST/result_get_voxRCST.pklz'
# 201022-12:52:40,499 nipype.workflow DEBUG:
# 	 Needed dirs: /Users/lucindasisk/Documents/qT1/workflow/get_stats/_subject_id_02-T2/get_voxLCST/_report
# 201022-12:52:40,502 nipype.workflow DEBUG:
# 	 Removing files:
# 201022-12:52:40,502 nipype.workflow DEBUG:
# 	 [Node] Writing post-exec report to "/Users/lucindasisk/Documents/qT1/workflow/get_stats/_subject_id_02-T2/get_voxRCST/_report/report.rst"
# 201022-12:52:40,504 nipype.workflow DEBUG:
# 	 Saving results file: '/Users/lucindasisk/Documents/qT1/workflow/get_stats/_subject_id_02-T2/get_voxLCST/result_get_voxLCST.pklz'
# 201022-12:52:40,505 nipype.workflow INFO:
# 	 [Node] Finished "get_stats.get_voxRCST".
# 201022-12:52:40,509 nipype.workflow DEBUG:
# 	 [Node] Writing post-exec report to "/Users/lucindasisk/Documents/qT1/workflow/get_stats/_subject_id_02-T2/get_voxLCST/_report/report.rst"
# 201022-12:52:40,512 nipype.workflow INFO:
# 	 [Node] Finished "get_stats.get_voxLCST".
# 201022-12:52:41,529 nipype.workflow DEBUG:
# 	 Progress: 96 jobs, 4/4/28 (done/running/ready), 4/88 (pending_tasks/waiting).
# 201022-12:52:41,530 nipype.workflow INFO:
# 	 [Job 1] Completed (get_stats.get_voxRCST).
# 201022-12:52:41,532 nipype.workflow INFO:
# 	 [Job 2] Completed (get_stats.get_voxRCC).
# 201022-12:52:41,534 nipype.workflow INFO:
# 	 [Job 3] Completed (get_stats.get_voxRUF).
# 201022-12:52:41,535 nipype.workflow INFO:
# 	 [Job 4] Completed (get_stats.get_voxLCST).
# 201022-12:52:41,537 nipype.workflow DEBUG:
# 	 Tasks currently running: 0. Pending: 0.
# 201022-12:52:41,538 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 28 jobs ready. Free memory (GB): 28.80/28.80, Free processors: 4/4.
# 201022-12:52:41,585 nipype.workflow DEBUG:
# 	 Allocating get_stats.get_voxLCC ID=5 (0.20GB, 1 threads). Free: 28.60GB, 3 threads.
# 201022-12:52:41,586 nipype.workflow DEBUG:
# 	 [Node] Not cached "/Users/lucindasisk/Documents/qT1/workflow/get_stats/_subject_id_02-T2/get_voxLCC".
# 201022-12:52:41,586 nipype.workflow DEBUG:
# ...
# 201022-12:53:17,741 nipype.interface INFO:
# 	 sub: /Users/lucindasisk/Documents/qT1/data/2_Extracted_Stats/_subject_id_15-T1/ROI_voxel-contrasts_RightUF.txt -> /Users/lucindasisk/Documents/qT1/data/2_Extracted_Stats/15-T1/ROI_voxel-contrasts_RightUF.txt
# 201022-12:53:17,742 nipype.interface DEBUG:
# 	 copyfile: /Users/lucindasisk/Documents/qT1/workflow/get_stats/_subject_id_15-T1/get_voxRUF/ROI_voxel-contrasts_RightUF.txt /Users/lucindasisk/Documents/qT1/data/2_Extracted_Stats/15-T1/ROI_voxel-contrasts_RightUF.txt
# 201022-12:53:17,744 nipype.utils DEBUG:
# 	 /Users/lucindasisk/Documents/qT1/data/2_Extracted_Stats/15-T1/ROI_voxel-contrasts_RightUF.txt
# 201022-12:53:17,745 nipype.utils DEBUG:
# 	 Linking File: /Users/lucindasisk/Documents/qT1/data/2_Extracted_Stats/15-T1/ROI_voxel-contrasts_RightUF.txt->/Users/lucindasisk/Documents/qT1/workflow/get_stats/_subject_id_15-T1/get_voxRUF/ROI_voxel-contrasts_RightUF.txt
# 201022-12:53:17,747 nipype.utils DEBUG:
# 	 /Users/lucindasisk/Documents/qT1/data/2_Extracted_Stats/15-T1/ROI_voxel-contrasts_RightUF.txt
# 201022-12:53:17,748 nipype.utils DEBUG:
# 	 File: /Users/lucindasisk/Documents/qT1/data/2_Extracted_Stats/15-T1/ROI_voxel-contrasts_RightUF.txt already exists, not overwriting, copy:1
# 201022-12:53:17,750 nipype.interface DEBUG:
# 	 key: 2_Extracted_Stats.@par.@par.@par.@par files: /Users/lucindasisk/Documents/qT1/workflow/get_stats/_subject_id_15-T1/get_voxRCC/ROI_voxel-contrasts_RightCC.txt
# 201022-12:53:17,752 nipype.interface DEBUG:
# 	 sub.str: /Users/lucindasisk/Documents/qT1/data/2_Extracted_Stats/_subject_id_15-T1/ROI_voxel-contrasts_RightCC.txt -> /Users/lucindasisk/Documents/qT1/data/2_Extracted_Stats/15-T1/ROI_voxel-contrasts_RightCC.txt using '_subject_id_' -> ''
# 201022-12:53:17,753 nipype.interface INFO:
# 	 sub: /Users/lucindasisk/Documents/qT1/data/2_Extracted_Stats/_subject_id_15-T1/ROI_voxel-contrasts_RightCC.txt -> /Users/lucindasisk/Documents/qT1/data/2_Extracted_Stats/15-T1/ROI_voxel-contrasts_RightCC.txt
# 201022-12:53:17,755 nipype.interface DEBUG:
# 	 copyfile: /Users/lucindasisk/Documents/qT1/workflow/get_stats/_subject_id_15-T1/get_voxRCC/ROI_voxel-contrasts_RightCC.txt /Users/lucindasisk/Documents/qT1/data/2_Extracted_Stats/15-T1/ROI_voxel-contrasts_RightCC.txt
# 201022-12:53:17,757 nipype.utils DEBUG:
# 	 /Users/lucindasisk/Documents/qT1/data/2_Extracted_Stats/15-T1/ROI_voxel-contrasts_RightCC.txt
# 201022-12:53:17,758 nipype.utils DEBUG:
# 	 Linking File: /Users/lucindasisk/Documents/qT1/data/2_Extracted_Stats/15-T1/ROI_voxel-contrasts_RightCC.txt->/Users/lucindasisk/Documents/qT1/workflow/get_stats/_subject_id_15-T1/get_voxRCC/ROI_voxel-contrasts_RightCC.txt
# 201022-12:53:17,760 nipype.utils DEBUG:
# 	 /Users/lucindasisk/Documents/qT1/data/2_Extracted_Stats/15-T1/ROI_voxel-contrasts_RightCC.txt
# 201022-12:53:17,762 nipype.utils DEBUG:
# 	 File: /Users/lucindasisk/Documents/qT1/data/2_Extracted_Stats/15-T1/ROI_voxel-contrasts_RightCC.txt already exists, not overwriting, copy:1
# 201022-12:53:17,764 nipype.interface DEBUG:
# 	 key: 2_Extracted_Stats.@par.@par.@par.@par.@par files: /Users/lucindasisk/Documents/qT1/workflow/get_stats/_subject_id_15-T1/get_voxRCST/ROI_voxel-contrasts_RightCST.txt
# 201022-12:53:17,766 nipype.interface DEBUG:
# 	 sub.str: /Users/lucindasisk/Documents/qT1/data/2_Extracted_Stats/_subject_id_15-T1/ROI_voxel-contrasts_RightCST.txt -> /Users/lucindasisk/Documents/qT1/data/2_Extracted_Stats/15-T1/ROI_voxel-contrasts_RightCST.txt using '_subject_id_' -> ''
# 201022-12:53:17,767 nipype.interface INFO:
# 	 sub: /Users/lucindasisk/Documents/qT1/data/2_Extracted_Stats/_subject_id_15-T1/ROI_voxel-contrasts_RightCST.txt -> /Users/lucindasisk/Documents/qT1/data/2_Extracted_Stats/15-T1/ROI_voxel-contrasts_RightCST.txt
# 201022-12:53:17,769 nipype.interface DEBUG:
# 	 copyfile: /Users/lucindasisk/Documents/qT1/workflow/get_stats/_subject_id_15-T1/get_voxRCST/ROI_voxel-contrasts_RightCST.txt /Users/lucindasisk/Documents/qT1/data/2_Extracted_Stats/15-T1/ROI_voxel-contrasts_RightCST.txt
# 201022-12:53:17,771 nipype.utils DEBUG:
# 	 /Users/lucindasisk/Documents/qT1/data/2_Extracted_Stats/15-T1/ROI_voxel-contrasts_RightCST.txt
# 201022-12:53:17,774 nipype.utils DEBUG:
# 	 Linking File: /Users/lucindasisk/Documents/qT1/data/2_Extracted_Stats/15-T1/ROI_voxel-contrasts_RightCST.txt->/Users/lucindasisk/Documents/qT1/workflow/get_stats/_subject_id_15-T1/get_voxRCST/ROI_voxel-contrasts_RightCST.txt
# 201022-12:53:17,777 nipype.utils DEBUG:
# 	 /Users/lucindasisk/Documents/qT1/data/2_Extracted_Stats/15-T1/ROI_voxel-contrasts_RightCST.txt
# 201022-12:53:17,779 nipype.utils DEBUG:
# 	 File: /Users/lucindasisk/Documents/qT1/data/2_Extracted_Stats/15-T1/ROI_voxel-contrasts_RightCST.txt already exists, not overwriting, copy:1
# 201022-12:53:17,784 nipype.workflow DEBUG:
# 	 Needed files: /Users/lucindasisk/Documents/qT1/data/2_Extracted_Stats/15-T1/ROI_voxel-contrasts_LeftUF.txt;/Users/lucindasisk/Documents/qT1/data/2_Extracted_Stats/15-T1/ROI_voxel-contrasts_LeftCC.txt;/Users/lucindasisk/Documents/qT1/data/2_Extracted_Stats/15-T1/ROI_voxel-contrasts_LeftCST.txt;/Users/lucindasisk/Documents/qT1/data/2_Extracted_Stats/15-T1/ROI_voxel-contrasts_RightUF.txt;/Users/lucindasisk/Documents/qT1/data/2_Extracted_Stats/15-T1/ROI_voxel-contrasts_RightCC.txt;/Users/lucindasisk/Documents/qT1/data/2_Extracted_Stats/15-T1/ROI_voxel-contrasts_RightCST.txt;/Users/lucindasisk/Documents/qT1/workflow/get_stats/_subject_id_15-T1/get_voxLUF/ROI_voxel-contrasts_LeftUF.txt;/Users/lucindasisk/Documents/qT1/workflow/get_stats/_subject_id_15-T1/get_voxLCC/ROI_voxel-contrasts_LeftCC.txt;/Users/lucindasisk/Documents/qT1/workflow/get_stats/_subject_id_15-T1/get_voxLCST/ROI_voxel-contrasts_LeftCST.txt;/Users/lucindasisk/Documents/qT1/workflow/get_stats/_subject_id_15-T1/get_voxRUF/ROI_voxel-contrasts_RightUF.txt;/Users/lucindasisk/Documents/qT1/workflow/get_stats/_subject_id_15-T1/get_voxRCC/ROI_voxel-contrasts_RightCC.txt;/Users/lucindasisk/Documents/qT1/workflow/get_stats/_subject_id_15-T1/get_voxRCST/ROI_voxel-contrasts_RightCST.txt;/Users/lucindasisk/Documents/qT1/workflow/get_stats/_subject_id_15-T1/datasink/_0x32e93350d8cb73a1ea807d54f1af26b5_unfinished.json;/Users/lucindasisk/Documents/qT1/workflow/get_stats/_subject_id_15-T1/datasink/_inputs.pklz;/Users/lucindasisk/Documents/qT1/workflow/get_stats/_subject_id_15-T1/datasink/_node.pklz
# 201022-12:53:17,786 nipype.workflow DEBUG:
# 	 Needed dirs: /Users/lucindasisk/Documents/qT1/workflow/get_stats/_subject_id_15-T1/datasink/_report
# 201022-12:53:17,788 nipype.workflow DEBUG:
# 	 Removing files:
# 201022-12:53:17,791 nipype.workflow DEBUG:
# 	 Saving results file: '/Users/lucindasisk/Documents/qT1/workflow/get_stats/_subject_id_15-T1/datasink/result_datasink.pklz'
# 201022-12:53:17,795 nipype.workflow DEBUG:
# 	 [Node] Writing post-exec report to "/Users/lucindasisk/Documents/qT1/workflow/get_stats/_subject_id_15-T1/datasink/_report/report.rst"
# 201022-12:53:17,798 nipype.workflow INFO:
# 	 [Node] Finished "get_stats.datasink".
# 201022-12:53:18,260 nipype.workflow DEBUG:
# 	 Saving results file: '/Users/lucindasisk/Documents/qT1/workflow/get_stats/_subject_id_16-T1/get_voxRCST/result_get_voxRCST.pklz'
# 201022-12:53:18,263 nipype.workflow WARNING:
# 	 Storing result file without outputs
# 201022-12:53:18,266 nipype.workflow WARNING:
# 	 [Node] Error on "get_stats.get_voxRCST" (/Users/lucindasisk/Documents/qT1/workflow/get_stats/_subject_id_16-T1/get_voxRCST)
# 201022-12:53:18,269 nipype.utils DEBUG:
# 	 Loading pkl: /Users/lucindasisk/Documents/qT1/workflow/get_stats/_subject_id_16-T1/get_voxRCST/result_get_voxRCST.pklz
# 201022-12:53:18,290 nipype.workflow DEBUG:
# 	 Needed files: /Users/lucindasisk/Documents/qT1/workflow/get_stats/_subject_id_16-T1/get_voxRCC/ROI_voxel-contrasts_RightCC.txt;/Users/lucindasisk/Documents/qT1/data/1_check_alignment/16-T1/registered_qT1_T1acpc.nii.gz;/Users/lucindasisk/Documents/qT1/subjDir/16-T1/Right_Cingulum_Cingulate.nii.gz;/Users/lucindasisk/Documents/qT1/workflow/get_stats/_subject_id_16-T1/get_voxRCC/_0xac02812c00382d0dcc7a194b03c1c812_unfinished.json;/Users/lucindasisk/Documents/qT1/workflow/get_stats/_subject_id_16-T1/get_voxRCC/command.txt;/Users/lucindasisk/Documents/qT1/workflow/get_stats/_subject_id_16-T1/get_voxRCC/_inputs.pklz;/Users/lucindasisk/Documents/qT1/workflow/get_stats/_subject_id_16-T1/get_voxRCC/_node.pklz
# 201022-12:53:18,290 nipype.workflow DEBUG:
# 	 Needed files: /Users/lucindasisk/Documents/qT1/workflow/get_stats/_subject_id_16-T1/get_voxRUF/ROI_voxel-contrasts_RightUF.txt;/Users/lucindasisk/Documents/qT1/data/1_check_alignment/16-T1/registered_qT1_T1acpc.nii.gz;/Users/lucindasisk/Documents/qT1/subjDir/16-T1/Right_Uncinate.nii.gz;/Users/lucindasisk/Documents/qT1/workflow/get_stats/_subject_id_16-T1/get_voxRUF/_0xce9085830e6963bebd6c81fb49bba594_unfinished.json;/Users/lucindasisk/Documents/qT1/workflow/get_stats/_subject_id_16-T1/get_voxRUF/command.txt;/Users/lucindasisk/Documents/qT1/workflow/get_stats/_subject_id_16-T1/get_voxRUF/_inputs.pklz;/Users/lucindasisk/Documents/qT1/workflow/get_stats/_subject_id_16-T1/get_voxRUF/_node.pklz
# 201022-12:53:18,292 nipype.workflow DEBUG:
# 	 Needed dirs: /Users/lucindasisk/Documents/qT1/workflow/get_stats/_subject_id_16-T1/get_voxRUF/_report
# 201022-12:53:18,292 nipype.workflow DEBUG:
# 	 Needed dirs: /Users/lucindasisk/Documents/qT1/workflow/get_stats/_subject_id_16-T1/get_voxRCC/_report
# 201022-12:53:18,294 nipype.workflow DEBUG:
# 	 Removing files:
# 201022-12:53:18,294 nipype.workflow DEBUG:
# 	 Removing files:
# 201022-12:53:18,296 nipype.workflow DEBUG:
# 	 Saving results file: '/Users/lucindasisk/Documents/qT1/workflow/get_stats/_subject_id_16-T1/get_voxRCC/result_get_voxRCC.pklz'
# 201022-12:53:18,296 nipype.workflow DEBUG:
# 	 Saving results file: '/Users/lucindasisk/Documents/qT1/workflow/get_stats/_subject_id_16-T1/get_voxRUF/result_get_voxRUF.pklz'
# 201022-12:53:18,299 nipype.workflow DEBUG:
# 	 [Node] Writing post-exec report to "/Users/lucindasisk/Documents/qT1/workflow/get_stats/_subject_id_16-T1/get_voxRCC/_report/report.rst"
# 201022-12:53:18,299 nipype.workflow DEBUG:
# 	 [Node] Writing post-exec report to "/Users/lucindasisk/Documents/qT1/workflow/get_stats/_subject_id_16-T1/get_voxRUF/_report/report.rst"
# 201022-12:53:18,301 nipype.workflow INFO:
# 	 [Node] Finished "get_stats.get_voxRUF".
# 201022-12:53:18,302 nipype.workflow INFO:
# 	 [Node] Finished "get_stats.get_voxRCC".
# 201022-12:53:19,555 nipype.workflow DEBUG:
# 	 Progress: 96 jobs, 80/4/4 (done/running/ready), 4/12 (pending_tasks/waiting).
# 201022-12:53:19,555 nipype.workflow INFO:
# 	 [Job 79] Completed (get_stats.datasink).
# 201022-12:53:19,556 nipype.workflow DEBUG:
# 	 Clearing 81 from queue
# 201022-12:53:19,557 nipype.utils DEBUG:
# 	 Loading pkl: /Users/lucindasisk/Documents/qT1/workflow/get_stats/_subject_id_16-T1/get_voxRCST/result_get_voxRCST.pklz
# 201022-12:53:19,558 nipype.workflow ERROR:
# 	 Node get_voxRCST.a01 failed to run on host Lucindas-MacBook-Pro.local.
# 201022-12:53:19,559 nipype.workflow ERROR:
# 	 Saving crash info to /Users/lucindasisk/Dropbox/Github/TIGER_qT1_Tracts/crash-20201022-125319-lucindasisk-get_voxRCST.a01-9469147d-5486-412e-8277-f7a4fac51dec.pklz
# Traceback (most recent call last):
#   File "/usr/local/anaconda3/lib/python3.7/site-packages/nipype/pipeline/plugins/multiproc.py", line 67, in run_node
#     result["result"] = node.run(updatehash=updatehash)
#   File "/usr/local/anaconda3/lib/python3.7/site-packages/nipype/pipeline/engine/nodes.py", line 516, in run
#     result = self._run_interface(execute=True)
#   File "/usr/local/anaconda3/lib/python3.7/site-packages/nipype/pipeline/engine/nodes.py", line 635, in _run_interface
#     return self._run_command(execute)
#   File "/usr/local/anaconda3/lib/python3.7/site-packages/nipype/pipeline/engine/nodes.py", line 741, in _run_command
#     result = self._interface.run(cwd=outdir)
#   File "/usr/local/anaconda3/lib/python3.7/site-packages/nipype/interfaces/base/core.py", line 419, in run
#     runtime = self._run_interface(runtime)
#   File "/usr/local/anaconda3/lib/python3.7/site-packages/nipype/interfaces/base/core.py", line 814, in _run_interface
#     self.raise_exception(runtime)
#   File "/usr/local/anaconda3/lib/python3.7/site-packages/nipype/interfaces/base/core.py", line 745, in raise_exception
#     ).format(**runtime.dictcopy())
# RuntimeError: Command:
# fslmeants -i /Users/lucindasisk/Documents/qT1/data/1_check_alignment/16-T1/registered_qT1_T1acpc.nii.gz -m /Users/lucindasisk/Documents/qT1/subjDir/16-T1/Right_Corticospinal.nii.gz --order=1 -o ROI_voxel-contrasts_RightCST.txt --showall
# Standard output:
#
# Standard error:
# ERROR: Mask and Input volumes have different (x,y,z) size.
# Return code: 255
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-12-559c16a8c430> in <module>
#      28 get_stats.base_dir = workflow_dir
#      29 get_stats.write_graph(graph2use = 'flat')
# ---> 30 preproc = get_stats.run('MultiProc', plugin_args={'n_procs': 4})
#
# /usr/local/anaconda3/lib/python3.7/site-packages/nipype/pipeline/engine/workflows.py in run(self, plugin, plugin_args, updatehash)
#     630         if str2bool(self.config["execution"]["create_report"]):
#     631             self._write_report_info(self.base_dir, self.name, execgraph)
# --> 632         runner.run(execgraph, updatehash=updatehash, config=self.config)
#     633         datestr = datetime.utcnow().strftime("%Y%m%dT%H%M%S")
#     634         if str2bool(self.config["execution"]["write_provenance"]):
#
# /usr/local/anaconda3/lib/python3.7/site-packages/nipype/pipeline/plugins/base.py in run(self, graph, config, updatehash)
#     162                         if result["traceback"]:
#     163                             notrun.append(
# --> 164                                 self._clean_queue(jobid, graph, result=result)
#     165                             )
#     166                         else:
#
# /usr/local/anaconda3/lib/python3.7/site-packages/nipype/pipeline/plugins/base.py in _clean_queue(self, jobid, graph, result)
#     225         crashfile = self._report_crash(self.procs[jobid], result=result)
#     226         if str2bool(self._config["execution"]["stop_on_first_crash"]):
# --> 227             raise RuntimeError("".join(result["traceback"]))
#     228         if jobid in self.mapnodesubids:
#     229             # remove current jobid
#
# RuntimeError: Traceback (most recent call last):
#   File "/usr/local/anaconda3/lib/python3.7/site-packages/nipype/pipeline/plugins/multiproc.py", line 67, in run_node
#     result["result"] = node.run(updatehash=updatehash)
#   File "/usr/local/anaconda3/lib/python3.7/site-packages/nipype/pipeline/engine/nodes.py", line 516, in run
#     result = self._run_interface(execute=True)
#   File "/usr/local/anaconda3/lib/python3.7/site-packages/nipype/pipeline/engine/nodes.py", line 635, in _run_interface
#     return self._run_command(execute)
#   File "/usr/local/anaconda3/lib/python3.7/site-packages/nipype/pipeline/engine/nodes.py", line 741, in _run_command
#     result = self._interface.run(cwd=outdir)
#   File "/usr/local/anaconda3/lib/python3.7/site-packages/nipype/interfaces/base/core.py", line 419, in run
#     runtime = self._run_interface(runtime)
#   File "/usr/local/anaconda3/lib/python3.7/site-packages/nipype/interfaces/base/core.py", line 814, in _run_interface
#     self.raise_exception(runtime)
#   File "/usr/local/anaconda3/lib/python3.7/site-packages/nipype/interfaces/base/core.py", line 745, in raise_exception
#     ).format(**runtime.dictcopy())
# RuntimeError: Command:
# fslmeants -i /Users/lucindasisk/Documents/qT1/data/1_check_alignment/16-T1/registered_qT1_T1acpc.nii.gz -m /Users/lucindasisk/Documents/qT1/subjDir/16-T1/Right_Corticospinal.nii.gz --order=1 -o ROI_voxel-contrasts_RightCST.txt --showall
# Standard output:
#
# Standard error:
# ERROR: Mask and Input volumes have different (x,y,z) size.
# Return code: 255

# %%
#SelectFiles
template3 = dict(t1w = fpath+'/{subject_id}/freesurfer_brain.nii.gz',
                aseg = fpath+'/{subject_id}/aparc.a2009s+aseg.nii.gz',
                qt1_reor = data_dir+'/1_check_alignment/_subject_id_{subject_id}/reoriented_qT1.nii.gz')       


sf3 = Node(SelectFiles(template3, 
                      base_directory = fpath),
          name = 'sf3')

# %%
# #MRI Convert Nodes
# convert_wb = Node(fsr.MRIConvert(in_type='mgz',
#                                out_file = 'freesurfer_brain.nii.gz'),
#                name = 'convert_wb')

# convert_aseg = Node(fsr.MRIConvert(in_type='mgz',
#                                out_file = 'aparc.a2009s+aseg.nii.gz'),
#                name = 'convert_aseg')

# %%
#Extract left hippocampus - seg value 17
extract_lhipp = Node(fsl.Threshold(thresh = 16.5, 
                                   direction = 'below', 
                                   args = '-uthr 17.5',
                                   output_type = 'NIFTI_GZ',
                                   out_file = 'left_hippocampus.nii.gz'),
                        name = 'extract_lhipp')
#Extract right hippocampus - seg value 53
extract_rhipp = Node(fsl.Threshold(thresh = 52.5, 
                                   direction = 'below', 
                                   args = '-uthr 53.5',
                                   output_type = 'NIFTI_GZ',
                                   out_file = 'right_hippocampus.nii.gz'),
                    name='extract_rhipp')

# %%
#Extract left amygdala - seg value 18
extract_lamyg = Node(fsl.Threshold(thresh = 17.5, 
                                   direction = 'below', 
                                   args = '-uthr 18.5',
                                   output_type = 'NIFTI_GZ',
                                   out_file = 'left_amygdala.nii.gz'),
                        name = 'extract_lamyg')
#Extract right amygdala - seg value 54
extract_ramyg = Node(fsl.Threshold(thresh = 53.5, 
                                   direction = 'below', 
                                   args = '-uthr 54.5',
                                   output_type = 'NIFTI_GZ',
                                   out_file = 'right_amygdala.nii.gz'),
                    name='extract_ramyg')

# %%
#Extract left caudate - seg value 11
extract_lcaud = Node(fsl.Threshold(thresh = 10.5, 
                                   direction = 'below', 
                                   args = '-uthr 11.5',
                                   output_type = 'NIFTI_GZ',
                                   out_file = 'left_caudate.nii.gz'),
                        name = 'extract_lcaud')

#Extract right caudate - seg value 50
extract_rcaud = Node(fsl.Threshold(thresh = 49.5, 
                                   direction = 'below', 
                                   args = '-uthr 50.5',
                                   output_type = 'NIFTI_GZ',
                                   out_file = 'right_caudate.nii.gz'),
                    name='extract_rcaud')

# %%
#Extract left nucleus accumbens - seg value 26
extract_lnacc  = Node(fsl.Threshold(thresh = 25.5, 
                                   direction = 'below', 
                                   args = '-uthr 26.5',
                                   output_type = 'NIFTI_GZ',
                                   out_file = 'left_nAcc.nii.gz'),
                        name = 'extract_lnacc')

#Extract right caudate - seg value 58
extract_rnacc = Node(fsl.Threshold(thresh = 57.5, 
                                   direction = 'below', 
                                   args = '-uthr 58.5',
                                   output_type = 'NIFTI_GZ',
                                   out_file = 'right_nAcc.nii.gz'),
                    name='extract_rnacc')

# %%
#Extract left putamen - seg value 26
extract_lput  = Node(fsl.Threshold(thresh = 11.5, 
                                   direction = 'below', 
                                   args = '-uthr 12.5',
                                   output_type = 'NIFTI_GZ',
                                   out_file = 'left_putamen.nii.gz'),
                        name = 'extract_lput')

#Extract right caudate - seg value 51
extract_rput = Node(fsl.Threshold(thresh = 50.5, 
                                   direction = 'below', 
                                   args = '-uthr 51.5',
                                   output_type = 'NIFTI_GZ',
                                   out_file = 'right_putamen.nii.gz'),
                    name='extract_rput')

# %%
#Extract voxel values from qT1 beneath overlaid mask - Left Hippocampus
get_voxRhipp = Node(fsl.ImageMeants(show_all = True,
                               out_file = 'ROI_voxel-contrasts_RightHippocampus.txt'),
               name = 'get_voxRhipp')

#Extract voxel values from qT1 beneath overlaid mask - Right Hippocampus
get_voxLhipp = Node(fsl.ImageMeants(show_all = True,
                               out_file = 'ROI_voxel-contrasts_LeftHippocampus.txt'),
               name = 'get_voxLhipp')

# %%
#Extract voxel values from qT1 beneath overlaid mask - Left Amygdala
get_voxRamyg = Node(fsl.ImageMeants(show_all = True,
                               out_file = 'ROI_voxel-contrasts_RightAmygdala.txt'),
               name = 'get_voxRamyg')

#Extract voxel values from qT1 beneath overlaid mask - Right Amygdala
get_voxLamyg = Node(fsl.ImageMeants(show_all = True,
                               out_file = 'ROI_voxel-contrasts_LeftAmygdala.txt'),
               name = 'get_voxLamyg')

# %%
#Extract voxel values from qT1 beneath overlaid mask - Left Putamen
get_voxRput = Node(fsl.ImageMeants(show_all = True,
                               out_file = 'ROI_voxel-contrasts_RightPutamen.txt'),
               name = 'get_voxRput')

#Extract voxel values from qT1 beneath overlaid mask - Right Putamen
get_voxLput = Node(fsl.ImageMeants(show_all = True,
                               out_file = 'ROI_voxel-contrasts_LeftPutamen.txt'),
               name = 'get_voxLput')

# %%
#Extract voxel values from qT1 beneath overlaid mask - Left NAcc
get_voxRnacc = Node(fsl.ImageMeants(show_all = True,
                               out_file = 'ROI_voxel-contrasts_RightNAcc.txt'),
               name = 'get_voxRnacc')

#Extract voxel values from qT1 beneath overlaid mask - Right NAcc
get_voxLnacc = Node(fsl.ImageMeants(show_all = True,
                               out_file = 'ROI_voxel-contrasts_LeftNAcc.txt'),
               name = 'get_voxLnacc')

# %%
#Extract voxel values from qT1 beneath overlaid mask - Left Caudate
get_voxRcaud = Node(fsl.ImageMeants(show_all = True,
                               out_file = 'ROI_voxel-contrasts_RightCaudate.txt'),
               name = 'get_voxRcaud')

#Extract voxel values from qT1 beneath overlaid mask - Right Caudate
get_voxLcaud = Node(fsl.ImageMeants(show_all = True,
                               out_file = 'ROI_voxel-contrasts_LeftCaudate.txt'),
               name = 'get_voxLcaud')

# %%
#Register qT1 to T1w
register_qt12 = Node(fsl.FLIRT(out_file = 'registered_qT1_toFreesurfer.nii.gz',
                              output_type = 'NIFTI_GZ',
                              out_matrix_file = 'flirt_transform_qt1.mat'),
                    name = 'register_qt12')

# %%
hippdata_flow = Workflow(name='hippdata_flow')
hippdata_flow.connect([(infosource, sf3, [('subject_id', 'subject_id')]),
                       (sf3, register_qt12, [('qt1_reor', 'in_file')]),
                       (sf3, register_qt12, [('t1w', 'reference')]),
                       (sf3, extract_lhipp, [('aseg', 'in_file')]),
                       (sf3, extract_rhipp, [('aseg', 'in_file')]),
                       (sf3, extract_lamyg, [('aseg', 'in_file')]),
                       (sf3, extract_ramyg, [('aseg', 'in_file')]),
                       (sf3, extract_lput, [('aseg', 'in_file')]),
                       (sf3, extract_rput, [('aseg', 'in_file')]),
                       (sf3, extract_lnacc, [('aseg', 'in_file')]),
                       (sf3, extract_rnacc, [('aseg', 'in_file')]),
                       (sf3, extract_lcaud, [('aseg', 'in_file')]),
                       (sf3, extract_rcaud, [('aseg', 'in_file')]),
                       (extract_lhipp, datasink, [('out_file', '1_check_alignment')]),
                       (extract_rhipp, datasink, [('out_file', '1_check_alignment.@par')]),
                       (extract_lamyg, datasink, [('out_file', '1_check_alignment.@par.@par')]),
                       (extract_ramyg, datasink, [('out_file', '1_check_alignment.@par.@par.@par')]),
                       (extract_lput, datasink, [('out_file', '1_check_alignment.@par.@par.@par.@par')]),
                       (extract_rput, datasink, [('out_file', '1_check_alignment.@par.@par.@par.@par.@par')]),
                       (extract_lnacc, datasink, [('out_file', 
                                                   '1_check_alignment.@par.@par.@par.@par.@par.@par')]),
                       (extract_rnacc, datasink, [('out_file', 
                                                   '1_check_alignment.@par.@par.@par.@par.@par.@par.@par')]),
                       (extract_lcaud, datasink, [('out_file', 
                                                   '1_check_alignment.@par.@par.@par.@par.@par.@par.@par.@par')]),
                       (extract_rcaud, datasink, [('out_file', 
                                                   '1_check_alignment.@par.@par.@par.@par.@par.@par.@par.@par.@par')]),
                       (register_qt12, datasink,[('out_file', '1_check_alignment.@par.@par.@par.@par.@par.@par.@par.@par.@par.@par')]),
                       (register_qt12, get_voxRhipp, [('out_file', 'in_file')]),
                       (extract_rhipp, get_voxRhipp, [('out_file', 'mask')]),
                       (register_qt12, get_voxLhipp, [('out_file', 'in_file')]),
                       (extract_lhipp, get_voxLhipp, [('out_file', 'mask')]),
                       
                       (register_qt12, get_voxRamyg, [('out_file', 'in_file')]),
                       (extract_ramyg, get_voxRamyg, [('out_file', 'mask')]),
                       (register_qt12, get_voxLamyg, [('out_file', 'in_file')]),
                       (extract_lamyg, get_voxLamyg, [('out_file', 'mask')]),
                       
                       (register_qt12, get_voxRput, [('out_file', 'in_file')]),
                       (extract_rput, get_voxRput, [('out_file', 'mask')]),
                       (register_qt12, get_voxLput, [('out_file', 'in_file')]),
                       (extract_lput, get_voxLput, [('out_file', 'mask')]),
                       
                       (register_qt12, get_voxRcaud, [('out_file', 'in_file')]),
                       (extract_rcaud, get_voxRcaud, [('out_file', 'mask')]),
                       (register_qt12, get_voxLcaud, [('out_file', 'in_file')]),
                       (extract_lcaud, get_voxLcaud, [('out_file', 'mask')]),
                       
                       (register_qt12, get_voxRnacc, [('out_file', 'in_file')]),
                       (extract_rnacc, get_voxRnacc, [('out_file', 'mask')]),
                       (register_qt12, get_voxLnacc, [('out_file', 'in_file')]),
                       (extract_lnacc, get_voxLnacc, [('out_file', 'mask')]),
                       
                       (get_voxLhipp, datasink, [('out_file', '2_Extracted_Stats')]),
                       (get_voxRhipp, datasink, [('out_file', '2_Extracted_Stats.@par')]),
                       (get_voxLamyg, datasink, [('out_file', '2_Extracted_Stats.@par.@par')]),
                       (get_voxRamyg, datasink, [('out_file', '2_Extracted_Stats.@par.@par.@par')]),
                       (get_voxLput, datasink, [('out_file', '2_Extracted_Stats.@par.@par.@par.@par')]),
                       (get_voxRput, datasink, [('out_file', '2_Extracted_Stats.@par.@par.@par.@par.@par')]),
                       (get_voxLnacc, datasink, [('out_file', '2_Extracted_Stats.@par.@par.@par.@par.@par.@par')]),
                       (get_voxRnacc, datasink, [('out_file', '2_Extracted_Stats.@par.@par.@par.@par.@par.@par.@par')]),
                       (get_voxLcaud, datasink, [('out_file', '2_Extracted_Stats.@par.@par.@par.@par.@par.@par.@par.@par')]),
                       (get_voxRcaud, datasink, [('out_file', '2_Extracted_Stats.@par.@par.@par.@par.@par.@par.@par.@par.@par')])
                      ])

hippdata_flow.base_dir = workflow_dir
hippdata_flow.write_graph(graph2use='flat')
preproc = hippdata_flow.run('MultiProc', plugin_args={'n_procs': 4})

# %%
subject_list
